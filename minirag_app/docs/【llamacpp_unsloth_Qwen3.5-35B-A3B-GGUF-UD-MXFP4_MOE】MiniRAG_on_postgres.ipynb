# %% [markdown]
# ## llamacpp_unsloth_Qwen3.5-35B-A3B-GGUF:UD-MXFP4_MOE(非思考モード)
# llamacpp を使う場合は 172.17.0.1 で接続する必要がある。
#
# 172.17.0.1は、主にDocker（ドッカー）環境におけるデフォルトのブリッジネットワーク（docker0）のホスト側のIPアドレスです。
#
# ## 所感
#
# - Qwen3.5-35B-A3B-GGUF-UD-MXFP4_MOE(非思考モード) の速度も精度も十分。現時点の最高峰で MiniRAG でも十分使える。これで完全ローカルになった。
# - sashisuseso_GPT-OSS-Swallow-20B-SFT-v0.1-MXFP4 は速度は早いけど、コンテキストからうまく回答ができなかったので使えない。

# %%
import json
import time
import httpx

BASE_URL = "http://172.17.0.1:1067"
MODEL    = "Qwen3.5-35B-A3B-GGUF-UD-MXFP4_MOE"   # 非思考モードで使用

HEADERS = {
    "Content-Type": "application/json",
    "Authorization": "Bearer no-key",
}

def wait_until_ready(timeout_sec: float = 60.0) -> None:
    deadline = time.time() + timeout_sec
    while time.time() < deadline:
        r = httpx.get(f"{BASE_URL}/health", timeout=5.0)
        if r.status_code == 200:
            return
        if r.status_code == 503:
            time.sleep(0.5)
            continue
        r.raise_for_status()
    raise TimeoutError("llama-server が ready になりませんでした")

def stream_chat(user_text: str, system_text: str = "あなたは高度なAIアシスタントです。英語で考えて日本語で回答してください。") -> None:
    payload = {
        "model": MODEL,
        "messages": [
            {"role": "system", "content": system_text},
            {"role": "user", "content": user_text},
        ],
        "temperature": 0.7,
        "top_p": 0.8,
        "top_k": 20,
        "min_p": 0.0,
        "stream": True,
    }

    with httpx.Client(base_url=BASE_URL, headers=HEADERS, timeout=None) as client:
        # httpx は stream=True ではなく client.stream(...) を使う :contentReference[oaicite:5]{index=5}
        with client.stream("POST", "/v1/chat/completions", json=payload) as resp:
            resp.raise_for_status()

            for line in resp.iter_lines():
                if not line:
                    continue

                # SSE: "data: ...."
                if not line.startswith("data:"):
                    continue

                data_str = line[len("data:"):].strip()
                if data_str == "[DONE]":
                    break

                chunk = json.loads(data_str)

                # OpenAI 互換: choices[0].delta.content に増分が入ることが多い
                choice0 = (chunk.get("choices") or [{}])[0]
                delta = choice0.get("delta") or {}
                text = delta.get("content")
                if text:
                    print(text, end="", flush=True)

    print()  # 改行

if __name__ == "__main__":
    wait_until_ready()
    stream_chat("RustでHTTPサーバーを立てる最小例を説明して。")
# Out:
# Rust で HTTP サーバーを立てる最小限の例を説明します。
# Rust では、標準ライブラリ（`std`）だけで TCP サーバーを作ることも可能ですが、HTTP プロトコルを正しく処理するには少し複雑になります。そのため、実用的かつコード量が最小になる「`tiny_http`」という軽量なライブラリを使う方法が一般的です。
#
# 以下の手順で進めます。
#
# ### 1. プロジェクトの準備
#
# まず、新しい Rust プロジェクトを作成し、依存関係を追加します。
#
# ```bash
# # プロジェクト作成
# cargo new tiny_http_server
# cd tiny_http_server
#
# # tiny_http ライブラリを追加
# cargo add tiny_http
# ```
#
# ### 2. コードの実装 (`src/main.rs`)
#
# `main.rs` に以下のコードを記述します。このコードは、ポート 8080 でリッスンし、任意の URL にアクセスされたら「Hello, World!」を返すだけの最小構成です。
#
# ```rust
# use tiny_http::{Server, Response};
#
# fn main() {
#     // ポート 8080 でサーバーを起動
#     let server = Server::http("127.0.0.1:8080").unwrap();
#
#     println!("サーバー起動中：http://127.0.0.1:8080");
#
#     // リクエストを処理するループ
#     for request in server.incoming_requests() {
#         // HTTP 応答を生成（テキスト/plain, ステータス 200 OK）
#         let response = Response::from_data("Hello, World!");
#
#         // 応答を送信
#         let _ = request.respond(response);
#     }
# }
# ```
#
# ### 3. 実行とテスト
#
# ターミナルで以下のコマンドを実行してサーバーを起動します。
#
# ```bash
# cargo run
# ```
#
# その後、ブラウザや `curl` で以下のようにアクセスすると、応答が得られます。
#
# ```bash
# curl http://127.0.0.1:8080
# # 出力: Hello, World!
# ```
#
# ### 解説：なぜこのコードで最小なのか？
#
# 1.  **依存関係**: `tiny_http` は Rust の生態系で最も軽量な HTTP サーバーライブラリの一つです。`actix-web` や `axum` などのフル機能フレームワークに比べて、依存する crates が非常に少なく、コンパイル速度も速いです。
# 2.  **標準ライブラリのみでの実装**:
#     *   標準ライブラリ（`std::net::TcpListener`）だけで HTTP を実装する場合、HTTP リクエストの解析（ヘッダーの読み取り、メソッドの特定など）を自分で記述する必要があります。これは数百行に及び、バグのリスクが高いため、「最小例」としては不向きです。
#     *   上記の `tiny_http` の例は、外部の信頼されたライブラリを 1 つ使うことで、本質的なロジック（リクエストを受け取って応答を送る）のみを数行で表現しています。
# 3.  **非同期 vs 同期**: この例は同期（`blocking`）方式です。Rust の非同期ランタイム（`tokio` など）を使うとコード量は少し増えますが、高負荷なサーバーには必要です。しかし「最小例」という要件であれば、同期方式で `for request in server.incoming_requests()` を回すのが最もシンプルです。
#
# このコードをベースに、ルーティングの追加や JSON の返却などを拡張していくことで、本格的な API サーバーへ発展させることができます。

# %% [markdown]
# # MiniRAG を postgres で実行する
#
# - 精度は安定していないところもあるし、まだバグが潜んでいる可能性もあるが、一旦このレベルで OK

# %%
# 必要なライブラリのインポート
import os
import tempfile
from minirag import MiniRAG, QueryParam
from minirag.llm.hf import (
    hf_model_complete,
    hf_embed,
)
# from minirag.llm.openai import openrouter_openai_complete
# from minirag.llm.openai import openai_complete_if_cache
from minirag.utils import EmbeddingFunc
from minirag.utils import (
    wrap_embedding_func_with_attrs,
    locate_json_string_body_from_string,
    safe_unicode_decode,
    logger,
)

import asyncpg
from psycopg_pool import AsyncConnectionPool
from minirag.kg.postgres_impl import PostgreSQLDB
from minirag.kg.postgres_impl import PGKVStorage
from minirag.kg.postgres_impl import PGVectorStorage
from minirag.kg.postgres_impl import PGGraphStorage
from minirag.kg.postgres_impl import PGDocStatusStorage

from transformers import AutoModel, AutoTokenizer
from tenacity import retry, stop_after_attempt, wait_random_exponential, retry_if_exception
from openai import RateLimitError, APIStatusError # openaiライブラリが投げる例外をインポート
import asyncio
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### データベース接続テスト

# %%
import psycopg
from psycopg.rows import dict_row

def get_conn():
    url = os.getenv("DATABASE_URL")
    if url:
        return psycopg.connect(url, row_factory=dict_row)
    # fallback: assemble from separate vars
    dsn = (
        f"host={os.getenv('PGHOST','db')} "
        f"port={os.getenv('PGPORT','5432')} "
        f"dbname={os.getenv('PGDATABASE','postgres')} "
        f"user={os.getenv('POSTGRES_USER','postgres')} "
        f"password={os.getenv('POSTGRES_PASSWORD')}"
    )
    return psycopg.connect(dsn, row_factory=dict_row)

with get_conn() as conn, conn.cursor() as cur:
    cur.execute("SELECT version();")
    print(cur.fetchone())
# Out:
# {'version': 'PostgreSQL 16.11 (Debian 16.11-1.pgdg12+1) on x86_64-pc-linux-gnu, compiled by gcc (Debian 12.2.0-14+deb12u1) 12.2.0, 64-bit'}

# %% [markdown]
# ### ハイブリッドクエリのテスト（任意）
# - 前提: 先に init_db.sh が実行されテーブルが作成されていること

# %%
def get_conn():
    """
    環境変数からデータベース接続情報を取得し、接続オブジェクトを返す。
    DATABASE_URLが設定されていればそれを使用し、なければ個別の変数を組み立てる。
    結果は辞書形式で返されるように設定済み。
    """
    url = os.getenv("DATABASE_URL")
    if url:
        # DATABASE_URLが設定されている場合
        return psycopg.connect(url, row_factory=dict_row)
    
    # DATABASE_URLがない場合、個別の環境変数からDSNを組み立てる
    # PGPASSWORDが設定されていないと接続に失敗するため、チェックを追加するとより親切
    password = os.getenv('PGPASSWORD')
    if not password:
        raise ValueError("環境変数 PGPASSWORD が設定されていません。")
        
    dsn = (
        f"host={os.getenv('PGHOST', 'localhost')} "
        f"port={os.getenv('PGPORT', '5432')} "
        f"dbname={os.getenv('PGDATABASE', 'postgres')} "
        f"user={os.getenv('POSTGRES_USER', 'postgres')} "
        f"password={password}"
    )
    return psycopg.connect(dsn, row_factory=dict_row)

def find_recommended_products_for_alice(_results):
    """
    指定されたSQLクエリを実行し、'Alice'が好む商品とベクトル的に類似した商品を取得する。
    """
    # 実行したいSQLクエリを三重クォートで定義
    # これにより、複数行のクエリを読みやすく記述できる
    sql_query = """
    SELECT
        p.id,
        p.name,
        p.embedding
    FROM
        public.products AS p
    JOIN
        -- cypher関数でグラフクエリを実行し、結果をテーブルのように扱う
        cypher('my_minirag_graph', $$
            MATCH (u:User {name: 'Alice'})-[:LIKES]->(prod:Product)
            RETURN prod.product_id
        $$) AS liked(product_id agtype)
    ON
        -- グラフクエリの結果(agtype)を整数にキャストしてproductsテーブルのIDと結合
        p.id = (liked.product_id)::INTEGER
    ORDER BY
        -- pgvectorの<->演算子で、指定ベクトルとのコサイン距離が近い順に並び替え
        p.embedding <=> '[0.1, 0.1, 0.2]';
    """

    try:
        # with文で接続とカーソルを管理し、処理終了後に自動でクローズする
        with get_conn() as conn, conn.cursor() as cur:
            print("データベースに接続し、クエリを実行します...")
            
            # クエリの実行
            cur.execute(sql_query)
            
            # 全ての実行結果を取得 (fetchall)
            # 1件だけなら fetchone(), 複数件なら fetchall() を使う
            results = cur.fetchall()
            
            print("\n--- クエリ実行結果 ---")
            if results:
                # 取得した結果を1行ずつ表示
                for row in results:
                    print(row)
                    _results.append(row)
            else:
                print("条件に一致する結果は見つかりませんでした。")
        return _results

    except psycopg.Error as e:
        print(f"データベースエラーが発生しました: {e}")
    except ValueError as e:
        print(f"設定エラーが発生しました: {e}")

query_results = []
query_results = find_recommended_products_for_alice(query_results)
# Out:
# データベースに接続し、クエリを実行します...
#
# --- クエリ実行結果 ---
# {'id': 1, 'name': '商品A', 'embedding': '[0.1,0.2,0.3]'}
# {'id': 2, 'name': '商品B', 'embedding': '[0.2,0.1,0.9]'}

# %% [markdown]
# ### マークダウンに整形

# %%
def convert_to_markdown(data: list[dict]) -> str:
    """
    辞書のリストをマークダウンのテーブル形式に変換します。

    Args:
        data: 辞書のリスト。各辞書がテーブルの1行に対応します。

    Returns:
        マークダウン形式のテーブル文字列。
    """
    if not data:
        return "データがありません。"

    # ヘッダーの作成 (最初のデータのキーから取得)
    headers = data[0].keys()
    header_line = "| " + " | ".join(headers) + " |"

    # 区切り線の作成
    separator_line = "| " + " | ".join(["---"] * len(headers)) + " |"

    # データ行の作成
    data_lines = []
    for row in data:
        # 各値を文字列に変換して結合
        values = [str(row.get(h, "")) for h in headers]
        data_lines.append("| " + " | ".join(values) + " |")

    # 全ての行を結合して返す
    return "\n".join([header_line, separator_line] + data_lines)

# --- 変換を実行して結果を表示 ---
markdown_table = convert_to_markdown(query_results)
print(markdown_table)
# Out:
# | id | name | embedding |
# | --- | --- | --- |
# | 1 | 商品A | [0.1,0.2,0.3] |
# | 2 | 商品B | [0.2,0.1,0.9] |

# %%
#  id | name  |   embedding   
# ----+-------+---------------
#   1 | 商品A | [0.1,0.2,0.3]
#   2 | 商品B | [0.2,0.1,0.9]

# 上記の結果になればOK

# %%
# API KEY が見えないようにコメントアウト

# print(os.getenv("OPENROUTER_API_KEY"))
# print(os.getenv("OPENAI_API_KEY"))
print("Openrouter APIキーが設定されました")
print()

HF_TOKEN = os.getenv("HF_TOKEN")
# print(HF_TOKEN)
print("HuggingFace TOKEN が設定されました")
# Out:
# Openrouter APIキーが設定されました
#
# HuggingFace TOKEN が設定されました

# %%
use_japanese_embedding = False

if use_japanese_embedding:
    # MINI モードでの回答ができなくなったので、逆に精度が落ちたかも。
    EMBEDDING_MODEL = "hotchpotch/static-embedding-japanese"
    EMBEDDING_DIM   = 1024
    TOKENIZER_MODEL = "hotchpotch/xlm-roberta-japanese-tokenizer"
    print("-------------- static-embedding-japanese を使用します --------------")
else:
    # 埋め込みモデルの設定
    EMBEDDING_MODEL = "sentence-transformers/all-MiniLM-L6-v2"
    EMBEDDING_DIM   = 384
    print("-------------- all-MiniLM-L6-v2 を使用します --------------")


# -------------------------------------------------
# LLMの設定
# -------------------------------------------------
# LLM_MODEL = "Qwen/Qwen3-1.7B"  # または "Qwen/Qwen3-4B", "Qwen/Qwen3-1.7B" など
# LLM_MODEL = "jaeyong2/Qwen2.5-3B-Instruct-Ja-SFT"
# LLM_MODEL = "deepseek/deepseek-chat-v3-0324:free"
# LLM_MODEL = "deepseek/deepseek-v3.2-speciale"    # 一生進まないのでこれは使わない。思考モードが悪さしている？
# LLM_MODEL = "qwen/qwen3-235b-a22b-2507"          # これは良い
# LLM_MODEL = "qwen/qwen3-30b-a3b-thinking-2507"     # 30B でも十分だった
# LLM_MODEL = "gpt-oss:20b"
# LLM_MODEL = "unsloth/Qwen3.5-27B-GGUF"
LLM_MODEL = "Qwen3.5-35B-A3B-GGUF-UD-MXFP4_MOE"    # 非思考モードで使用
# -------------------------------------------------



# 作業ディレクトリの作成
WORKING_DIR = "/tmp/minirag_demo"
os.makedirs(WORKING_DIR, exist_ok=True)

print(f"作業ディレクトリ: {WORKING_DIR}")


# DATA_PATH = args.datapath
# QUERY_PATH = args.querypath
# OUTPUT_PATH = args.outputpath
# print("USING LLM:", LLM_MODEL)
# print("USING WORKING DIR:", WORKING_DIR)
# Out:
# -------------- all-MiniLM-L6-v2 を使用します --------------
# 作業ディレクトリ: /tmp/minirag_demo

# %%
if use_japanese_embedding:

    from sentence_transformers import SentenceTransformer
    model = SentenceTransformer(EMBEDDING_MODEL, device="cpu", token=HF_TOKEN)
    
    query = "美味しいラーメン屋に行きたい"
    docs = [
        "素敵なカフェが近所にあるよ。落ち着いた雰囲気でゆっくりできるし、窓際の席からは公園の景色も見えるんだ。",
        "新鮮な魚介を提供する店です。地元の漁師から直接仕入れているので鮮度は抜群ですし、料理人の腕も確かです。",
        "あそこは行きにくいけど、隠れた豚骨の名店だよ。スープが最高だし、麺の硬さも好み。",
        "おすすめの中華そばの店を教えてあげる。とりわけチャーシューが手作りで柔らかくてジューシーなんだ。",
    ]
    
    embeddings = model.encode([query] + docs)
    print(embeddings.shape)
    similarities = model.similarity(embeddings[0], embeddings[1:])
    for i, similarity in enumerate(similarities[0].tolist()):
        print(f"{similarity:.04f}: {docs[i]}")

else:
    
    tokenizer = AutoTokenizer.from_pretrained(EMBEDDING_MODEL, token=HF_TOKEN)
    model = AutoModel.from_pretrained(EMBEDDING_MODEL, token=HF_TOKEN)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %% [markdown]
# ## transformer の API で使えるように変換する

# %%
if use_japanese_embedding:
    
    import torch
    from torch import nn
    from transformers import PreTrainedModel, PretrainedConfig
    from transformers.modeling_outputs import BaseModelOutputWithPoolingAndCrossAttentions
    
    
    class StaticEmbeddingConfig(PretrainedConfig):
        model_type = "static-embedding"
    
        def __init__(self, vocab_size=32768, hidden_size=1024, pad_token_id=0, **kwargs):
            super().__init__(pad_token_id=pad_token_id, **kwargs)
            self.vocab_size = vocab_size
            self.hidden_size = hidden_size
    
    
    class StaticEmbeddingModel(PreTrainedModel):
        config_class = StaticEmbeddingConfig
    
        def __init__(self, config: StaticEmbeddingConfig):
            super().__init__(config)
            # ★ EmbeddingBag そのものでも OK ですが、
            #   シーケンス長をそろえて attention_mask で平均を取る方が扱いやすいので nn.Embedding に変更
            self.embedding = nn.Embedding(
                num_embeddings=config.vocab_size,
                embedding_dim=config.hidden_size,
                padding_idx=config.pad_token_id,
            )
            self.post_init()  # transformers の重み初期化
    
        def forward(self, input_ids, attention_mask=None, **kwargs):
            """
            - input_ids      : (batch, seq_len)
            - attention_mask : (batch, seq_len) — 0 は padding
            戻り値は Transformers 共通の BaseModelOutputWithPoolingAndCrossAttentions
            """
            if attention_mask is None:
                attention_mask = (input_ids != self.config.pad_token_id).int()
    
            token_embs = self.embedding(input_ids)                       # (B, L, H)
            # マスク付き平均プール
            masked_embs = token_embs * attention_mask.unsqueeze(-1)      # (B, L, H)
            lengths = attention_mask.sum(dim=1, keepdim=True).clamp(min=1e-8)  # (B, 1)
            sentence_emb = masked_embs.sum(dim=1) / lengths              # (B, H)
    
            return BaseModelOutputWithPoolingAndCrossAttentions(
                last_hidden_state=token_embs,  # ここでは token レベルをそのまま
                pooler_output=sentence_emb,    # 文ベクトル
                attentions=None,
                cross_attentions=None,
            )

# %%
if use_japanese_embedding:
    """
    SentenceTransformer 版 (hotchpotch/static-embedding-japanese) から
    StaticEmbeddingModel へ重みをコピーして保存するスクリプト
    """
    
    SRC = "hotchpotch/static-embedding-japanese"   # オリジナル
    DST = "./static-embedding-transformers"        # 保存先
    
    # ① SentenceTransformer を読み込む
    st_model = SentenceTransformer(SRC)
    embedding_weight = st_model[0].embedding.weight.data   # nn.EmbeddingBag の重みを取得
    
    # ② Config → Model を作成
    config = StaticEmbeddingConfig(
        vocab_size=embedding_weight.size(0),
        hidden_size=embedding_weight.size(1),
        pad_token_id=0,           # トークナイザの <pad> が id=0
    )
    model = StaticEmbeddingModel(config)
    
    # ③ 重みコピー
    with torch.no_grad():
        model.embedding.weight.copy_(embedding_weight)
    
    # ④ save_pretrained で書き出し
    model.save_pretrained(DST)
    # st_model.tokenizer.save_pretrained(DST)   # tokenizer.json なども一緒に保存
    
    print(f"✅ 変換完了 — 保存先: {DST}")

# %%
if use_japanese_embedding:
    
    MODEL_DIR = "./static-embedding-transformers"
    tokenizer = AutoTokenizer.from_pretrained(TOKENIZER_MODEL)
    model     = StaticEmbeddingModel.from_pretrained(MODEL_DIR)
    
    sentences = [
        "美味しいラーメン屋に行きたい",
        "あそこは行きにくいけど、隠れた豚骨の名店だよ。スープが最高だし、麺の硬さも好み。",
    ]
    
    inputs = tokenizer(
        sentences,
        return_tensors="pt",
        padding=True,
        truncation=True,
        add_special_tokens=False,   # 元モデルは special tokens なし
    )
    
    with torch.no_grad():
        outputs = model(**inputs)
        vecs = outputs.pooler_output     # (batch, hidden_size)
    
    print("shape:", vecs.shape)          # torch.Size([2, 1024])
    similarity = torch.nn.functional.cosine_similarity(vecs[0], vecs[1], dim=0)
    print("cosine:", similarity.item())

# %%
import sys
from typing import List, Union

if sys.version_info < (3, 9):
    from typing import AsyncIterator
else:
    from collections.abc import AsyncIterator

from openai import (
    AsyncOpenAI,
    APIConnectionError,
    RateLimitError,
)


async def openai_complete_if_cache(
    model,
    prompt,
    system_prompt=None,
    history_messages=None,
    base_url=None,
    api_key=None,
    **kwargs,
) -> Union[str, AsyncIterator[str]]:
    """
    llama-server(OpenAI互換)向けに接続・JSON(response_format)・min_p / top_k を安定化した版。

    llama-server 設定（ユーザー指定）:
      - alias: Qwen3.5-35B-A3B-GGUF-UD-MXFP4_MOE
      - host: 0.0.0.0 (待受)
      - port: 1067
      - temperature: 0.7 / top_p: 0.8 / top_k: 20 / min_p: 0.0 / stream: False
    """
    import json
    import httpx
    import os  # os.environ を使用するため
    from urllib.parse import urlparse, urlunparse

    # ---- llama-server defaults (ユーザー指定) ----
    LLAMA_SERVER_BASE_URL_DEFAULT = "http://172.17.0.1:1067/v1"
    LLAMA_SERVER_MODEL_ALIAS_DEFAULT = (
        "Qwen3.5-35B-A3B-GGUF-UD-MXFP4_MOE"
    )
    LLAMA_SERVER_DEFAULTS = {
        "temperature": 0.7,
        "top_p": 0.8,
        "top_k": 20,
        "min_p": 0.0,
        "stream": False,
    }

    def _is_official_openai(resolved_base_url: str | None) -> bool:
        if resolved_base_url is None:
            return True
        return "api.openai.com" in resolved_base_url

    def _is_pydantic_model_class(x) -> bool:
        try:
            return isinstance(x, type) and issubclass(x, BaseModel)
        except Exception:
            return False

    def _normalize_json_mode_response_format(rf):
        if isinstance(rf, dict):
            return rf
        if isinstance(rf, str) and rf in ("json", "json_object"):
            return {"type": "json_object"}
        return None

    def _augment_system_prompt_for_json(sp: str | None, rf) -> str:
        base = (sp or "").strip()
        lines: list[str] =[]

        if _is_pydantic_model_class(rf):
            try:
                schema = rf.model_json_schema()
                schema_text = json.dumps(schema, ensure_ascii=False)
                lines.append("必ずJSONだけを出力してください。前後に説明文やコードブロックは付けないでください。")
                lines.append("次のJSONスキーマに厳密に従ってください。")
                lines.append(schema_text)
            except Exception:
                lines.append("必ずJSONだけを出力してください。前後に説明文やコードブロックは付けないでください。")
        else:
            lines.append("必ずJSONオブジェクトだけを出力してください。前後に説明文やコードブロックは付けないでください。")

        addon = "\n".join(lines).strip()
        if not addon:
            return base
        if not base:
            return addon
        return f"{base}\n\n{addon}"

    def _sanitize_base_url(raw: str) -> str:
        """
        - 余計な空白除去
        - スキームが無ければ http を付与
        - host が 0.0.0.0 なら 172.17.0.1 に置換（接続先としては不適になりやすい）
        - パス末尾が /v1 になるよう補正（OpenAI SDK の base_url 期待）
        """
        s = (raw or "").strip()
        if not s:
            return LLAMA_SERVER_BASE_URL_DEFAULT
        if "://" not in s:
            s = "http://" + s

        u = urlparse(s)
        netloc = u.netloc.replace("0.0.0.0", "172.17.0.1")

        path = (u.path or "").rstrip("/")
        if path == "":
            path = "/v1"
        elif path != "/v1" and not path.endswith("/v1"):
            # 例: http://172.17.0.1:1067 -> /v1 を付ける
            path = path + "/v1"

        u2 = u._replace(netloc=netloc, path=path)
        return urlunparse(u2)

    def _resolve_base_url(explicit_base_url: str | None) -> str:
        # “こちらで設定してください”に合わせ、明示指定が無ければ llama-server 既定を使う
        if explicit_base_url is not None:
            return _sanitize_base_url(explicit_base_url)
        return _sanitize_base_url(LLAMA_SERVER_BASE_URL_DEFAULT)

    async def _preflight_healthcheck(url_v1: str) -> None:
        """
        llama-server は /health と /v1/health を提供するので、base_url(/v1) 側で叩く。
        タイムアウト：10秒(2秒は厳しい)
        """
        health_url = url_v1.rstrip("/") + "/health"
        last_error: Exception | None = None
        for _ in range(3):
            try:
                async with httpx.AsyncClient(timeout=5.0) as client:
                    r = await client.get(health_url)
                # 200 以外でも “接続できている” ことは分かるので、接続不能だけを明確に切り分けたい
                logger.debug("Healthcheck %s -> %s", health_url, r.status_code)
                return
            except Exception as e:
                last_error = e
                await asyncio.sleep(0.5)
        # preflight は補助的チェック。ここで即失敗にせず、本リクエスト側に委ねる。
        logger.warning(
            "llama-server preflight healthcheck failed (continue): base_url=%s / url=%s / reason=%r",
            url_v1,
            health_url,
            last_error,
        )

    # ---- API key ----
    if api_key:
        os.environ["OPENAI_API_KEY"] = api_key

    # ---- base_url / model ----
    resolved_base_url = _resolve_base_url(base_url)
    official_openai = _is_official_openai(resolved_base_url)

    if not model:
        model = LLAMA_SERVER_MODEL_ALIAS_DEFAULT

    # ---- client ----
    resolved_api_key = api_key or os.getenv("OPENAI_API_KEY") or "sk-local-no-key-required"
    openai_async_client = AsyncOpenAI(api_key=resolved_api_key, base_url=resolved_base_url)

    # ---- strip internal kwargs ----
    kwargs.pop("hashing_kv", None)
    kwargs.pop("keyword_extraction", None)

    # ---- llama-server sampling defaults (ユーザー指定) ----
    kwargs.setdefault("temperature", LLAMA_SERVER_DEFAULTS["temperature"])
    kwargs.setdefault("top_p", LLAMA_SERVER_DEFAULTS["top_p"])
    kwargs.setdefault("stream", LLAMA_SERVER_DEFAULTS["stream"])

    # 【修正箇所】top_k, min_p は SDK が create() 引数として受け付けないので extra_body へ移す準備
    if official_openai:
        kwargs.pop("top_k", None)
        kwargs.pop("min_p", None)
        top_k_value = None
        min_p_value = None
    else:
        top_k_value = kwargs.pop("top_k", LLAMA_SERVER_DEFAULTS["top_k"])
        min_p_value = kwargs.pop("min_p", LLAMA_SERVER_DEFAULTS["min_p"])

    # ---- messages ----
    if history_messages is None:
        history_messages =[]

    response_format = kwargs.pop("response_format", None)
    effective_system_prompt = system_prompt
    if response_format is not None:
        effective_system_prompt = _augment_system_prompt_for_json(system_prompt, response_format)

    messages =[]
    if effective_system_prompt:
        messages.append({"role": "system", "content": effective_system_prompt})
    messages.extend(history_messages)
    messages.append({"role": "user", "content": prompt})

    # ---- logs ----
    logger.debug("===== Query Input to LLM =====")
    logger.debug(f"Base URL: {resolved_base_url}")
    logger.debug(f"Model: {model}")
    logger.debug(f"Kwargs: { {k: v for k, v in kwargs.items() if k != 'api_key'} }")

    # ---- preflight (接続不能を早く・分かりやすく) ----
    if not official_openai:
        await _preflight_healthcheck(resolved_base_url)

    # ---- request ----
    use_stream = bool(kwargs.get("stream", False))

    # (A) OpenAI公式 + Pydantic response_format の場合は parse を試す（stream時は不可）
    if (not use_stream) and official_openai and _is_pydantic_model_class(response_format):
        try:
            parsed_resp = await openai_async_client.beta.chat.completions.parse(
                model=model,
                messages=messages,
                response_format=response_format,
                **kwargs,
            )
            msg = parsed_resp.choices[0].message if parsed_resp and parsed_resp.choices else None
            if msg is not None and getattr(msg, "parsed", None) is not None:
                out = msg.parsed.model_dump_json()
                if r"\u" in out:
                    out = safe_unicode_decode(out.encode("utf-8"))
                return out

            content = getattr(msg, "content", "") if msg is not None else ""
            if content and r"\u" in content:
                content = safe_unicode_decode(content.encode("utf-8"))
            if content:
                try:
                    return locate_json_string_body_from_string(content)
                except Exception:
                    return content
            return ""
        except Exception as e:
            logger.warning("beta.chat.completions.parse failed; fallback to create(): %s", e)

    # (B) create() 用 kwargs
    create_kwargs = dict(kwargs)

    # JSON mode（公式OpenAIのみ）
    if (not use_stream) and official_openai and response_format is not None:
        rf = _normalize_json_mode_response_format(response_format)
        if rf is not None:
            create_kwargs["response_format"] = rf
        # Pydantic は parse 失敗時にここへ来るので、create側ではプロンプト誘導で対応

    # 【修正箇所】llama-server 向け top_k, min_p を extra_body に注入
    if not official_openai:
        if top_k_value is not None or min_p_value is not None:
            extra_body = create_kwargs.pop("extra_body", None)
            if not isinstance(extra_body, dict):
                extra_body = {}
            if top_k_value is not None:
                extra_body["top_k"] = top_k_value
            if min_p_value is not None:
                extra_body["min_p"] = min_p_value
            create_kwargs["extra_body"] = extra_body

    try:
        response = await openai_async_client.chat.completions.create(
            model=model,
            messages=messages,
            **create_kwargs,
        )
    except APIConnectionError as e:
        # ここに来るのは「到達不能」系がほとんどなので、情報を付ける
        raise ConnectionError(
            "OpenAI互換サーバへの接続に失敗しました。\n"
            f"- base_url = {resolved_base_url}\n"
            "確認: `curl http://172.17.0.1:1067/v1/health` が返るかを見てください。\n"
            "注: llama-server の `--host 0.0.0.0` は待受用です。接続先は 172.17.0.1 か実IPにしてください。"
        ) from e

    # ---- streaming ----
    if hasattr(response, "__aiter__"):

        async def inner():
            async for chunk in response:
                content = chunk.choices[0].delta.content
                if content is None:
                    continue
                if r"\u" in content:
                    content = safe_unicode_decode(content.encode("utf-8"))
                yield content

        return inner()

    # ---- non-stream ----
    if not response or not hasattr(response, "choices") or not response.choices:
        logger.error("No valid choices returned. Full response: %s", response)
        return ""

    msg = response.choices[0].message
    content = getattr(msg, "content", None)
    if content is None:
        logger.error("The message content is None. Full response: %s", response)
        return ""

    if r"\u" in content:
        content = safe_unicode_decode(content.encode("utf-8"))

    # response_format 指定時は JSON 部分だけ抜き出す（llama-server等の差異吸収）
    if (not use_stream) and response_format is not None:
        try:
            return locate_json_string_body_from_string(content)
        except Exception:
            return content

    return content



# どのエラーでリトライするかを定義
# 429 (RateLimitError) や サーバー側のエラー(5xx) でリトライするのが一般的
def should_retry(e: Exception) -> bool:
    if isinstance(e, RateLimitError):
        print(f"RateLimitError発生。リトライします...: {e}")
        return True
    # 5xx系のサーバーエラーでもリトライすることが多い
    if isinstance(e, APIStatusError) and e.status_code >= 500:
        print(f"サーバーエラー( {e.status_code} )発生。リトライします...: {e}")
        return True
    if isinstance(e, APIConnectionError):
        print(f"接続エラー発生。リトライします...: {e}")
        return True
    if isinstance(e, ConnectionError):
        print(f"接続失敗発生。リトライします...: {e}")
        return True
    return False


@retry(
    wait=wait_random_exponential(multiplier=30, max=100), # 30, 32, 34, 38秒...とランダムな時間を加えて待つ（最大100秒）
    stop=stop_after_attempt(5), # 最大5回リトライする
    retry=retry_if_exception(should_retry) # 上で定義した条件の例外が発生した場合にリトライ
)
async def openai_complete(
    prompt,
    system_prompt=None,
    history_messages=None,
    keyword_extraction=False,
    **kwargs,
) -> Union[str, AsyncIterator[str]]:
    """
    - keyword_extraction=True の場合、JSONを返すように response_format を有効化
    - model は hashing_kv.global_config["llm_model_name"] を優先し、無ければ llama-server の alias を使う
    """
    if history_messages is None:
        history_messages =[]

    kw_flag = kwargs.pop("keyword_extraction", None)
    keyword_extraction = bool(keyword_extraction or kw_flag)

    if keyword_extraction and "response_format" not in kwargs:
        kwargs["response_format"] = "json"

    LLAMA_SERVER_MODEL_ALIAS_DEFAULT = (
        "Qwen3.5-35B-A3B-GGUF-UD-MXFP4_MOE"
    )
    model_name = None
    hashing_kv = kwargs.get("hashing_kv")
    try:
        model_name = hashing_kv.global_config.get("llm_model_name")
    except Exception:
        model_name = None
    if not model_name:
        model_name = LLAMA_SERVER_MODEL_ALIAS_DEFAULT

    return await openai_complete_if_cache(
        model_name,
        prompt,
        system_prompt=system_prompt,
        history_messages=history_messages,
        **kwargs,
    )

# %%
# !pwd

# !ls
# Out:
# /app/docs
# '!- Ollama-GPT OSS 20B はハルシネーションはあるけど使える可能性はありそう.txt'
#  MiniRAG_on_Colabのサンプルコード.ipynb
#  MiniRAG_on_postgres.ipynb
#  MiniRAG_static-embedding-japanese.ipynb
#  POSTGRESQL_USAGE.md
#  POSTGRESQL_USAGE_JA.md
#  PostgreSQL_on_Colabのサンプルコード.ipynb
# '【Ollama-GPT OSS 20B】MiniRAG_on_postgres.ipynb'
#  【llamacpp_unsloth_Qwen3.5-27B-GGUF_UD-Q4_K_XL】MiniRAG_on_postgres-Copy1.ipynb

# %% [markdown]
# ### RAGシステムセットアップ

# %%
# テーブルチェックで以下のような表示大量に出るのは正常に動いている証拠
# ---
# PostgreSQL database error: relation "lightrag_doc_full" does not exist
# Failed to check table LIGHTRAG_DOC_FULL in PostgreSQL database
# ---
# SELECT 1 FROM LIGHTRAG_DOC_FULL LIMIT 1
# None
# ---

async def setup_rag_system():
    """RAGシステムを初期化し、準備ができたインスタンスを返す"""

    # 1. データベース設定
    db_config={
        "host": "postgres",    # これは Docker のサービス名「postgres」で指定
        "port": 5432,
        "user": os.getenv("POSTGRES_USER"),
        "password": os.getenv("POSTGRES_PASSWORD"),
        "database": os.getenv("POSTGRES_DB"),
    }

    # 2. PostgreSQLDBインスタンスを作成
    db_postgre = PostgreSQLDB(config=db_config)

    # 3. データベース接続を初期化
    print("------------------------- ポスグレに接続しています -------------------------")
    await db_postgre.initdb()
    print("------------------------- ポスグレに接続しました！ -------------------------")

    # 必要なテーブルが存在するかチェックし、なければ作成する
    print("------------------------- テーブルの存在を確認・作成しています -------------------------")
    await db_postgre.check_tables()
    print("------------------------- テーブルの準備が完了しました！ -------------------------")

    # 5. MiniRAGインスタンスを作成
    os.environ["AGE_GRAPH_NAME"] = "my_minirag_graph" # init_db.sh で指定したもの
    rag = MiniRAG(
        working_dir=WORKING_DIR,
        # llm_model_func=hf_model_complete,
        # llm_model_func=gemini_2_5_flash_complete,
        # llm_model_func=ollama_openai_complete,
        llm_model_func=openai_complete,
        llm_model_max_token_size=1000,
        llm_model_name=LLM_MODEL,
        embedding_func=EmbeddingFunc(
            embedding_dim=EMBEDDING_DIM,
            max_token_size=1000,
            func=lambda texts: hf_embed(
                texts,
                tokenizer=tokenizer,
                embed_model=model
            ),
        ),
        kv_storage="PGKVStorage",
        vector_storage="PGVectorStorage",
        graph_storage="PGGraphStorage",
        doc_status_storage="PGDocStatusStorage",
        vector_db_storage_cls_kwargs={
            "cosine_better_than_threshold": float(os.getenv("COSINE_THRESHOLD"))
        }
    )
    # データベースの情報を渡す
    rag.set_storage_client(db_postgre)    
    return rag

# RAGシステムをセットアップ
try:
    rag = await setup_rag_system()
    print("------------------------- MiniRAGが初期化されました！ -------------------------")
except Exception as e:
    print(f"RAGシステムのセットアップに失敗しました: {e}")
# Out:
# PostgreSQL database error: relation "lightrag_doc_full" does not exist
# Failed to check table LIGHTRAG_DOC_FULL in PostgreSQL database
# PostgreSQL database error: relation "lightrag_doc_full" does not exist
# PostgreSQL database error: relation "lightrag_doc_chunks" does not exist
# Failed to check table LIGHTRAG_DOC_CHUNKS in PostgreSQL database
# PostgreSQL database error: relation "lightrag_doc_chunks" does not exist
# PostgreSQL database error: relation "lightrag_vdb_entity" does not exist
# Failed to check table LIGHTRAG_VDB_ENTITY in PostgreSQL database
# PostgreSQL database error: relation "lightrag_vdb_entity" does not exist
# PostgreSQL database error: relation "lightrag_vdb_relation" does not exist
# Failed to check table LIGHTRAG_VDB_RELATION in PostgreSQL database
# PostgreSQL database error: relation "lightrag_vdb_relation" does not exist
# PostgreSQL database error: relation "lightrag_llm_cache" does not exist
# Failed to check table LIGHTRAG_LLM_CACHE in PostgreSQL database
# PostgreSQL database error: relation "lightrag_llm_cache" does not exist
# PostgreSQL database error: relation "lightrag_doc_status" does not exist
# Failed to check table LIGHTRAG_DOC_STATUS in PostgreSQL database
# PostgreSQL database error: relation "lightrag_doc_status" does not exist
# ------------------------- ポスグレに接続しています -------------------------
# ------------------------- ポスグレに接続しました！ -------------------------
# ------------------------- テーブルの存在を確認・作成しています -------------------------
# SELECT 1 FROM LIGHTRAG_DOC_FULL LIMIT 1
# None
# SELECT 1 FROM LIGHTRAG_DOC_CHUNKS LIMIT 1
# None
# SELECT 1 FROM LIGHTRAG_VDB_ENTITY LIMIT 1
# None
# SELECT 1 FROM LIGHTRAG_VDB_RELATION LIMIT 1
# None
# SELECT 1 FROM LIGHTRAG_LLM_CACHE LIMIT 1
# None
# SELECT 1 FROM LIGHTRAG_DOC_STATUS LIMIT 1
# None
# ------------------------- テーブルの準備が完了しました！ -------------------------
# ------------------------- MiniRAGが初期化されました！ -------------------------

# %%
# PostgreSQL database error: relation "lightrag_doc_full" does not exist
# Failed to check table LIGHTRAG_DOC_FULL in PostgreSQL database
# PostgreSQL database error: relation "lightrag_doc_full" does not exist
# PostgreSQL database error: relation "lightrag_doc_chunks" does not exist
# Failed to check table LIGHTRAG_DOC_CHUNKS in PostgreSQL database
# PostgreSQL database error: relation "lightrag_doc_chunks" does not exist
# PostgreSQL database error: relation "lightrag_vdb_entity" does not exist
# Failed to check table LIGHTRAG_VDB_ENTITY in PostgreSQL database
# PostgreSQL database error: relation "lightrag_vdb_entity" does not exist
# PostgreSQL database error: relation "lightrag_vdb_relation" does not exist
# Failed to check table LIGHTRAG_VDB_RELATION in PostgreSQL database
# PostgreSQL database error: relation "lightrag_vdb_relation" does not exist
# PostgreSQL database error: relation "lightrag_llm_cache" does not exist
# Failed to check table LIGHTRAG_LLM_CACHE in PostgreSQL database
# PostgreSQL database error: relation "lightrag_llm_cache" does not exist
# PostgreSQL database error: relation "lightrag_doc_status" does not exist
# Failed to check table LIGHTRAG_DOC_STATUS in PostgreSQL database
# PostgreSQL database error: relation "lightrag_doc_status" does not exist
# ------------------------- ポスグレに接続しています -------------------------
# ------------------------- ポスグレに接続しました！ -------------------------
# ------------------------- テーブルの存在を確認・作成しています -------------------------
# SELECT 1 FROM LIGHTRAG_DOC_FULL LIMIT 1
# None
# SELECT 1 FROM LIGHTRAG_DOC_CHUNKS LIMIT 1
# None
# SELECT 1 FROM LIGHTRAG_VDB_ENTITY LIMIT 1
# None
# SELECT 1 FROM LIGHTRAG_VDB_RELATION LIMIT 1
# None
# SELECT 1 FROM LIGHTRAG_LLM_CACHE LIMIT 1
# None
# SELECT 1 FROM LIGHTRAG_DOC_STATUS LIMIT 1
# None
# ------------------------- テーブルの準備が完了しました！ -------------------------
# ------------------------- MiniRAGが初期化されました！ -------------------------


# 上記の結果になればOK

# %% [markdown]
# ### 構造化ドキュメントのマルチフィールド挿入と検索
#
# 以下の投入しているデータが悪すぎて検索のテストにならないが、雰囲気的にはうまく実装できていそうなので、一旦OKとする

# %%
from datetime import datetime, timezone

workspace = rag.storage_client.workspace

structured_docs = [
    {
        "workspace": "procurement_docs",
        "doc_id": "proc-plan-fy2026-apac",
        "title": "2026年度 APAC地域包括調達戦略・実施計画書（第1版）",
        "summary": "2026年度から2028年度までの中期経営計画に基づき、APAC地域における調達オペレーションの最適化、サプライヤー・レジリエンスの強化、およびコスト構造の改革を定義する包括的文書。",
        "body": ["""# 1. はじめに
本計画書は、地政学的リスクの増大と原材料価格の変動に対応するため、2026年度におけるAPAC地域の調達方針を定めるものである。

# 2. 戦略目標
2026年度の最優先課題は「供給網の安定化」と「持続可能なコスト削減」の両立である。具体的には以下のKPIを設定する。
- 重点カテゴリーにおける複数社購買（Multi-sourcing）率を現状の40%から65%へ引き上げる。
- 地域内調達率（LCR: Local Content Ratio）を平均12%向上させ、物流コストと関税リスクを低減する。
- AIによる需給予測モデルを本格稼働させ、過剰在庫による保管コストを年間で約1.2億円削減する。

# 3. サプライヤーマネジメント
## 3.1 新規サプライヤーの開拓
東南アジア諸国（特にベトナム、タイ、インドネシア）における製造拠点の拡大に伴い、現地の有力サプライヤー50社との戦略的パートナーシップを締結する。
特にインド市場においては、半導体関連部材の現地調達比率を25%まで高めることを目指す。

## 3.2 ESG対応と監査
2026年度より、全ての主要サプライヤー（年間取引額1億円以上）に対し、CO2排出量の四半期報告を義務付ける。
また、人権デューデリジェンスに関する第三者機関による監査を、対象企業の30%で実施する。

# 4. デジタル変革（Procurement DX）
調達プロセスの透明性を高めるため、次世代型E-Procurementシステムを全拠点に導入する。
これにより、発注から支払いまでのリードタイムを20%短縮し、サプライヤー支払いの100%電子化を実現する。

# 5. リスク管理
地政学的リスクに対応するため、特定の1カ国に生産が集中している重要部材（23品目）について、代替生産拠点の確保をQ2（7-9月）までに完了させる。
大規模災害発生時の緊急調達フローを再構築し、初動対応時間を現状の24時間から6時間以内へ短縮する。"""
        ],
        "status": "in_progress",
        "region": "APAC",
        "priority": 1,
        "created_at": datetime(2025, 10, 1, 8, 30, tzinfo=timezone.utc),
        "metadata": {
            "category": "planning_document",
            "region": "APAC",
            "year": 2026,
            "owner_department": "IT Procurement Department",
            "approver": "John Smith",
            "version": "2.1"
        },
    },
    {
        "workspace": "procurement_docs",
        "doc_id": "contract-na-fy2025-qsi",
        "title": "2026年度 次世代ITサービス調達・運用ガイドライン",
        "summary": "グローバル全拠点におけるIT資産、ソフトウェア、クラウドサービスの調達基準とセキュリティ要件。",
        "body": ["""# 1. 目的
本ガイドラインは、グループ全体のITガバナンスを強化し、サイバーセキュリティリスクを低減しつつ、ITコストの最適化を図ることを目的とする。

# 2. クラウドファースト戦略
新規ITシステムの導入に際しては、クラウドネイティブな構成を原則とする。
- 推奨プラットフォーム：AWS (Asia Pacific Regions), Microsoft Azure (Global)
- 調達基準：可用性99.99%以上の保証、およびISO 27017認証の取得が必須。

# 3. ソフトウェア・ライセンス管理
SaaS利用の急増に伴い、シャドーITの撲滅とライセンス費用の重複を排除する。
- 全拠点共通のSaaS管理ツールを導入し、利用率が30%以下のアプリケーションについては契約更新を行わない。
- オープンソースソフトウェア（OSS）の利用に関しては、法務部およびセキュリティ部門の承認が必要。

# 4. セキュリティ要件（サプライチェーンセキュリティ）
ITサービス提供ベンダーに対しては、以下のセキュリティ基準への準拠を求める。
1. SOC2 Type2レポートの定期的な提出。
2. ゼロトラストアーキテクチャに基づいたアクセス制御の実装。
3. 脆弱性診断を年2回以上実施し、その結果を報告すること。

# 5. ハードウェア調達と循環経済
PC、サーバー、ネットワーク機器の調達において、環境負荷を最小限に抑える。
- 廃棄されるハードウェアの80%以上をリサイクルまたはリユースする「IT資産循環プログラム」をQ3より開始する。
- 消費電力効率が前世代比で15%以上向上しているモデルを優先的に選定する。"""
        ],
        "status": "finalized",
        "region": "NA",
        "priority": 1,
        "created_at": datetime(2025, 10, 2, 9, 15, tzinfo=timezone.utc),
        "metadata": {
            "category": "contract",
            "region": "NA",
            "year": 2025,
            "owner_department": "Legal & Supply Chain Management",
            "supplier_name": "Quantum Systems Inc.",
            "contract_value_usd": 12000000
        },
    },
]

schema = {
    "table": "public.customer_orders",
    "id_column": "doc_id",
    "fields": {
        "workspace": {"type": "text", "nullable": False},
        "doc_id": {"type": "text", "nullable": False},
        "title": {"type": "text"},
        "summary": {"type": "text"},
        "body": {"type": "text"},
        "status": {"type": "text"},
        "region": {"type": "text"},
        "priority": {"type": "integer"},
        "created_at": {"type": "timestamp"},
    },
    "conflict_columns": ["workspace", "doc_id"],
}

await rag.ainsert(structured_docs, schema=schema, text_fields=["title", "summary", "body"])
print(f"構造化ドキュメントを {len(structured_docs)} 件登録しました (workspace={workspace}).")
# Out:
# 🚀 AINSERT called with overwrite=False
# 📥 Input: 2 documents
# 📥 IDs: ['proc-plan-fy2026-apac', 'contract-na-fy2025-qsi']
# 📥 Metadatas: [{'category': 'planning_document', 'region': 'APAC', 'year': 2026, 'owner_department': 'IT Procurement Department', 'approver': 'John Smith', 'version': '2.1', 'workspace': 'procurement_docs', 'title': '2026年度 APAC地域包括調達戦略・実施計画書（第1版）', 'summary': '2026年度から2028年度までの中期経営計画に基づき、APAC地域における調達オペレーションの最適化、サプライヤー・レジリエンスの強化、およびコスト構造の改革を定義する包括的文書。', 'body': '# 1. はじめに\n本計画書は、地政学的リスクの増大と原材料価格の変動に対応するため、2026年度におけるAPAC地域の調達方針を定めるものである。\n\n# 2. 戦略目標\n2026年度の最優先課題は「供給網の安定化」と「持続可能なコスト削減」の両立である。具体的には以下のKPIを設定する。\n- 重点カテゴリーにおける複数社購買（Multi-sourcing）率を現状の40%から65%へ引き上げる。\n- 地域内調達率（LCR: Local Content Ratio）を平均12%向上させ、物流コストと関税リスクを低減する。\n- AIによる需給予測モデルを本格稼働させ、過剰在庫による保管コストを年間で約1.2億円削減する。\n\n# 3. サプライヤーマネジメント\n## 3.1 新規サプライヤーの開拓\n東南アジア諸国（特にベトナム、タイ、インドネシア）における製造拠点の拡大に伴い、現地の有力サプライヤー50社との戦略的パートナーシップを締結する。\n特にインド市場においては、半導体関連部材の現地調達比率を25%まで高めることを目指す。\n\n## 3.2 ESG対応と監査\n2026年度より、全ての主要サプライヤー（年間取引額1億円以上）に対し、CO2排出量の四半期報告を義務付ける。\nまた、人権デューデリジェンスに関する第三者機関による監査を、対象企業の30%で実施する。\n\n# 4. デジタル変革（Procurement DX）\n調達プロセスの透明性を高めるため、次世代型E-Procurementシステムを全拠点に導入する。\nこれにより、発注から支払いまでのリードタイムを20%短縮し、サプライヤー支払いの100%電子化を実現する。\n\n# 5. リスク管理\n地政学的リスクに対応するため、特定の1カ国に生産が集中している重要部材（23品目）について、代替生産拠点の確保をQ2（7-9月）までに完了させる。\n大規模災害発生時の緊急調達フローを再構築し、初動対応時間を現状の24時間から6時間以内へ短縮する。', 'status': 'in_progress', 'priority': 1, 'created_at': datetime.datetime(2025, 10, 1, 8, 30, tzinfo=datetime.timezone.utc), '_original_data': {'workspace': 'procurement_docs', 'doc_id': 'proc-plan-fy2026-apac', 'title': '2026年度 APAC地域包括調達戦略・実施計画書（第1版）', 'summary': '2026年度から2028年度までの中期経営計画に基づき、APAC地域における調達オペレーションの最適化、サプライヤー・レジリエンスの強化、およびコスト構造の改革を定義する包括的文書。', 'body': ['# 1. はじめに\n本計画書は、地政学的リスクの増大と原材料価格の変動に対応するため、2026年度におけるAPAC地域の調達方針を定めるものである。\n\n# 2. 戦略目標\n2026年度の最優先課題は「供給網の安定化」と「持続可能なコスト削減」の両立である。具体的には以下のKPIを設定する。\n- 重点カテゴリーにおける複数社購買（Multi-sourcing）率を現状の40%から65%へ引き上げる。\n- 地域内調達率（LCR: Local Content Ratio）を平均12%向上させ、物流コストと関税リスクを低減する。\n- AIによる需給予測モデルを本格稼働させ、過剰在庫による保管コストを年間で約1.2億円削減する。\n\n# 3. サプライヤーマネジメント\n## 3.1 新規サプライヤーの開拓\n東南アジア諸国（特にベトナム、タイ、インドネシア）における製造拠点の拡大に伴い、現地の有力サプライヤー50社との戦略的パートナーシップを締結する。\n特にインド市場においては、半導体関連部材の現地調達比率を25%まで高めることを目指す。\n\n## 3.2 ESG対応と監査\n2026年度より、全ての主要サプライヤー（年間取引額1億円以上）に対し、CO2排出量の四半期報告を義務付ける。\nまた、人権デューデリジェンスに関する第三者機関による監査を、対象企業の30%で実施する。\n\n# 4. デジタル変革（Procurement DX）\n調達プロセスの透明性を高めるため、次世代型E-Procurementシステムを全拠点に導入する。\nこれにより、発注から支払いまでのリードタイムを20%短縮し、サプライヤー支払いの100%電子化を実現する。\n\n# 5. リスク管理\n地政学的リスクに対応するため、特定の1カ国に生産が集中している重要部材（23品目）について、代替生産拠点の確保をQ2（7-9月）までに完了させる。\n大規模災害発生時の緊急調達フローを再構築し、初動対応時間を現状の24時間から6時間以内へ短縮する。'], 'status': 'in_progress', 'region': 'APAC', 'priority': 1, 'created_at': datetime.datetime(2025, 10, 1, 8, 30, tzinfo=datetime.timezone.utc), 'metadata': {'category': 'planning_document', 'region': 'APAC', 'year': 2026, 'owner_department': 'IT Procurement Department', 'approver': 'John Smith', 'version': '2.1'}}}, {'category': 'contract', 'region': 'NA', 'year': 2025, 'owner_department': 'Legal & Supply Chain Management', 'supplier_name': 'Quantum Systems Inc.', 'contract_value_usd': 12000000, 'workspace': 'procurement_docs', 'title': '2026年度 次世代ITサービス調達・運用ガイドライン', 'summary': 'グローバル全拠点におけるIT資産、ソフトウェア、クラウドサービスの調達基準とセキュリティ要件。', 'body': '# 1. 目的\n本ガイドラインは、グループ全体のITガバナンスを強化し、サイバーセキュリティリスクを低減しつつ、ITコストの最適化を図ることを目的とする。\n\n# 2. クラウドファースト戦略\n新規ITシステムの導入に際しては、クラウドネイティブな構成を原則とする。\n- 推奨プラットフォーム：AWS (Asia Pacific Regions), Microsoft Azure (Global)\n- 調達基準：可用性99.99%以上の保証、およびISO 27017認証の取得が必須。\n\n# 3. ソフトウェア・ライセンス管理\nSaaS利用の急増に伴い、シャドーITの撲滅とライセンス費用の重複を排除する。\n- 全拠点共通のSaaS管理ツールを導入し、利用率が30%以下のアプリケーションについては契約更新を行わない。\n- オープンソースソフトウェア（OSS）の利用に関しては、法務部およびセキュリティ部門の承認が必要。\n\n# 4. セキュリティ要件（サプライチェーンセキュリティ）\nITサービス提供ベンダーに対しては、以下のセキュリティ基準への準拠を求める。\n1. SOC2 Type2レポートの定期的な提出。\n2. ゼロトラストアーキテクチャに基づいたアクセス制御の実装。\n3. 脆弱性診断を年2回以上実施し、その結果を報告すること。\n\n# 5. ハードウェア調達と循環経済\nPC、サーバー、ネットワーク機器の調達において、環境負荷を最小限に抑える。\n- 廃棄されるハードウェアの80%以上をリサイクルまたはリユースする「IT資産循環プログラム」をQ3より開始する。\n- 消費電力効率が前世代比で15%以上向上しているモデルを優先的に選定する。', 'status': 'finalized', 'priority': 1, 'created_at': datetime.datetime(2025, 10, 2, 9, 15, tzinfo=datetime.timez ...
# 📝 Storing doc 'contract-na-fy2025-qsi' with metadata: {'category': 'contract', 'region': 'NA', 'year': 2025, 'owner_department': 'Legal & Supply Chain Management', 'supplier_name': 'Quantum Systems Inc.', 'contract_value_usd': 12000000, 'workspace': 'procurement_docs', 'title': '2026年度 次世代ITサービス調達・運用ガイドライン', 'summary': 'グローバル全拠点におけるIT資産、ソフトウェア、クラウドサービスの調達基準とセキュリティ要件。', 'body': '# 1. 目的\n本ガイドラインは、グループ全体のITガバナンスを強化し、サイバーセキュリティリスクを低減しつつ、ITコストの最適化を図ることを目的とする。\n\n# 2. クラウドファースト戦略\n新規ITシステムの導入に際しては、クラウドネイティブな構成を原則とする。\n- 推奨プラットフォーム：AWS (Asia Pacific Regions), Microsoft Azure (Global)\n- 調達基準：可用性99.99%以上の保証、およびISO 27017認証の取得が必須。\n\n# 3. ソフトウェア・ライセンス管理\nSaaS利用の急増に伴い、シャドーITの撲滅とライセンス費用の重複を排除する。\n- 全拠点共通のSaaS管理ツールを導入し、利用率が30%以下のアプリケーションについては契約更新を行わない。\n- オープンソースソフトウェア（OSS）の利用に関しては、法務部およびセキュリティ部門の承認が必要。\n\n# 4. セキュリティ要件（サプライチェーンセキュリティ）\nITサービス提供ベンダーに対しては、以下のセキュリティ基準への準拠を求める。\n1. SOC2 Type2レポートの定期的な提出。\n2. ゼロトラストアーキテクチャに基づいたアクセス制御の実装。\n3. 脆弱性診断を年2回以上実施し、その結果を報告すること。\n\n# 5. ハードウェア調達と循環経済\nPC、サーバー、ネットワーク機器の調達において、環境負荷を最小限に抑える。\n- 廃棄されるハードウェアの80%以上をリサイクルまたはリユースする「IT資産循環プログラム」をQ3より開始する。\n- 消費電力効率が前世代比で15%以上向上しているモデルを優先的に選定する。', 'status': 'finalized', 'priority': 1, 'created_at': datetime.datetime(2025, 10, 2, 9, 15, tzinfo=datetime.timezone.utc), '_original_data': {'workspace': 'procurement_docs', 'doc_id': 'contract-na-fy2025-qsi', 'title': '2026年度 次世代ITサービス調達・運用ガイドライン', 'summary': 'グローバル全拠点におけるIT資産、ソフトウェア、クラウドサービスの調達基準とセキュリティ要件。', 'body': ['# 1. 目的\n本ガイドラインは、グループ全体のITガバナンスを強化し、サイバーセキュリティリスクを低減しつつ、ITコストの最適化を図ることを目的とする。\n\n# 2. クラウドファースト戦略\n新規ITシステムの導入に際しては、クラウドネイティブな構成を原則とする。\n- 推奨プラットフォーム：AWS (Asia Pacific Regions), Microsoft Azure (Global)\n- 調達基準：可用性99.99%以上の保証、およびISO 27017認証の取得が必須。\n\n# 3. ソフトウェア・ライセンス管理\nSaaS利用の急増に伴い、シャドーITの撲滅とライセンス費用の重複を排除する。\n- 全拠点共通のSaaS管理ツールを導入し、利用率が30%以下のアプリケーションについては契約更新を行わない。\n- オープンソースソフトウェア（OSS）の利用に関しては、法務部およびセキュリティ部門の承認が必要。\n\n# 4. セキュリティ要件（サプライチェーンセキュリティ）\nITサービス提供ベンダーに対しては、以下のセキュリティ基準への準拠を求める。\n1. SOC2 Type2レポートの定期的な提出。\n2. ゼロトラストアーキテクチャに基づいたアクセス制御の実装。\n3. 脆弱性診断を年2回以上実施し、その結果を報告すること。\n\n# 5. ハードウェア調達と循環経済\nPC、サーバー、ネットワーク機器の調達において、環境負荷を最小限に抑える。\n- 廃棄されるハードウェアの80%以上をリサイクルまたはリユースする「IT資産循環プログラム」をQ3より開始する。\n- 消費電力効率が前世代比で15%以上向上しているモデルを優先的に選定する。'], 'status': 'finalized', 'region': 'NA', 'priority': 1, 'created_at': datetime.datetime(2025, 10, 2, 9, 15, tzinfo=datetime.timezone.utc), 'metadata': {'category': 'contract', 'region': 'NA', 'year': 2025, 'owner_department': 'Legal & Supply Chain Management', 'supplier_name': 'Quantum Systems Inc.', 'contract_value_usd': 12000000}}}
# 📝 Storing doc 'proc-plan-fy2026-apac' with metadata: {'category': 'planning_document', 'region': 'APAC', 'year': 2026, 'owner_department': 'IT Procurement Department', 'approver': 'John Smith', 'version': '2.1', 'workspace': 'procurement_docs', 'title': '2026年度 APAC地域包括調達戦略・実施計画書（第1版）', 'summary': '2026年度から2028年度までの中期経営計画に基づき、APAC地域における調達オペレーションの最適化、サプライヤー・レジリエンスの強化、およびコスト構造の改革を定義する包括的文書。', 'body': '# 1. はじめに\n本計画書は、地政学的リスクの増大と原材料価格の変動に対応するため、2026年度におけるAPAC地域の調達方針を定めるものである。\n\n# 2. 戦略目標\n2026年度の最優先課題は「供給網の安定化」と「持続可能なコスト削減」の両立である。具体的には以下のKPIを設定する。\n- 重点カテゴリーにおける複数社購買（Multi-sourcing）率を現状の40%から65%へ引き上げる。\n- 地域内調達率（LCR: Local Content Ratio）を平均12%向上させ、物流コストと関税リスクを低減する。\n- AIによる需給予測モデルを本格稼働させ、過剰在庫による保管コストを年間で約1.2億円削減する。\n\n# 3. サプライヤーマネジメント\n## 3.1 新規サプライヤーの開拓\n東南アジア諸国（特にベトナム、タイ、インドネシア）における製造拠点の拡大に伴い、現地の有力サプライヤー50社との戦略的パートナーシップを締結する。\n特にインド市場においては、半導体関連部材の現地調達比率を25%まで高めることを目指す。\n\n## 3.2 ESG対応と監査\n2026年度より、全ての主要サプライヤー（年間取引額1億円以上）に対し、CO2排出量の四半期報告を義務付ける。\nまた、人権デューデリジェンスに関する第三者機関による監査を、対象企業の30%で実施する。\n\n# 4. デジタル変革（Procurement DX）\n調達プロセスの透明性を高めるため、次世代型E-Procurementシステムを全拠点に導入する。\nこれにより、発注から支払いまでのリードタイムを20%短縮し、サプライヤー支払いの100%電子化を実現する。\n\n# 5. リスク管理\n地政学的リスクに対応するため、特定の1カ国に生産が集中している重要部材（23品目）について、代替生産拠点の確保をQ2（7-9月）までに完了させる。\n大規模災害発生時の緊急調達フローを再構築し、初動対応時間を現状の24時間から6時間以内へ短縮する。', 'status': 'in_progress', 'priority': 1, 'created_at': datetime.datetime(2025, 10, 1, 8, 30, tzinfo=datetime.timezone.utc), '_original_data': {'workspace': 'procurement_docs', 'doc_id': 'proc-plan-fy2026-apac', 'title': '2026年度 APAC地域包括調達戦略・実施計画書（第1版）', 'summary': '2026年度から2028年度までの中期経営計画に基づき、APAC地域における調達オペレーションの最適化、サプライヤー・レジリエンスの強化、およびコスト構造の改革を定義する包括的文書。', 'body': ['# 1. はじめに\n本計画書は、地政学的リスクの増大と原材料価格の変動に対応するため、2026年度におけるAPAC地域の調達方針を定めるものである。\n\n# 2. 戦略目標\n2026年度の最優先課題は「供給網の安定化」と「持続可能なコスト削減」の両立である。具体的には以下のKPIを設定する。\n- 重点カテゴリーにおける複数社購買（Multi-sourcing）率を現状の40%から65%へ引き上げる。\n- 地域内調達率（LCR: Local Content Ratio）を平均12%向上させ、物流コストと関税リスクを低減する。\n- AIによる需給予測モデルを本格稼働させ、過剰在庫による保管コストを年間で約1.2億円削減する。\n\n# 3. サプライヤーマネジメント\n## 3.1 新規サプライヤーの開拓\n東南アジア諸国（特にベトナム、タイ、インドネシア）における製造拠点の拡大に伴い、現地の有力サプライヤー50社との戦略的パートナーシップを締結する。\n特にインド市場においては、半導体関連部材の現地調達比率を25%まで高めることを目指す。\n\n## 3.2 ESG対応と監査\n2026年度より、全ての主要サプライヤー（年間取引額1億円以上）に対し、CO2排出量の四半期報告を義務付ける。\nまた、人権デューデリジェンスに関する第三者機関による監査を、対象企業の30%で実施する。\n\n# 4. デジタル変革（Procurement DX）\n調達プロセスの透明性を高めるため、次世代型E-Procurementシステムを全拠点に導入する。\nこれにより、発注から支払いまでのリードタイムを20%短縮し、サプライヤー支払いの100%電子化を実現する。\n\n# 5. リスク管理\n地政学的リスクに対応するため、特定の1カ国に生産が集中している重要部材（23品目）について、代替生産拠点の確保をQ2（7-9月）までに完了させる。\n大規模災害発生時の緊急調達フローを再構築し、初動対応時間を現状の24時間から6時間以内へ短縮する。'], 'status': 'in_progress', 'region': 'APAC', 'priority': 1, 'created_at': datetime.datetime(2025, 10, 1, 8, 30, tzinfo=datetime.timezone.utc), 'metadata': {'category': 'planning_document', 'region': 'APAC', 'year': 2026, 'owner_department': 'IT Procurement Department', 'approver': 'John Smith', 'version': '2.1'}}}
# ⚙️  Processing doc 'contract-na-fy2025-qsi', status_doc.metadata = {"body": "# 1. 目的\n本ガイドラインは、グループ全体のITガバナンスを強化し、サイバーセキュリティリスクを低減しつつ、ITコストの最適化を図ることを目的とする。\n\n# 2. クラウドファースト戦略\n新規ITシステムの導入に際しては、クラウドネイティブな構成を原則とする。\n- 推奨プラットフォーム：AWS (Asia Pacific Regions), Microsoft Azure (Global)\n- 調達基準：可用性99.99%以上の保証、およびISO 27017認証の取得が必須。\n\n# 3. ソフトウェア・ライセンス管理\nSaaS利用の急増に伴い、シャドーITの撲滅とライセンス費用の重複を排除する。\n- 全拠点共通のSaaS管理ツールを導入し、利用率が30%以下のアプリケーションについては契約更新を行わない。\n- オープンソースソフトウェア（OSS）の利用に関しては、法務部およびセキュリティ部門の承認が必要。\n\n# 4. セキュリティ要件（サプライチェーンセキュリティ）\nITサービス提供ベンダーに対しては、以下のセキュリティ基準への準拠を求める。\n1. SOC2 Type2レポートの定期的な提出。\n2. ゼロトラストアーキテクチャに基づいたアクセス制御の実装。\n3. 脆弱性診断を年2回以上実施し、その結果を報告すること。\n\n# 5. ハードウェア調達と循環経済\nPC、サーバー、ネットワーク機器の調達において、環境負荷を最小限に抑える。\n- 廃棄されるハードウェアの80%以上をリサイクルまたはリユースする「IT資産循環プログラム」をQ3より開始する。\n- 消費電力効率が前世代比で15%以上向上しているモデルを優先的に選定する。", "year": 2025, "title": "2026年度 次世代ITサービス調達・運用ガイドライン", "region": "NA", "status": "finalized", "summary": "グローバル全拠点におけるIT資産、ソフトウェア、クラウドサービスの調達基準とセキュリティ要件。", "category": "contract", "priority": 1, "workspace": "procurement_docs", "created_at": "2025-10-02T09:15:00+00:00", "supplier_name": "Quantum Systems Inc.", "_original_data": {"body": ["# 1. 目的\n本ガイドラインは、グループ全体のITガバナンスを強化し、サイバーセキュリティリスクを低減しつつ、ITコストの最適化を図ることを目的とする。\n\n# 2. クラウドファースト戦略\n新規ITシステムの導入に際しては、クラウドネイティブな構成を原則とする。\n- 推奨プラットフォーム：AWS (Asia Pacific Regions), Microsoft Azure (Global)\n- 調達基準：可用性99.99%以上の保証、およびISO 27017認証の取得が必須。\n\n# 3. ソフトウェア・ライセンス管理\nSaaS利用の急増に伴い、シャドーITの撲滅とライセンス費用の重複を排除する。\n- 全拠点共通のSaaS管理ツールを導入し、利用率が30%以下のアプリケーションについては契約更新を行わない。\n- オープンソースソフトウェア（OSS）の利用に関しては、法務部およびセキュリティ部門の承認が必要。\n\n# 4. セキュリティ要件（サプライチェーンセキュリティ）\nITサービス提供ベンダーに対しては、以下のセキュリティ基準への準拠を求める。\n1. SOC2 Type2レポートの定期的な提出。\n2. ゼロトラストアーキテクチャに基づいたアクセス制御の実装。\n3. 脆弱性診断を年2回以上実施し、その結果を報告すること。\n\n# 5. ハードウェア調達と循環経済\nPC、サーバー、ネットワーク機器の調達において、環境負荷を最小限に抑える。\n- 廃棄されるハードウェアの80%以上をリサイクルまたはリユースする「IT資産循環プログラム」をQ3より開始する。\n- 消費電力効率が前世代比で15%以上向上しているモデルを優先的に選定する。"], "title": "2026年度 次世代ITサービス調達・運用ガイドライン", "doc_id": "contract-na-fy2025-qsi", "region": "NA", "status": "finalized", "summary": "グローバル全拠点におけるIT資産、ソフトウェア、クラウドサービスの調達基準とセキュリティ要件。", "metadata": {"year": 2025, "region": "NA", "category": "contract", "supplier_name": "Quantum Systems Inc.", "owner_department": "Legal & Supply Chain Management", "contract_value_usd": 12000000}, "priority": 1, "workspace": "procurement_docs", "created_at": "2025-10-02T09:15:00+00:00"}, "owner_department": "Legal & Supply Chain Management", "contract_value_usd": 12000000}
# 📦 Created 8 field-split chunks for doc 'contract-na-fy2025-qsi' (fields: ['body', 'title', 'region', 'status', 'summary', 'workspace', 'created_at'])
#    └─ Chunk 'chunk-body-00424...' text_field: body, metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000, 'priority': 1, 'text_field': 'body'}
#    └─ Chunk 'chunk-title-e215...' text_field: title, metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000, 'priority': 1, 'text_field': 'title'}
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00,  4.26batch/s]
# 💾 Upserting chunk 'chunk-body-00424...' with metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000, 'priority': 1, 'text_field': 'body'}
# 💾 Upserting chunk 'chunk-title-e215...' with metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000, 'priority': 1, 'text_field': 'title'}
# 💾 Upserting chunk 'chunk-region-b28...' with metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000, 'priority': 1, 'text_field': 'region'}
# 💾 Upserting chunk 'chunk-status-03b...' with metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000, 'priority': 1, 'text_field': 'status'}
# 💾 Upserting chunk 'chunk-summary-bc...' with metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000, 'priority': 1, 'text_field': 'summary'}
# 💾 Upserting chunk 'chunk-workspace-...' with metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000, 'priority': 1, 'text_field': 'workspace'}
# 💾 Upserting chunk 'chunk-created_at...' with metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000, 'priority': 1, 'text_field': 'created_at'}
# 💾 Upserting chunk 'chunk-all-d46b86...' with metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000, 'priority': 1, 'text_field': '_all'}
# ⠇ Processed 8 chunks, 41 entities(duplicated), 44 relations(duplicated)
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# Key value duplicate, but upsert succeeded.
# Key value duplicate, but upsert succeeded.
# Key value duplicate, but upsert succeeded.
# Key value duplicate, but upsert succeeded.
# Key value duplicate, but upsert succeeded.
# Key value duplicate, but upsert succeeded.
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# Key value duplicate, but upsert succeeded.
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# Key value duplicate, but upsert succeeded.
# Key value duplicate, but upsert succeeded.
# Key value duplicate, but upsert succeeded.
# Key value duplicate, but upsert succeeded.
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# Key value duplicate, but upsert succeeded.
# Key value duplicate, but upsert succeeded.
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00,  6.12batch/s]
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00,  6.00batch/s]
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 16.25batch/s]
# Generating embeddings: 100%|██████████| 2/2 [00:00<00:00,  9.71batch/s]
# ⚙️  Processing doc 'proc-plan-fy2026-apac', status_doc.metadata = {"body": "# 1. はじめに\n本計画書は、地政学的リスクの増大と原材料価格の変動に対応するため、2026年度におけるAPAC地域の調達方針を定めるものである。\n\n# 2. 戦略目標\n2026年度の最優先課題は「供給網の安定化」と「持続可能なコスト削減」の両立である。具体的には以下のKPIを設定する。\n- 重点カテゴリーにおける複数社購買（Multi-sourcing）率を現状の40%から65%へ引き上げる。\n- 地域内調達率（LCR: Local Content Ratio）を平均12%向上させ、物流コストと関税リスクを低減する。\n- AIによる需給予測モデルを本格稼働させ、過剰在庫による保管コストを年間で約1.2億円削減する。\n\n# 3. サプライヤーマネジメント\n## 3.1 新規サプライヤーの開拓\n東南アジア諸国（特にベトナム、タイ、インドネシア）における製造拠点の拡大に伴い、現地の有力サプライヤー50社との戦略的パートナーシップを締結する。\n特にインド市場においては、半導体関連部材の現地調達比率を25%まで高めることを目指す。\n\n## 3.2 ESG対応と監査\n2026年度より、全ての主要サプライヤー（年間取引額1億円以上）に対し、CO2排出量の四半期報告を義務付ける。\nまた、人権デューデリジェンスに関する第三者機関による監査を、対象企業の30%で実施する。\n\n# 4. デジタル変革（Procurement DX）\n調達プロセスの透明性を高めるため、次世代型E-Procurementシステムを全拠点に導入する。\nこれにより、発注から支払いまでのリードタイムを20%短縮し、サプライヤー支払いの100%電子化を実現する。\n\n# 5. リスク管理\n地政学的リスクに対応するため、特定の1カ国に生産が集中している重要部材（23品目）について、代替生産拠点の確保をQ2（7-9月）までに完了させる。\n大規模災害発生時の緊急調達フローを再構築し、初動対応時間を現状の24時間から6時間以内へ短縮する。", "year": 2026, "title": "2026年度 APAC地域包括調達戦略・実施計画書（第1版）", "region": "APAC", "status": "in_progress", "summary": "2026年度から2028年度までの中期経営計画に基づき、APAC地域における調達オペレーションの最適化、サプライヤー・レジリエンスの強化、およびコスト構造の改革を定義する包括的文書。", "version": "2.1", "approver": "John Smith", "category": "planning_document", "priority": 1, "workspace": "procurement_docs", "created_at": "2025-10-01T08:30:00+00:00", "_original_data": {"body": ["# 1. はじめに\n本計画書は、地政学的リスクの増大と原材料価格の変動に対応するため、2026年度におけるAPAC地域の調達方針を定めるものである。\n\n# 2. 戦略目標\n2026年度の最優先課題は「供給網の安定化」と「持続可能なコスト削減」の両立である。具体的には以下のKPIを設定する。\n- 重点カテゴリーにおける複数社購買（Multi-sourcing）率を現状の40%から65%へ引き上げる。\n- 地域内調達率（LCR: Local Content Ratio）を平均12%向上させ、物流コストと関税リスクを低減する。\n- AIによる需給予測モデルを本格稼働させ、過剰在庫による保管コストを年間で約1.2億円削減する。\n\n# 3. サプライヤーマネジメント\n## 3.1 新規サプライヤーの開拓\n東南アジア諸国（特にベトナム、タイ、インドネシア）における製造拠点の拡大に伴い、現地の有力サプライヤー50社との戦略的パートナーシップを締結する。\n特にインド市場においては、半導体関連部材の現地調達比率を25%まで高めることを目指す。\n\n## 3.2 ESG対応と監査\n2026年度より、全ての主要サプライヤー（年間取引額1億円以上）に対し、CO2排出量の四半期報告を義務付ける。\nまた、人権デューデリジェンスに関する第三者機関による監査を、対象企業の30%で実施する。\n\n# 4. デジタル変革（Procurement DX）\n調達プロセスの透明性を高めるため、次世代型E-Procurementシステムを全拠点に導入する。\nこれにより、発注から支払いまでのリードタイムを20%短縮し、サプライヤー支払いの100%電子化を実現する。\n\n# 5. リスク管理\n地政学的リスクに対応するため、特定の1カ国に生産が集中している重要部材（23品目）について、代替生産拠点の確保をQ2（7-9月）までに完了させる。\n大規模災害発生時の緊急調達フローを再構築し、初動対応時間を現状の24時間から6時間以内へ短縮する。"], "title": "2026年度 APAC地域包括調達戦略・実施計画書（第1版）", "doc_id": "proc-plan-fy2026-apac", "region": "APAC", "status": "in_progress", "summary": "2026年度から2028年度までの中期経営計画に基づき、APAC地域における調達オペレーションの最適化、サプライヤー・レジリエンスの強化、およびコスト構造の改革を定義する包括的文書。", "metadata": {"year": 2026, "region": "APAC", "version": "2.1", "approver": "John Smith", "category": "planning_document", "owner_department": "IT Procurement Department"}, "priority": 1, "workspace": "procurement_docs", "created_at": "2025-10-01T08:30:00+00:00"}, "owner_department": "IT Procurement Department"}
# 📦 Created 8 field-split chunks for doc 'proc-plan-fy2026-apac' (fields: ['body', 'title', 'region', 'status', 'summary', 'workspace', 'created_at'])
#    └─ Chunk 'chunk-body-af651...' text_field: body, metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'owner_department': 'IT Procurement Department', 'priority': 1, 'text_field': 'body'}
#    └─ Chunk 'chunk-title-171b...' text_field: title, metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'owner_department': 'IT Procurement Department', 'priority': 1, 'text_field': 'title'}
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00,  4.27batch/s]
# 💾 Upserting chunk 'chunk-body-af651...' with metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'owner_department': 'IT Procurement Department', 'priority': 1, 'text_field': 'body'}
# 💾 Upserting chunk 'chunk-title-171b...' with metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'owner_department': 'IT Procurement Department', 'priority': 1, 'text_field': 'title'}
# 💾 Upserting chunk 'chunk-region-724...' with metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'owner_department': 'IT Procurement Department', 'priority': 1, 'text_field': 'region'}
# 💾 Upserting chunk 'chunk-status-138...' with metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'owner_department': 'IT Procurement Department', 'priority': 1, 'text_field': 'status'}
# 💾 Upserting chunk 'chunk-summary-6e...' with metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'owner_department': 'IT Procurement Department', 'priority': 1, 'text_field': 'summary'}
# 💾 Upserting chunk 'chunk-workspace-...' with metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'owner_department': 'IT Procurement Department', 'priority': 1, 'text_field': 'workspace'}
# 💾 Upserting chunk 'chunk-created_at...' with metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'owner_department': 'IT Procurement Department', 'priority': 1, 'text_field': 'created_at'}
# 💾 Upserting chunk 'chunk-all-2bcdca...' with metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'owner_department': 'IT Procurement Department', 'priority': 1, 'text_field': '_all'}
# ⠇ Processed 8 chunks, 56 entities(duplicated), 59 relations(duplicated)
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# Generating embeddings: 100%|██████████| 2/2 [00:00<00:00,  8.14batch/s]
# Generating embeddings: 100%|██████████| 2/2 [00:00<00:00,  7.65batch/s]
# Generating embeddings: 100%|██████████| 2/2 [00:00<00:00, 20.37batch/s]
# Generating embeddings: 100%|██████████| 2/2 [00:00<00:00,  9.58batch/s]
# KG successfully indexed.
# 構造化ドキュメントを 2 件登録しました (workspace=default).

# %%
import json

doc_ids = [doc["doc_id"] for doc in structured_docs]
chunk_rows = await rag.storage_client.query(
    """
    SELECT full_doc_id,
           metadata,
           metadata->>'text_field' AS text_field,
           content,
           chunk_order_index
    FROM LIGHTRAG_DOC_CHUNKS
    WHERE workspace=$1
      AND full_doc_id = ANY($2::text[])
    ORDER BY full_doc_id, chunk_order_index
    """,
    params={"workspace": workspace, "doc_ids": doc_ids},
    multirows=True,
)

print(f"取得チャンク数: {len(chunk_rows)}")
for row in chunk_rows:
    head = row["content"].split("\n")[0][:60]
    metadata_json = json.dumps(row["metadata"], ensure_ascii=False)
    print(f"- {row['full_doc_id']} | text_field={row['text_field']} | chunk_order={row['chunk_order_index']}\n  preview: {head}\n  metadata: {metadata_json}")
# Out:
# 取得チャンク数: 16
# - contract-na-fy2025-qsi | text_field=workspace | chunk_order=0
#   preview: procurement_docs
#   metadata: "{\"year\": 2025, \"region\": \"NA\", \"category\": \"contract\", \"priority\": 1, \"text_field\": \"workspace\", \"supplier_name\": \"Quantum Systems Inc.\", \"owner_department\": \"Legal & Supply Chain Management\", \"contract_value_usd\": 12000000}"
# - contract-na-fy2025-qsi | text_field=_all | chunk_order=0
#   preview: # 1. 目的
#   metadata: "{\"year\": 2025, \"region\": \"NA\", \"category\": \"contract\", \"priority\": 1, \"text_field\": \"_all\", \"supplier_name\": \"Quantum Systems Inc.\", \"owner_department\": \"Legal & Supply Chain Management\", \"contract_value_usd\": 12000000}"
# - contract-na-fy2025-qsi | text_field=body | chunk_order=0
#   preview: # 1. 目的
#   metadata: "{\"year\": 2025, \"region\": \"NA\", \"category\": \"contract\", \"priority\": 1, \"text_field\": \"body\", \"supplier_name\": \"Quantum Systems Inc.\", \"owner_department\": \"Legal & Supply Chain Management\", \"contract_value_usd\": 12000000}"
# - contract-na-fy2025-qsi | text_field=created_at | chunk_order=0
#   preview: 2025-10-02T09:15:00+00:00
#   metadata: "{\"year\": 2025, \"region\": \"NA\", \"category\": \"contract\", \"priority\": 1, \"text_field\": \"created_at\", \"supplier_name\": \"Quantum Systems Inc.\", \"owner_department\": \"Legal & Supply Chain Management\", \"contract_value_usd\": 12000000}"
# - contract-na-fy2025-qsi | text_field=region | chunk_order=0
#   preview: NA
#   metadata: "{\"year\": 2025, \"region\": \"NA\", \"category\": \"contract\", \"priority\": 1, \"text_field\": \"region\", \"supplier_name\": \"Quantum Systems Inc.\", \"owner_department\": \"Legal & Supply Chain Management\", \"contract_value_usd\": 12000000}"
# - contract-na-fy2025-qsi | text_field=status | chunk_order=0
#   preview: finalized
#   metadata: "{\"year\": 2025, \"region\": \"NA\", \"category\": \"contract\", \"priority\": 1, \"text_field\": \"status\", \"supplier_name\": \"Quantum Systems Inc.\", \"owner_department\": \"Legal & Supply Chain Management\", \"contract_value_usd\": 12000000}"
# - contract-na-fy2025-qsi | text_field=summary | chunk_order=0
#   preview: グローバル全拠点におけるIT資産、ソフトウェア、クラウドサービスの調達基準とセキュリティ要件。
#   metadata: "{\"year\": 2025, \"region\": \"NA\", \"category\": \"contract\", \"priority\": 1, \"text_field\": \"summary\", \"supplier_name\": \"Quantum Systems Inc.\", \"owner_department\": \"Legal & Supply Chain Management\", \"contract_value_usd\": 12000000}"
# - contract-na-fy2025-qsi | text_field=title | chunk_order=0
#   preview: 2026年度 次世代ITサービス調達・運用ガイドライン
#   metadata: "{\"year\": 2025, \"region\": \"NA\", \"category\": \"contract\", \"priority\": 1, \"text_field\": \"title\", \"supplier_name\": \"Quantum Systems Inc.\", \"owner_department\": \"Legal & Supply Chain Management\", \"contract_value_usd\": 12000000}"
# - proc-plan-fy2026-apac | text_field=_all | chunk_order=0
#   preview: # 1. はじめに
#   metadata: "{\"year\": 2026, \"region\": \"APAC\", \"version\": \"2.1\", \"approver\": \"John Smith\", \"category\": \"planning_document\", \"priority\": 1, \"text_field\": \"_all\", \"owner_department\": \"IT Procurement Department\"}"
# - proc-plan-fy2026-apac | text_field=status | chunk_order=0
#   preview: in_progress
#   metadata: "{\"year\": 2026, \"region\": \"APAC\", \"version\": \"2.1\", \"approver\": \"John Smith\", \"category\": \"planning_document\", \"priority\": 1, \"text_field\": \"status\", \"owner_department\": \"IT Procurement Department\"}"
# - proc-plan-fy2026-apac | text_field=summary | chunk_order=0
#   preview: 2026年度から2028年度までの中期経営計画に基づき、APAC地域における調達オペレーションの最適化、サプライヤー・レ
#   metadata: "{\"year\": 2026, \"region\": \"APAC\", \"version\": \"2.1\", \"approver\": \"John Smith\", \"category\": \"planning_document\", \"priority\": 1, \"text_field\": \"summary\", \"owner_department\": \"IT Procurement Department\"}"
# - proc-plan-fy2026-apac | text_field=body | chunk_order=0
#   preview: # 1. はじめに
#   metadata: "{\"year\": 2026, \"region\": \"APAC\", \"version\": \"2.1\", \"approver\": \"John Smith\", \"category\": \"planning_document\", \"priority\": 1, \"text_field\": \"body\", \"owner_department\": \"IT Procurement Department\"}"
# - proc-plan-fy2026-apac | text_field=created_at | chunk_order=0
#   preview: 2025-10-01T08:30:00+00:00
#   metadata: "{\"year\": 2026, \"region\": \"APAC\", \"version\": \"2.1\", \"approver\": \"John Smith\", \"category\": \"planning_document\", \"priority\": 1, \"text_field\": \"created_at\", \"owner_department\": \"IT Procurement Department\"}"
# - proc-plan-fy2026-apac | text_field=workspace | chunk_order=0
#   preview: procurement_docs
#   metadata: "{\"year\": 2026, \"region\": \"APAC\", \"version\": \"2.1\", \"approver\": \"John Smith\", \"category\": \"planning_document\", \"priority\": 1, \"text_field\": \"workspace\", \"owner_department\": \"IT Procurement Department\"}"
# - proc-plan-fy2026-apac | text_field=region | chunk_order=0
#   preview: APAC
#   metadata: "{\"year\": 2026, \"region\": \"APAC\", \"version\": \"2.1\", \"approver\": \"John Smith\", \"category\": \"planning_document\", \"priority\": 1, \"text_field\": \"region\", \"owner_department\": \"IT Procurement Department\"}"
# - proc-plan-fy2026-apac | text_field=title | chunk_order=0
#   preview: 2026年度 APAC地域包括調達戦略・実施計画書（第1版）
#   metadata: "{\"year\": 2026, \"region\": \"APAC\", \"version\": \"2.1\", \"approver\": \"John Smith\", \"category\": \"planning_document\", \"priority\": 1, \"text_field\": \"title\", \"owner_department\": \"IT Procurement Department\"}"

# %% [markdown]
# #### target_fields を利用した検索例

# %%
from pprint import pprint

summary_param = QueryParam(
    mode="light",
    target_fields=["summary"],
    include_provenance=True,
    top_k=3,
)

queries = [
    "2026年度のインド市場における調達目標は何ですか？",
    "ITサービス調達におけるクラウドプラットフォームの選定基準を教えてください。",
    "サプライヤーに対するESGやCO2排出に関する要求事項は何ですか？"
]

for query in queries:
    print(f"\n質問: {query}")
    summary_result, summary_sources = await rag.aquery(
        query,
        param=summary_param,
    )
    print("回答:")
    if isinstance(summary_result, dict):
        pprint(summary_result)
    else:
        print(summary_result)
    
    print("\n参照したチャンク:")
    for src in summary_sources:
        print("-", src.split("\n")[0])
# Out:
# 質問: 2026年度のインド市場における調達目標は何ですか？
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 3 results
# ✅ Result 1: id=ent-797a556b01b8..., distance=0.6008168313656308
# ✅ Result 2: id=ent-2af9667e60ea..., distance=0.5004614674811595
# 🔎 Total records in LIGHTRAG_VDB_ENTITY: 156
# 🔎 Raw metadata and distance values:
#    - ID: ent-797a556b01b8...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': '_all', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.6008168313656308
#    - ID: ent-2af9667e60ea...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'body', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.5004614674811595
#    - ID: ent-0b5e38b3f3c2...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': '_all', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.4698167853890153
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# [Local] Metadata filter: {'text_field': 'summary'}
# [Local] before: 5 candidates
# [Local] before samples:
#   - id=chunk-all-2bcdca..., category=planning_document, distance=0.08597025515420675
#   - id=chunk-summary-6e..., category=planning_document, distance=-0.001720549929009385
#   - id=chunk-title-e215..., category=contract, distance=-0.017030694632228505
#   - id=chunk-all-d46b86..., category=contract, distance=0.05804263999167314
#   - id=chunk-body-af651..., category=planning_document, distance=0.08597025515420675
# [Local] filter reduced candidates: before=5 -> after=1
# [Local] Metadata filter: {'text_field': 'summary'}
# [Local] after: 1 candidates
# [Local] after samples:
#   - id=chunk-summary-6e..., category=planning_document, distance=-0.001720549929009385
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 3 results
# ✅ Result 1: id=..., distance=0.5856549934525969
# ✅ Result 2: id=..., distance=0.5686871386621611
# 🔎 Total records in LIGHTRAG_VDB_RELATION: 102
# 🔎 Raw metadata and distance values:
#    - ID: rel-c98c9eb8aa29...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': '_all', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.5856549934525969
#    - ID: rel-7b59e1095d30...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': '_all', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.5686871386621611
#    - ID: rel-e69692eedb0b...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'body', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.561693363184435
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# [Global] Metadata filter: {'text_field': 'summary'}
# [Global] before: 0 candidates
# [Global] filter reduced candidates: before=0 -> after=0
# [Global] Metadata filter: {'text_field': 'summary'}
# [Global] after: 0 candidates
# 回答:
# 2026年度から2028年度までの「中期経営計画」に基づき、APAC（アジア太平洋）地域全体における調達オペレーションの最適化、サプライヤー・レジリエンスの強化、およびコスト構造の改革が定義されています。しかし、提供されたデータには、インド市場に限定された具体的な調達目標や数値は含まれていません。
#
# したがって、2026年度のインド市場における個別の調達目標について言及することはできません。データは地域全体（APAC）を対象とした包括的な方針を示すものであり、特定の国や地域への詳細な目標値は記載されていません。
#
# 参照したチャンク:
# - 2026年度から2028年度までの中期経営計画に基づき、APAC地域における調達オペレーションの最適化、サプライヤー・レジリエンスの強化、およびコスト構造の改革を定義する包括的文書。
#
# 質問: ITサービス調達におけるクラウドプラットフォームの選定基準を教えてください。
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 3 results
# ✅ Result 1: id=ent-242746dddd53..., distance=0.3734827265943341
# ✅ Result 2: id=ent-082cfeb5ab59..., distance=0.36282943231498677
# 🔎 Total records in LIGHTRAG_VDB_ENTITY: 156
# 🔎 Raw metadata and distance values:
#    - ID: ent-242746dddd53...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': 'title', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.3734827265943341
#    - ID: ent-082cfeb5ab59...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'body', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.36282943231498677
#    - ID: ent-4ab6bb189782...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': '_all', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.3607958968484202
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# [Local] Metadata filter: {'text_field': 'summary'}
# [Local] before: 6 candidates
# [Local] before samples:
#   - id=chunk-title-e215..., category=contract, distance=0.02479973592551854
#   - id=chunk-all-d46b86..., category=contract, distance=0.1866650824089402
#   - id=chunk-body-af651..., category=planning_document, distance=0.11449814919196077
#   - id=chunk-title-171b..., category=planning_document, distance=0.016750929956447336
#   - id=chunk-all-2bcdca..., category=planning_document, distance=0.11449814919196077
# [Local] filter reduced candidates: before=6 -> after=1
# [Local] Metadata filter: {'text_field': 'summary'}
# [Local] after: 1 candidates
# [Local] after samples:
#   - id=chunk-summary-6e..., category=planning_document, distance=0.02163894184695936
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 3 results
# ✅ Result 1: id=..., distance=0.44887949550968154
# ✅ Result 2: id=..., distance=0.44624924998858406
# 🔎 Total records in LIGHTRAG_VDB_RELATION: 102
# 🔎 Raw metadata and distance values:
#    - ID: rel-cb57396baed2...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': 'summary', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.44887949550968154
#    - ID: rel-c98c9eb8aa29...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': '_all', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.44624924998858406
#    - ID: rel-907ef7a279be...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': '_all', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.4450635073816731
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# [Global] Metadata filter: {'text_field': 'summary'}
# [Global] before: 0 candidates
# [Global] filter reduced candidates: before=0 -> after=0
# [Global] Metadata filter: {'text_field': 'summary'}
# [Global] after: 0 candidates
# 回答:
# 提供されたデータテーブルには、ITサービス調達におけるクラウドプラットフォームの選定基準に関する具体的な情報は含まれておりません。
#
# 現在のデータセットでは、2026年度から2028年度までの中期経営計画に基づき、APAC地域における調達オペレーションの最適化、サプライヤー・レジリエンスの強化、およびコスト構造の改革を定義する包括的文書が存在する「サプライヤー」というエンティティのみが確認できます。しかし、この文書や関連する関係性データには、クラウドプラットフォームの選定基準や具体的な評価項目についての記述は見当たりません。
#
# したがって、ご質問への回答として具体的な選定基準を提供することはできません。クラウド選定においては通常、パフォーマンス、セキュリティ、コスト効率、スケーラビリティ、およびベンダーの信頼性などが考慮されますが、これらは提供されたデータに基づく情報ではなく、一般的な知識に依存する内容となります。
#
# 参照したチャンク:
# - 2026年度から2028年度までの中期経営計画に基づき、APAC地域における調達オペレーションの最適化、サプライヤー・レジリエンスの強化、およびコスト構造の改革を定義する包括的文書。
#
# 質問: サプライヤーに対するESGやCO2排出に関する要求事項は何ですか？
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 3 results
# ✅ Result 1: id=ent-9da43f985cad..., distance=0.4473731792443023
# ✅ Result 2: id=ent-46ee281fb1b2..., distance=0.39331000747005485
# 🔎 Total records in LIGHTRAG_VDB_ENTITY: 156
# 🔎 Raw metadata and distance values:
#    - ID: ent-9da43f985cad...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'body', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.4473731792443023
#    - ID: ent-46ee281fb1b2...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': '_all', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.39331000747005485
#    - ID: ent-3891f8107ed4...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'body', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.36409968935795334
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# [Local] Metadata filter: {'text_field': 'summary'}
# [Local] before: 2 candidates
# [Local] before samples:
#   - id=chunk-body-af651..., category=planning_document, distance=0.15294875409933528
#   - id=chunk-all-2bcdca..., category=planning_document, distance=0.15294875409933528
# [Local] filter reduced candidates: before=2 -> after=0
# [Local] Metadata filter: {'text_field': 'summary'}
# [Local] after: 0 candidates
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 3 results
# ✅ Result 1: id=..., distance=0.6474655052398651
# ✅ Result 2: id=..., distance=0.6118499755610889
# 🔎 Total records in LIGHTRAG_VDB_RELATION: 102
# 🔎 Raw metadata and distance values:
#    - ID: rel-730035e62876...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': '_all', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.6474655052398651
#    - ID: rel-211285e950ef...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'body', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.6118499755610889
#    - ID: rel-6187c8eb0809...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'body', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.5915806545866578
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# [Global] Metadata filter: {'text_field': 'summary'}
# [Global] before: 0 candidates
# [Global] filter reduced candidates: before=0 -> after=0
# [Global] Metadata filter: {'text_field': 'summary'}
# [Global] after: 0 candidates
# 回答:
# ご提示いただいたデータテーブルには、サプライヤーに対するESG（環境・社会・ガバナンス）やCO2排出に関する具体的な要求事項や条件を示すエントリ、関係性、またはソース情報が含まれていません。
#
# *   **Entities（エンティティ）テーブル**：ヘッダー行のみ（id, entity, type, description, rank）があり、具体的なサプライヤー名やESG基準の定義が含まれていません。
# *   **Relationships（関係性）テーブル**：ヘッダー行のみ（id, source, target, description, keywords, weight, rank）があり、サプライヤーと環境要件を結びつける具体的な記述がありません。
# *   **Sources（ソース）テーブル**：ヘッダー行のみ（id, content）であり、具体的な報告書や基準文書のコンテンツが含まれていません。
#
# したがって、これらのデータに基づいて回答することは不可能であり、現在の情報からは「サプライヤーに対するESGやCO2排出に関する要求事項は何ですか？」という質問に対する具体的な答えを導き出すことができません。もし具体的な要件に関する詳細なデータ（例：特定の基準値、認証要件、報告義務など）が追加されれば、改めて分析を行うことができます。
#
# 参照したチャンク:

# %% [markdown]
# #### target_fields と metadata_filter の併用

# %%
supply_param = QueryParam(
    mode="light",
    target_fields=["body"],
    metadata_filter={"category": "supply", "year": 2025},
    include_provenance=True,
    only_need_context=True,
    top_k=3,
)
queries = [
    "2026年度のインド市場における調達目標は何ですか？",
    "ITサービス調達におけるクラウドプラットフォームの選定基準を教えてください。",
    "サプライヤーに対するESGやCO2排出に関する要求事項は何ですか？"
]

for query in queries:
    print(f"\n質問: {query}")
    supply_context, supply_sources = await rag.aquery(
        query,
        param=supply_param,
    )
    
    print("取得したコンテキスト:")
    if isinstance(supply_context, dict):
        pprint(supply_context)
    else:
        print(supply_context)
    
    print("\n対象チャンク (body フィールド):")
    for src in supply_sources:
        print("-", src.split("\n")[0])
# Out:
# 質問: 2026年度のインド市場における調達目標は何ですか？
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 3 results
# ✅ Result 1: id=Ename-4ecfeeae37..., distance=0.6822239236807861
# ✅ Result 2: id=Ename-773fbe264b..., distance=0.6318540111274639
# 🔎 Total records in LIGHTRAG_VDB_ENTITY: 90
# 🔎 Raw metadata and distance values:
#    - ID: Ename-4ecfeeae37...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': '_all', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.6822239236807861
#    - ID: Ename-773fbe264b...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'summary', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.6318540111274639
#    - ID: ent-4ecfeeae37cc...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': '_all', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.487932879843224
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# [Local] Metadata filter: {'category': 'supply', 'year': 2025, 'text_field': 'body'}
# [Local] before: 3 candidates
# [Local] before samples:
#   - id=chunk-all-d46b86..., category=contract, distance=0.044646868404885076
#   - id=chunk-title-e215..., category=contract, distance=N/A
#   - id=chunk-summary-6e..., category=planning_document, distance=-0.04731117189115985
# [Local] filter reduced candidates: before=3 -> after=0
# [Local] Metadata filter: {'category': 'supply', 'year': 2025, 'text_field': 'body'}
# [Local] after: 0 candidates
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 3 results
# ✅ Result 1: id=..., distance=0.48200458019859793
# ✅ Result 2: id=..., distance=0.4313366702007697
# 🔎 Total records in LIGHTRAG_VDB_RELATION: 32
# 🔎 Raw metadata and distance values:
#    - ID: rel-09584a7de4db...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'title', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.48200458019859793
#    - ID: rel-ea25d6f52988...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'body', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.4313366702007697
#    - ID: rel-c52286f7af4b...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'title', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.3629960106694128
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# [Global] Metadata filter: {'category': 'supply', 'year': 2025, 'text_field': 'body'}
# [Global] before: 0 candidates
# [Global] filter reduced candidates: before=0 -> after=0
# [Global] Metadata filter: {'category': 'supply', 'year': 2025, 'text_field': 'body'}
# [Global] after: 0 candidates
# 取得したコンテキスト:
#
# -----Entities-----
# ```csv
# [{'tokens': 10, 'content': 'id,\tentity,\ttype,\tdescription,\trank', 'chunk_order_index': 0}]
# ```
# -----Relationships-----
# ```csv
# [{'tokens': 16, 'content': 'id,\tsource,\ttarget,\tdescription,\tkeywords,\tweight,\trank', 'chunk_order_index': 0}]
# ```
# -----Sources-----
# ```csv
# [{'tokens': 3, 'content': 'id,\tcontent', 'chunk_order_index': 0}]
# ```
#
#
# 対象チャンク (body フィールド):
#
# 質問: ITサービス調達におけるクラウドプラットフォームの選定基準を教えてください。
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 3 results
# ✅ Result 1: id=ent-609c9690729a..., distance=0.3660474457506324
# ✅ Result 2: id=ent-6a4ec0f0ede8..., distance=0.3645918392022207
# 🔎 Total records in LIGHTRAG_VDB_ENTITY: 90
# 🔎 Raw metadata and distance values:
#    - ID: ent-609c9690729a...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'body', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.3660474457506324
#    - ID: ent-6a4ec0f0ede8...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': 'summary', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.3645918392022207
#    - ID: ent-e1cfc2754e22...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': '_all', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.35519849118373426
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# [Local] Metadata filter: {'category': 'supply', 'year': 2025, 'text_field': 'body'}
# [Local] before: 4 candidates
# [Local] before samples:
#   - id=chunk-body-af651..., category=planning_document, distance=0.29999523855052423
#   - id=chunk-all-2bcdca..., category=planning_document, distance=0.29999523855052423
#   - id=chunk-all-d46b86..., category=contract, distance=0.4820408293219667
#   - id=chunk-body-00424..., category=contract, distance=0.4820408293219667
# [Local] filter reduced candidates: before=4 -> after=0
# [Local] Metadata filter: {'category': 'supply', 'year': 2025, 'text_field': 'body'}
# [Local] after: 0 candidates
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 3 results
# ✅ Result 1: id=..., distance=0.3791123105920049
# ✅ Result 2: id=..., distance=0.3185322301032043
# 🔎 Total records in LIGHTRAG_VDB_RELATION: 32
# 🔎 Raw metadata and distance values:
#    - ID: rel-6a9101de4b0b...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': '_all', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.3791123105920049
#    - ID: rel-f3272539f555...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': '_all', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.3185322301032043
#    - ID: rel-619c93a3511c...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': '_all', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.2968618864516206
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# [Global] Metadata filter: {'category': 'supply', 'year': 2025, 'text_field': 'body'}
# [Global] before: 0 candidates
# [Global] filter reduced candidates: before=0 -> after=0
# [Global] Metadata filter: {'category': 'supply', 'year': 2025, 'text_field': 'body'}
# [Global] after: 0 candidates
# 取得したコンテキスト:
#
# -----Entities-----
# ```csv
# [{'tokens': 10, 'content': 'id,\tentity,\ttype,\tdescription,\trank', 'chunk_order_index': 0}]
# ```
# -----Relationships-----
# ```csv
# [{'tokens': 16, 'content': 'id,\tsource,\ttarget,\tdescription,\tkeywords,\tweight,\trank', 'chunk_order_index': 0}]
# ```
# -----Sources-----
# ```csv
# [{'tokens': 3, 'content': 'id,\tcontent', 'chunk_order_index': 0}]
# ```
#
#
# 対象チャンク (body フィールド):
#
# 質問: サプライヤーに対するESGやCO2排出に関する要求事項は何ですか？
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 3 results
# ✅ Result 1: id=ent-773fbe264b07..., distance=0.2987313398435901
# ✅ Result 2: id=ent-c78512d26ca0..., distance=0.2824479624448033
# 🔎 Total records in LIGHTRAG_VDB_ENTITY: 90
# 🔎 Raw metadata and distance values:
#    - ID: ent-773fbe264b07...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'summary', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.2987313398435901
#    - ID: ent-c78512d26ca0...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': 'workspace', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.2824479624448033
#    - ID: ent-4ecfeeae37cc...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': '_all', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.27739306588297574
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# [Local] Metadata filter: {'category': 'supply', 'year': 2025, 'text_field': 'body'}
# [Local] before: 4 candidates
# [Local] before samples:
#   - id=chunk-summary-6e..., category=planning_document, distance=-0.07334226689344137
#   - id=chunk-workspace-..., category=contract, distance=N/A
#   - id=chunk-all-d46b86..., category=contract, distance=0.146268087091594
#   - id=chunk-title-e215..., category=contract, distance=-0.08429744414458873
# [Local] filter reduced candidates: before=4 -> after=0
# [Local] Metadata filter: {'category': 'supply', 'year': 2025, 'text_field': 'body'}
# [Local] after: 0 candidates
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 3 results
# ✅ Result 1: id=..., distance=0.40225619183608186
# ✅ Result 2: id=..., distance=0.35586235773086883
# 🔎 Total records in LIGHTRAG_VDB_RELATION: 32
# 🔎 Raw metadata and distance values:
#    - ID: rel-1ce222a2a830...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'body', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.40225619183608186
#    - ID: rel-6a9101de4b0b...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': '_all', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.35586235773086883
#    - ID: rel-80f8fa4d1316...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': '_all', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.30319435624604996
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# [Global] Metadata filter: {'category': 'supply', 'year': 2025, 'text_field': 'body'}
# [Global] before: 0 candidates
# [Global] filter reduced candidates: before=0 -> after=0
# [Global] Metadata filter: {'category': 'supply', 'year': 2025, 'text_field': 'body'}
# [Global] after: 0 candidates
# 取得したコンテキスト:
#
# -----Entities-----
# ```csv
# [{'tokens': 10, 'content': 'id,\tentity,\ttype,\tdescription,\trank', 'chunk_order_index': 0}]
# ```
# -----Relationships-----
# ```csv
# [{'tokens': 16, 'content': 'id,\tsource,\ttarget,\tdescription,\tkeywords,\tweight,\trank', 'chunk_order_index': 0}]
# ```
# -----Sources-----
# ```csv
# [{'tokens': 3, 'content': 'id,\tcontent', 'chunk_order_index': 0}]
# ```
#
#
# 対象チャンク (body フィールド):

# %% [markdown]
# #### 時間フィルタ（`start_time` / `end_time`）の利用

# %%
from datetime import datetime, timedelta, timezone

now = datetime.now(timezone.utc)

param = QueryParam(
    mode="light",
    start_time=now.isoformat(),
    end_time=(now + timedelta(hours=1)).isoformat(),
    metadata_filter={"category": "plan"},
)

answer, sources = await rag.aquery("最近登録された計画について教えて", param=param)
print(answer)
print(sources)
# Out:
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 0 results
# 🔎 Total records in LIGHTRAG_VDB_ENTITY: 74
# 🔎 Raw metadata and distance values:
#    - ID: Ename-a84fbb5cff...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': '_all', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.36557339889926355
#    - ID: Ename-4161566299...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': '_all', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.3612903468224189
#    - ID: Ename-44258c97dc...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': 'created_at', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.20028934885341587
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 0 results
# 🔎 Total records in LIGHTRAG_VDB_RELATION: 11
# 🔎 Raw metadata and distance values:
#    - ID: rel-a899ea833948...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'summary', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.34148275077401413
#    - ID: rel-4bda126441c8...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'summary', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.30284329644702623
#    - ID: rel-871fdbd4ad9a...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'summary', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.24138665159521377
# 申し訳ありませんが、提供されたデータテーブル（エンティティ、関係、ソース）はすべて空です。そのため、最新の計画に関する情報は提供できません。データに記載された具体的な内容が存在しないため、ご質問にお答えする材料がございません。ご了承ください。
# []

# %% [markdown]
# #### target_fields を指定しない場合（_all チャンク）

# %%
default_param = QueryParam(mode="light", top_k=3)
default_answer, default_sources = await rag.aquery(
    "契約全体の概要をまとめてください。",
    param=default_param,
)

print("回答:")
print(default_answer)

print("\n参照したソース: ")
for src in default_sources:
    print(src)
    print("================================================")
# Out:
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 3 results
# ✅ Result 1: id=Ename-773fbe264b..., distance=0.30495817211176424
# ✅ Result 2: id=ent-a35eb4dd7a5b..., distance=0.28456572084164833
# 🔎 Total records in LIGHTRAG_VDB_ENTITY: 90
# 🔎 Raw metadata and distance values:
#    - ID: Ename-773fbe264b...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'summary', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.30495817211176424
#    - ID: ent-a35eb4dd7a5b...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'body', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.28456572084164833
#    - ID: Ename-4b6d4ed759...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'title', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.27087175781975414
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 3 results
# ✅ Result 1: id=..., distance=0.2651302620187397
# ✅ Result 2: id=..., distance=0.2410311952590385
# 🔎 Total records in LIGHTRAG_VDB_RELATION: 32
# 🔎 Raw metadata and distance values:
#    - ID: rel-2d657d0895d0...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': '_all', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.2651302620187397
#    - ID: rel-559460f2ac7e...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': '_all', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.2410311952590385
#    - ID: rel-c52286f7af4b...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'title', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.23407976001594544
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# 回答:
# ## 2026年度 APAC地域包括調達戦略・実施計画書（第1版）概要
#
# ### 1️⃣ はじめに
# 本計画書は、**地政学的リスクの増大**と**原材料価格の変動**に対処するため、2026年度におけるAPAC地域の調達方針を定めたものです。
# > *「本計画書は、地政学的リスクの増大と原材料価格の変動に対応するため、2026年度におけるAPAC地域の調達方針を定めるものである。」*【Source 1】
#
# ---
#
# ### 2️⃣ 戦略目標（KPI）
# | 目標 | 現状 | 目標値 | 期待効果 |
# |------|------|--------|----------|
# | **Multi‑sourcing率** | 40 % | 65 % | サプライチェーンのレジリエンス向上 |
# | **Local Content Ratio (LCR)** | - | +12 % | 物流コスト・関税リスクの低減 |
# | **AI需給予測モデル** | - | 本格稼働 | 過剰在庫の保管コストを年間約1.2億円削減 |
#
# > *「重点カテゴリーにおける複数社購買（Multi‑sourcing）率を現状の40 %から65 %へ引き上げる。」*【Source 1】
# > *「地域内調達率（LCR: Local Content Ratio）を平均12 %向上させ、物流コストと関税リスクを低減する。」*【Source 1】
# > *「AIによる需給予測モデルを本格稼働させ、過剰在庫による保管コストを年間で約1.2億円削減する。」*【Source 1】
#
# ---
#
# ### 3️⃣ サプライヤーマネジメント
# | 項目 | 内容 | 具体策 |
# |------|------|--------|
# | **新規サプライヤー開拓** | 東南アジア（ベトナム・タイ・インドネシア）での製造拠点拡大に伴い、**有力サプライヤー50社**と戦略的パートナーシップを締結 | 主要サプライヤーの多様化 |
# | **インド市場** | 半導体関連部材の現地調達比率を**25 %**まで向上 | 供給リスクの分散 |
# | **ESG対応・監査** | 主要サプライヤー（年間取引額1億円以上）に対し、**CO₂排出量の四半期報告**を義務付け | 30 %の対象企業で第三者機関による人権デューデリジェンス監査を実施 | 透明性とサステナビリティの確保 |
#
# > *「全ての主要サプライヤー（年間取引額1億円以上）に対し、CO₂排出量の四半期報告を義務付ける。」*【Source 1】
# > *「人権デューデリジェンスに関する第三者機関による監査を、対象企業の30 %で実施する。」*【Source 1】
#
# ---
#
# ### 4️⃣ デジタル変革（Procurement DX）
# - **次世代型E‑Procurementシステム**を全拠点に導入
# - 発注から支払いまでのリードタイムを**20 %短縮**
# - サプライヤー支払いを**100 %電子化**
#
# > *「調達プロセスの透明性を高めるため、次世代型E‑Procurementシステムを全拠点に導入する。」*【Source 1】
#
# ---
#
# ### 5️⃣ リスク管理
# | リスク | 対策 | 期限 |
# |--------|------|------|
# | **重要部材の生産集中**（23品目） | 代替生産拠点を確保 | Q2（7‑9月） |
# | **大規模災害時の緊急調達** | 緊急調達フローを再構築 | 初動対応時間を24 h→6 h以内へ短縮 |
#
# > *「地政学的リスクに対応するため、特定の1カ国に生産が集中している重要部材（23品目）について、代替生産拠点の確保をQ2（7‑9月）までに完了させる。」*【Source 1】
# > *「大規模災害発生時の緊急調達フローを再構築し、初動対応時間を現状の24時間から6時間以内へ短縮する。」*【Source 1】
#
# ---
#
# ## 📌 まとめ
# - **目的**：地政学的リスクと原材料価格変動への対応
# - **主な目標**：サプライチェーンのレジリエンス向上、コスト削減、ESG遵守
# - **実施手段**：サプライヤー多様化、デジタル化、リスク対策の強化
#
# この計画書は、APAC地域における調達オペレーションの最適化とサプライヤー・レジリエンスの強化を図るための包括的なロードマップとして位置付けられています。
#
# 参照したソース:
# 2026年度 APAC地域包括調達戦略・実施計画書（第1版）
# ================================================
# # 1. はじめに
# 本計画書は、地政学的リスクの増大と原材料価格の変動に対応するため、2026年度におけるAPAC地域の調達方針を定めるものである。
#
# # 2. 戦略目標
# 2026年度の最優先課題は「供給網の安定化」と「持続可能なコスト削減」の両立である。具体的には以下のKPIを設定する。
# - 重点カテゴリーにおける複数社購買（Multi-sourcing）率を現状の40%から65%へ引き上げる。
# - 地域内調達率（LCR: Local Content Ratio）を平均12%向上させ、物流コストと関税リスクを低減する。
# - AIによる需給予測モデルを本格稼働させ、過剰在庫による保管コストを年間で約1.2億円削減する。
#
# # 3. サプライヤーマネジメント
# ## 3.1 新規サプライヤーの開拓
# 東南アジア諸国（特にベトナム、タイ、インドネシア）における製造拠点の拡大に伴い、現地の有力サプライヤー50社との戦略的パートナーシップを締結する。
# 特にインド市場においては、半導体関連部材の現地調達比率を25%まで高めることを目指す。
#
# ## 3.2 ESG対応と監査
# 2026年度より、全ての主要サプライヤー（年間取引額1億円以上）に対し、CO2排出量の四半期報告を義務付ける。
# また、人権デューデリジェンスに関する第三者機関による監査を、対象企業の30%で実施する。
#
# # 4. デジタル変革（Procurement DX）
# 調達プロセスの透明性を高めるため、次世代型E-Procurementシステムを全拠点に導入する。
# これにより、発注から支払いまでのリードタイムを20%短縮し、サプライヤー支払いの100%電子化を実現する。
#
# # 5. リスク管理
# 地政学的リスクに対応するため、特定の1カ国に生産が集中している重要部材（23品目）について、代替生産拠点の確保をQ2（7-9月）までに完了させる。
# 大規模災害発生時の緊急調達フローを再構築し、初動対応時間を現状の24時間から6時間以内へ短縮する。
# ================================================
# 2026年度から2028年度までの中期経営計画に基づき、APAC地域における調達オペレーションの最適化、サプライヤー・レジリエンスの強化、およびコスト構造の改革を定義する包括的文書。
# ================================================

# %% [markdown]
# ### フィルターしないシンプルVerで試してみる

# %%
# 良い感じにできている
default_param = QueryParam(
    mode="light",
    include_provenance=True,
    top_k=3,
)

queries = [
    "2026年度のインド市場における調達目標は何ですか？",
    "ITサービス調達におけるクラウドプラットフォームの選定基準を教えてください。",
    "サプライヤーに対するESGやCO2排出に関する要求事項は何ですか？"
]

for query in queries:
    print(f"\n質問: {query}")
    default_result, default_sources = await rag.aquery(
        query,
        param=default_param,
    )
    print("回答:")
    if isinstance(default_result, dict):
        pprint(default_result)
    else:
        print(default_result)
    
    print("\n参照したチャンク:")
    for src in default_sources:
        print("-", src.split("\n")[0])
# Out:
# 質問: 2026年度のインド市場における調達目標は何ですか？
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 3 results
# ✅ Result 1: id=ent-797a556b01b8..., distance=0.6049779946245438
# ✅ Result 2: id=ent-2af9667e60ea..., distance=0.5337048228087333
# 🔎 Total records in LIGHTRAG_VDB_ENTITY: 156
# 🔎 Raw metadata and distance values:
#    - ID: ent-797a556b01b8...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': '_all', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.6049779946245438
#    - ID: ent-2af9667e60ea...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'body', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.5337048228087333
#    - ID: ent-0b5e38b3f3c2...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': '_all', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.48199176433751567
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 3 results
# ✅ Result 1: id=..., distance=0.6148039573258441
# ✅ Result 2: id=..., distance=0.553317095320178
# 🔎 Total records in LIGHTRAG_VDB_RELATION: 102
# 🔎 Raw metadata and distance values:
#    - ID: rel-c98c9eb8aa29...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': '_all', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.6148039573258441
#    - ID: rel-b16d2e114cb1...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'title', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.553317095320178
#    - ID: rel-4a79e8cae0a0...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'summary', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.5447688665592935
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# 回答:
# 2026年度のAPAC地域包括調達戦略・実施計画書において、インド市場に関する具体的な調達目標は、半導体関連部材の現地調達比率を25%まで高めることです。これは、東南アジア諸国（ベトナム、タイ、インドネシア）における製造拠点の拡大に伴い、現地の有力サプライヤー50社との戦略的パートナーシップを締結する「新規サプライヤーの開拓」の一環として設定されています。この目標は、地政学的リスクの増大や原材料価格の変動に対応し、供給網の安定化を図るための重要な施策の一つです。
#
# また、この戦略は2026年度から2028年度までの中期経営計画に基づいて策定されており、APAC地域における調達オペレーションの最適化、サプライヤー・レジリエンスの強化、コスト構造の改革を目的としています。インド市場における半導体部材の現地調達比率向上は、物流コストと関税リスクの低減、ならびに地域内調達率（LCR）の平均12%向上というより広範な目標の一部を構成しています。
#
# なお、この計画書は現在「in_progress」の段階にあり、2026年度における具体的なKPI達成に向けた詳細な実行計画が進行中ですが、インド市場の半導体調達目標は既に明確に定義されています。
#
# 参照したチャンク:
# - # 1. はじめに
# - 2026年度から2028年度までの中期経営計画に基づき、APAC地域における調達オペレーションの最適化、サプライヤー・レジリエンスの強化、およびコスト構造の改革を定義する包括的文書。
# - 2026年度 次世代ITサービス調達・運用ガイドライン
# - # 1. 目的
# - # 1. はじめに
#
# 質問: ITサービス調達におけるクラウドプラットフォームの選定基準を教えてください。
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 3 results
# ✅ Result 1: id=ent-907695ffaef2..., distance=0.40589135438542656
# ✅ Result 2: id=ent-1e1c4ffd23f3..., distance=0.38597096851651935
# 🔎 Total records in LIGHTRAG_VDB_ENTITY: 156
# 🔎 Raw metadata and distance values:
#    - ID: ent-907695ffaef2...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': 'body', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.40589135438542656
#    - ID: ent-1e1c4ffd23f3...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': 'summary', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.38597096851651935
#    - ID: ent-68b95e952c7e...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': 'body', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.3740353078358647
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 3 results
# ✅ Result 1: id=..., distance=0.4633050300837771
# ✅ Result 2: id=..., distance=0.4499138776134388
# 🔎 Total records in LIGHTRAG_VDB_RELATION: 102
# 🔎 Raw metadata and distance values:
#    - ID: rel-cb57396baed2...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': 'summary', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.4633050300837771
#    - ID: rel-907ef7a279be...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': '_all', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.4499138776134388
#    - ID: rel-c98c9eb8aa29...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': '_all', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.4489793944010789
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# 回答:
# 2026年度 次世代ITサービス調達・運用ガイドラインに基づき、ITサービス調達におけるクラウドプラットフォームの選定基準は、グループ全体のITガバナンス強化、サイバーセキュリティリスクの低減、およびITコストの最適化を目的とした「クラウドファースト戦略」の下で決定されます。新規ITシステムの導入に際しては、原則としてクラウドネイティブな構成が採用されることが求められます。プラットフォームの推奨は地域によって異なり、アジア太平洋地域（Asia Pacific Regions）では**AWS**が、グローバル地域では**Microsoft Azure**が推奨されています。
#
# プラットフォーム選定における具体的な調達基準は、以下の2点が必須条件として設定されています。第一に、サービスの可用性は**99.99%以上**を保証していること。第二に、**ISO 27017認証**（クラウドサービスの情報セキュリティ管理に関する国際規格）を取得していることが義務付けられています。これらの基準を満たさないクラウドサービスは、グループ全体のセキュリティリスクを低減する観点から、原則として採用できません。
#
# さらに、クラウドプラットフォームの選定は、ソフトウェアライセンス管理やサプライチェーンセキュリティの要件とも連動しています。例えば、SaaS利用の管理においては、利用率が30%以下のアプリケーションについては契約更新を行わないなど、効率的なリソース配分が求められます。また、ITサービス提供ベンダー（クラウドプロバイダー含む）に対しては、SOC2 Type2レポートの定期的な提出、ゼロトラストアーキテクチャに基づくアクセス制御の実装、および年2回以上の脆弱性診断の実施と報告が必須要件となっています。これらを満たすことで、シャドーITの撲滅とセキュリティリスクの最小化が図られます。
#
# 最後に、ハードウェア調達と循環経済の観点もクラウドインフラの選定に間接的に関連しています。PCやサーバー、ネットワーク機器の調達においては、環境負荷を最小限に抑えることが求められ、廃棄されるハードウェアの80%以上をリサイクルまたはリユースする「IT資産循環プログラム」がQ3より開始されます。また、消費電力効率が前世代比で15%以上向上しているモデルが優先的に選定されるため、クラウドプラットフォームの選定においても、その裏盤となるハードウェアの環境負荷やエネルギー効率を考慮した判断が推奨されます。
#
# 参照したチャンク:
# - # 1. 目的
# - グローバル全拠点におけるIT資産、ソフトウェア、クラウドサービスの調達基準とセキュリティ要件。
# - # 1. 目的
#
# 質問: サプライヤーに対するESGやCO2排出に関する要求事項は何ですか？
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 3 results
# ✅ Result 1: id=ent-9da43f985cad..., distance=0.5159100066385963
# ✅ Result 2: id=ent-46ee281fb1b2..., distance=0.4555342869368062
# 🔎 Total records in LIGHTRAG_VDB_ENTITY: 156
# 🔎 Raw metadata and distance values:
#    - ID: ent-9da43f985cad...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'body', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.5159100066385963
#    - ID: ent-46ee281fb1b2...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': '_all', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.4555342869368062
#    - ID: ent-3891f8107ed4...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'body', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.39052137165608425
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 3 results
# ✅ Result 1: id=..., distance=0.6244943273459045
# ✅ Result 2: id=..., distance=0.5613631241332241
# 🔎 Total records in LIGHTRAG_VDB_RELATION: 102
# 🔎 Raw metadata and distance values:
#    - ID: rel-730035e62876...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': '_all', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.6244943273459045
#    - ID: rel-6187c8eb0809...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'body', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.5613631241332241
#    - ID: rel-211285e950ef...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'body', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.5479074786447838
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# 回答:
# 2026年度におけるAPAC地域の調達方針では、サプライヤーに対する環境・社会（ESG）およびCO2排出に関する厳格な要求事項が明確に定められています。これらの施策は、地政学的リスクへの対応や持続可能なコスト削減を目的とした「供給網の安定化」の一環として位置づけられています。
#
# まず、環境面におけるCO2排出量に関する報告義務が強化されます。2026年度より、年間取引額が1億円以上の全ての主要サプライヤーに対し、CO2排出量の四半期ごとの報告が義務付けられます。これにより、企業はサプライチェーン全体のカーボンフットプリントを可視化し、定期的なモニタリングを通じて環境目標の達成状況を管理することが可能になります。
#
# 次に、社会面における人権デューデリジェンスへの対応です。第三者機関による監査を、対象となる企業の30%で実施することが計画されています。これは、サプライヤーが労働環境や人権尊重の観点から適切な基準を満たしているかを確認し、リスクを未然に防ぐための重要なステップとなります。
#
# これらの要求事項は、単なるコンプライアンス遵守を超え、サプライヤーとの戦略的パートナーシップを深めるための基盤となっています。東南アジア諸国（ベトナム、タイ、インドネシア）での製造拠点拡大に伴い、現地の有力サプライヤー50社との連携を強化する一方で、ESG対応の徹底を図ることで、長期的なサプライチェーンのレジリエンスと持続可能性を確保することが目指されています。
#
# 参照したチャンク:
# - # 1. はじめに
# - # 1. はじめに

# %%
# ミニモードも試してみる → 精度は置いておいてちゃんと動いていそう
default_param = QueryParam(
    mode="mini",
    include_provenance=True,
    top_k=3,
)

queries = [
    "2026年度のインド市場における調達目標は何ですか？",
    "ITサービス調達におけるクラウドプラットフォームの選定基準を教えてください。",
    "サプライヤーに対するESGやCO2排出に関する要求事項は何ですか？"
]

for query in queries:
    print(f"\n質問: {query}")
    default_result, default_sources = await rag.aquery(
        query,
        param=default_param,
    )
    print("回答:")
    if isinstance(default_result, dict):
        pprint(default_result)
    else:
        print(default_result)
    
    print("\n参照したチャンク:")
    for src in default_sources:
        print("-", src.split("\n")[0])
# Out:
# 質問: 2026年度のインド市場における調達目標は何ですか？
# ★デバッグ(minirag.py): mini mode
# ★デバッグ(postgres_impl.py): create_graph already exists
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 3 results
# ✅ Result 1: id=Ename-773fbe264b..., distance=0.6766635066308787
# ✅ Result 2: id=Ename-4ecfeeae37..., distance=0.6096748005065683
# 🔎 Total records in LIGHTRAG_DOC_CHUNKS: 16
# 🔎 Raw metadata and distance values:
#    - ID: chunk-summary-6e...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'summary', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.08200306450534867
#    - ID: chunk-title-171b...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'title', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.051903148176082436
#    - ID: chunk-title-e215...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': 'title', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.043632066163185046
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 3 results
# ✅ Result 1: id=ent-609c9690729a..., distance=0.5479656778625036
# ✅ Result 2: id=Ename-609c969072..., distance=0.5434841049228156
# 🔎 Total records in LIGHTRAG_DOC_CHUNKS: 16
# 🔎 Raw metadata and distance values:
#    - ID: chunk-all-2bcdca...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': '_all', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.054367148647521346
#    - ID: chunk-body-af651...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'body', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.054367148647521346
#    - ID: chunk-body-00424...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': 'body', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.02693158759200842
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 3 results
# ✅ Result 1: id=ent-984d2d238896..., distance=0.3634377666493962
# ✅ Result 2: id=Ename-4ecfeeae37..., distance=0.3232011968785382
# 🔎 Total records in LIGHTRAG_DOC_CHUNKS: 16
# 🔎 Raw metadata and distance values:
#    - ID: chunk-summary-6e...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'summary', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.0512568873198761
#    - ID: chunk-summary-bc...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': 'summary', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.049795330986262765
#    - ID: chunk-title-e215...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': 'title', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.04473438892688697
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x32303236e5b9b4e5baa6e3818be3828932303238e5b9b4e5baa6e381bee381a7e381aee4b8ade69c9fe7b58ce596b6e8a888e794bb"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x32303236e5b9b4e5baa620e6aca1e4b896e4bba34954e382b5e383bce38393e382b9e8aabfe98194e383bbe9818be794a8e382ace382a4e38389e383a9e382a4e383b3"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x32303236e5b9b4e5baa6"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe382a4e383b3e38389e5b882e5a0b4"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe382b0e383abe383bce38397"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 9 results
# ✅ Result 1: id=..., distance=0.3850707950355656
# ✅ Result 2: id=..., distance=0.3449298697087456
# 🔎 Total records in LIGHTRAG_VDB_RELATION: 32
# 🔎 Raw metadata and distance values:
#    - ID: rel-c52286f7af4b...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'title', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.3850707950355656
#    - ID: rel-2d657d0895d0...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': '_all', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.3449298697087456
#    - ID: rel-09584a7de4db...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'title', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.34482928000434376
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# 回答:
# {'answer': '## 2026年度のインド市場における調達目標\n'
#            '\n'
#            '### 1. 目標の概要  \n'
#            '2026年度のAPAC調達戦略の中で、インド市場に対して設定された具体的な調達目標は '
#            '**「半導体関連部材の現地調達比率を25\u202f%に高める」** です。  \n'
#            '> *Source: 3.1 新規サプライヤーの開拓 – '
#            '「インド市場においては、半導体関連部材の現地調達比率を25%まで高めることを目指す。」*\n'
#            '\n'
#            '### 2. 背景と意図  \n'
#            '- **サプライチェーンの分散化**  \n'
#            '  '
#            'インドは地政学的リスクや輸送コストの高騰が懸念される地域の一つです。現地調達比率を上げることで、サプライチェーンの集中リスクを低減し、供給安定性を確保します。  \n'
#            '- **コスト最適化**  \n'
#            '  現地調達により輸送費や関税リスクを抑え、総調達コストの削減を図ります。  \n'
#            '- **ESG・サステナビリティ**  \n'
#            '  地元企業との協業を進めることで、CO₂排出量削減や人権・労働条件の改善といったESG目標にも寄与します。\n'
#            '\n'
#            '### 3. 実施手段  \n'
#            '- **サプライヤー開拓**  \n'
#            '  東南アジア諸国と同様に、インド国内の有力サプライヤーとの戦略的パートナーシップを構築。  \n'
#            '- **監査・報告体制**  \n'
#            '  '
#            '主要サプライヤー（年間取引額1億円以上）に対し、CO₂排出量の四半期報告を義務付け、第三者機関による人権デューデリジェンス監査を30\u202f'
#            '%実施。  \n'
#            '- **デジタル化**  \n'
#            '  '
#            '次世代型E‑Procurementシステムを導入し、発注から支払いまでのリードタイムを短縮し、サプライヤー支払いを100\u202f'
#            '%電子化。\n'
#            '\n'
#            '### 4. 期待される成果  \n'
#            '- **現地調達比率の向上**  \n'
#            '  2026年度末までに半導体関連部材の現地調達比率を25\u202f%に到達。  \n'
#            '- **コスト削減**  \n'
#            '  物流コストと関税リスクの低減により、全体の調達コストが安定化。  \n'
#            '- **リスク軽減**  \n'
#            '  重要部材の代替生産拠点確保や緊急調達フローの再構築により、災害時の初動対応時間を24時間から6時間以内に短縮。\n'
#            '\n'
#            '---\n'
#            '\n'
#            '**結論**  \n'
#            '2026年度におけるインド市場の調達目標は、半導体関連部材の現地調達比率を25\u202f'
#            '%に引き上げることです。この目標は、サプライチェーンの安定化、コスト削減、ESG対応といった全体戦略と連動して実施されます。',
#  'provenance': {'chunks': [{'chunk_id': 'chunk-body-af651d5c8935697198b0b6cec74d3d02',
#                             'chunk_order_index': 0,
#                             'content': '# 1. はじめに\n'
#                                        '本計画書は、地政学的リスクの増大と原材料価格の変動に対応するため、2026年度におけるAPAC地域の調達方針を定めるものである。\n'
#                                        '\n'
#                                        '# 2. 戦略目標\n'
#                                        '2026年度の最優先課題は「供給網の安定化」と「持続可能なコスト削減」の両立である。具体的には以下のKPIを設定する。\n'
#                                        '- '
#                                        '重点カテゴリーにおける複数社購買（Multi-sourcing）率を現状の40%から65%へ引き上げる。\n'
#                                        '- 地域内調達率（LCR: Local Content '
#                                        'Ratio）を平均12%向上させ、物流コストと関税リスクを低減する。\n'
#                                        '- '
#                                        'AIによる需給予測モデルを本格稼働させ、過剰在庫による保管コストを年間で約1.2億円削減する。\n'
#                                        '\n'
#                                        '# 3. サプライヤーマネジメント\n'
#                                        '## 3.1 新規サプライヤーの開拓\n'
#                                        '東南アジア諸国（特にベトナム、タイ、インドネシア）における製造拠点の拡大に伴い、現地の有力サプライヤー50社との戦略的パートナーシップを締結する。\n'
#                                        '特にインド市場においては、半導体関連部材の現地調達比率を25%まで高めることを目指す。\n'
#                                        '\n'
#                                        '## 3.2 ESG対応と監査\n'
#                                        '2026年度より、全ての主要サプライヤー（年間取引額1億円以上）に対し、CO2排出量の四半期報告を義務付ける。\n'
#                                        'また、人権デューデリジェンスに関する第三者機関による監査を、対象企業の30%で実施する。\n'
#                                        '\n'
#                                        '# 4. デジタル変革（Procurement DX）\n'
#                                        '調達プロセスの透明性を高めるため、次世代型E-Procurementシステムを全拠点に導入する。\n'
#                                        'これにより、発注から支払いまでのリードタイムを20%短縮し、サプライヤー支払いの100%電子化を実現する。\n'
#                                        '\n'
#                                        '# 5. リスク管理\n'
#                                        '地政学的リスクに対応するため、特定の1カ国に生産が集中している重要部材（23品目）について、代替生産拠点の確保をQ2（7-9月）までに完了させる。\n'
#                                        '大規模災害発生時の緊急調達フローを再構築し、初動対応時間を現状の24時間から6時間以内へ短縮する。',
#                             'full_doc_id': 'proc-plan-fy2026-apac',
#                             'tokens': 652}],
#                 'entities': [{'description': '"2026年度 denotes the fiscal year '
#                                              '2026, marking the time period '
#                                              'for which the APAC procurement '
#                                              'strategy and implementation plan '
#                                              'are intended."<SEP>"2026年度 '
#                                              'denotes the fiscal year 2026, '
#                                              'the time period for which the '
#                                              'APAC procurement strategy and '
#                                              'implementation plan are '
#                                              'intended."<SEP>"2026年度 is the '
#                                              'fiscal year during which the '
#                                              'procurement strategy is '
#                                              'implemented, focusing on supply '
#                                              'chain stability and cost '
#                                              'reduction."<SEP>"2026年度 is the '
#                                              'fiscal year for which the '
#                                              'procurement policy and strategic '
#                                              'objectives are set, including '
#                                              'supply chain stabilization and '
#                                              'cost reduction."',
#                               'entity_name': '"2026年度"',
#                               'score': 0.5992447023567247}]}}
#
# 参照したチャンク:
# - # 1. はじめに
#
# 質問: ITサービス調達におけるクラウドプラットフォームの選定基準を教えてください。
# ★デバッグ(minirag.py): mini mode
# ★デバッグ(postgres_impl.py): create_graph already exists
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 3 results
# ✅ Result 1: id=Ename-4ecfeeae37..., distance=0.4437823535326866
# ✅ Result 2: id=Ename-e1cfc2754e..., distance=0.42359309820316504
# 🔎 Total records in LIGHTRAG_DOC_CHUNKS: 16
# 🔎 Raw metadata and distance values:
#    - ID: chunk-summary-bc...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': 'summary', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.05746256218718293
#    - ID: chunk-summary-6e...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'summary', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.0475851807117077
#    - ID: chunk-title-e215...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': 'title', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.04032721812527629
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 3 results
# ✅ Result 1: id=Ename-773fbe264b..., distance=0.3420490765411286
# ✅ Result 2: id=Ename-4ecfeeae37..., distance=0.29918793914103214
# 🔎 Total records in LIGHTRAG_DOC_CHUNKS: 16
# 🔎 Raw metadata and distance values:
#    - ID: chunk-summary-6e...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'summary', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.059525514008428204
#    - ID: chunk-summary-bc...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': 'summary', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.0391188407539409
#    - ID: chunk-title-171b...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'title', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.03223009848783387
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x32303236e5b9b4e5baa620e6aca1e4b896e4bba34954e382b5e383bce38393e382b9e8aabfe98194e383bbe9818be794a8e382ace382a4e38389e383a9e382a4e383b3"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x4954e382b5e383bce38393e382b9e68f90e4be9be38399e383b3e38380e383bc"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x32303236e5b9b4e5baa6e3818be3828932303238e5b9b4e5baa6e381bee381a7e381aee4b8ade69c9fe7b58ce596b6e8a888e794bb"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe7acace4b889e88085e6a99fe996a2"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 6 results
# ✅ Result 1: id=..., distance=0.2721208220578333
# ✅ Result 2: id=..., distance=0.27186393507551754
# 🔎 Total records in LIGHTRAG_VDB_RELATION: 32
# 🔎 Raw metadata and distance values:
#    - ID: rel-6a9101de4b0b...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': '_all', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.2721208220578333
#    - ID: rel-f3272539f555...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': '_all', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.27186393507551754
#    - ID: rel-1ce222a2a830...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'body', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.25376371661795116
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# 回答:
# {'answer': '## クラウドプラットフォーム選定基準（2026年度次世代ITサービス調達・運用ガイドライン）\n'
#            '\n'
#            '### 1. 目的と背景  \n'
#            '本ガイドラインは、グループ全体のITガバナンスを強化し、サイバーセキュリティリスクを低減しつつ、ITコストの最適化を図ることを目的としています。クラウドファースト戦略を採用することで、柔軟性・拡張性・可用性を高め、業務効率化を実現します。\n'
#            '\n'
#            '### 2. 推奨クラウドプラットフォーム  \n'
#            '| プラットフォーム | 推奨エリア | 備考 |\n'
#            '|-----------------|------------|------|\n'
#            '| **AWS** | アジア太平洋地域 | 主要クラウドプロバイダーとしての実績と豊富なサービス群 |\n'
#            '| **Microsoft Azure** | グローバル | エンタープライズ向け統合機能とオンプレミスとの親和性 |\n'
#            '\n'
#            '### 3. 主要選定基準  \n'
#            '1. **可用性（Availability）**  \n'
#            '   - 99.99\u202f% 以上の可用性保証が必須。  \n'
#            '   - SLA（Service Level Agreement）に明記され、継続的に監視・報告されることが求められます。  \n'
#            '\n'
#            '2. **セキュリティ認証**  \n'
#            '   - **ISO\u202f27017**（クラウドサービスの情報セキュリティ管理に関する国際規格）の取得が必須。  \n'
#            '   - さらに、SOC\u202f2 Type\u202f'
#            '2レポートの提出やゼロトラストアーキテクチャの実装が求められる場合があります。  \n'
#            '\n'
#            '3. **コスト最適化**  \n'
#            '   - 予算内で最大限のリソースを確保できる価格モデル（例：予約インスタンス、スポットインスタンス）を活用。  \n'
#            '   - 料金体系が透明で、利用状況に応じた詳細レポートが提供されること。  \n'
#            '\n'
#            '4. **コンプライアンスとガバナンス**  \n'
#            '   - グローバル規模でのデータ保護規制（GDPR、個人情報保護法等）に準拠。  \n'
#            '   - 監査ログやアクセス制御の設定が容易に管理できること。  \n'
#            '\n'
#            '5. **パフォーマンスとスケーラビリティ**  \n'
#            '   - 必要に応じて自動スケーリングが可能で、ピーク時の負荷に耐えられる設計。  \n'
#            '   - ネットワークレイテンシが業務要件を満たすこと。  \n'
#            '\n'
#            '### 4. 実装時のチェックリスト  \n'
#            '- **SLA確認**：可用性、障害時の対応時間、復旧手順を明文化。  \n'
#            '- **認証証明書の取得**：ISO\u202f27017、SOC\u202f2 Type\u202f'
#            '2などの証明書を取得し、提出。  \n'
#            '- **コスト管理ツール**：利用状況を可視化し、予算超過を防止。  \n'
#            '- **セキュリティポリシー**：ゼロトラストアクセス、脆弱性診断（年2回以上）を実施。  \n'
#            '\n'
#            '### 5. まとめ  \n'
#            'クラウドプラットフォーム選定は、単に「クラウドを使う」だけでなく、**可用性・セキュリティ・コスト・コンプライアンス**という多面的な要件を満たすことが不可欠です。AWSとMicrosoft '
#            'Azureは、推奨エリアと認証取得の観点から最適な選択肢とされています。選定にあたっては、上記の基準とチェックリストを活用し、組織全体のITガバナンスとリスク管理に沿った意思決定を行ってください。',
#  'provenance': {'chunks': [{'chunk_id': 'chunk-all-d46b860c1a540be92f1a51e798cc1fe9',
#                             'chunk_order_index': 0,
#                             'content': '# 1. 目的\n'
#                                        '本ガイドラインは、グループ全体のITガバナンスを強化し、サイバーセキュリティリスクを低減しつつ、ITコストの最適化を図ることを目的とする。\n'
#                                        '\n'
#                                        '# 2. クラウドファースト戦略\n'
#                                        '新規ITシステムの導入に際しては、クラウドネイティブな構成を原則とする。\n'
#                                        '- 推奨プラットフォーム：AWS (Asia Pacific '
#                                        'Regions), Microsoft Azure (Global)\n'
#                                        '- 調達基準：可用性99.99%以上の保証、およびISO '
#                                        '27017認証の取得が必須。\n'
#                                        '\n'
#                                        '# 3. ソフトウェア・ライセンス管理\n'
#                                        'SaaS利用の急増に伴い、シャドーITの撲滅とライセンス費用の重複を排除する。\n'
#                                        '- '
#                                        '全拠点共通のSaaS管理ツールを導入し、利用率が30%以下のアプリケーションについては契約更新を行わない。\n'
#                                        '- '
#                                        'オープンソースソフトウェア（OSS）の利用に関しては、法務部およびセキュリティ部門の承認が必要。\n'
#                                        '\n'
#                                        '# 4. セキュリティ要件（サプライチェーンセキュリティ）\n'
#                                        'ITサービス提供ベンダーに対しては、以下のセキュリティ基準への準拠を求める。\n'
#                                        '1. SOC2 Type2レポートの定期的な提出。\n'
#                                        '2. ゼロトラストアーキテクチャに基づいたアクセス制御の実装。\n'
#                                        '3. 脆弱性診断を年2回以上実施し、その結果を報告すること。\n'
#                                        '\n'
#                                        '# 5. ハードウェア調達と循環経済\n'
#                                        'PC、サーバー、ネットワーク機器の調達において、環境負荷を最小限に抑える。\n'
#                                        '- '
#                                        '廃棄されるハードウェアの80%以上をリサイクルまたはリユースする「IT資産循環プログラム」をQ3より開始する。\n'
#                                        '- '
#                                        '消費電力効率が前世代比で15%以上向上しているモデルを優先的に選定する。\n'
#                                        '2026年度 次世代ITサービス調達・運用ガイドライン\n'
#                                        'NA\n'
#                                        'finalized\n'
#                                        'グローバル全拠点におけるIT資産、ソフトウェア、クラウドサービスの調達基準とセキュリティ要件。\n'
#                                        'procurement_docs\n'
#                                        '2025-10-02T09:15:00+00:00',
#                             'full_doc_id': 'contract-na-fy2025-qsi',
#                             'tokens': 600}],
#                 'entities': [{'description': '"Companies that provide IT '
#                                              'services to clients, required to '
#                                              'comply with specified security '
#                                              'standards."<SEP>"ITサービス提供ベンダー '
#                                              'refers to IT service providers '
#                                              'that must comply with security '
#                                              'standards such as SOC2 Type2 '
#                                              'reports and zero‑trust '
#                                              'architecture."',
#                               'entity_name': '"ITサービス提供ベンダー"',
#                               'score': 0.3931897799456885}]}}
#
# 参照したチャンク:
# - # 1. 目的
#
# 質問: サプライヤーに対するESGやCO2排出に関する要求事項は何ですか？
# ★デバッグ(minirag.py): mini mode
# ★デバッグ(postgres_impl.py): create_graph already exists
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 3 results
# ✅ Result 1: id=Ename-773fbe264b..., distance=0.3420490765411286
# ✅ Result 2: id=Ename-4ecfeeae37..., distance=0.29918793914103214
# 🔎 Total records in LIGHTRAG_DOC_CHUNKS: 16
# 🔎 Raw metadata and distance values:
#    - ID: chunk-summary-6e...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'summary', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.059525514008428204
#    - ID: chunk-summary-bc...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': 'summary', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.0391188407539409
#    - ID: chunk-title-171b...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'title', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.03223009848783387
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 3 results
# ✅ Result 1: id=Ename-907695ffae..., distance=0.2530565945296287
# ✅ Result 2: id=Ename-609c969072..., distance=0.23728350518881902
# 🔎 Total records in LIGHTRAG_DOC_CHUNKS: 16
# 🔎 Raw metadata and distance values:
#    - ID: chunk-title-e215...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': 'title', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.10990376084914266
#    - ID: chunk-summary-6e...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'summary', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.10776332040807712
#    - ID: chunk-title-171b...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'title', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.10734009315194093
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 3 results
# ✅ Result 1: id=ent-b37553307b37..., distance=0.2842717050337631
# ✅ Result 2: id=Ename-fc2ee528fb..., distance=0.2513877373387021
# 🔎 Total records in LIGHTRAG_DOC_CHUNKS: 16
# 🔎 Raw metadata and distance values:
#    - ID: chunk-all-2bcdca...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': '_all', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.043206955634748634
#    - ID: chunk-body-af651...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'body', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.043206955634748634
#    - ID: chunk-summary-bc...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': 'summary', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.021984346143404387
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 3 results
# ✅ Result 1: id=Ename-773fbe264b..., distance=0.4433894151186395
# ✅ Result 2: id=Ename-4ecfeeae37..., distance=0.35215969509030454
# 🔎 Total records in LIGHTRAG_DOC_CHUNKS: 16
# 🔎 Raw metadata and distance values:
#    - ID: chunk-all-2bcdca...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': '_all', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.005487029479131822
#    - ID: chunk-body-af651...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'body', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.005487029479131822
#    - ID: chunk-summary-6e...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'summary', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.0028376728167138765
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x32303236e5b9b4e5baa6e3818be3828932303238e5b9b4e5baa6e381bee381a7e381aee4b8ade69c9fe7b58ce596b6e8a888e794bb"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x32303236e5b9b4e5baa620e6aca1e4b896e4bba34954e382b5e383bce38393e382b9e8aabfe98194e383bbe9818be794a8e382ace382a4e38389e383a9e382a4e383b3"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe7acace4b889e88085e6a99fe996a2"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x415753"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe382a4e383b3e38389e5b882e5a0b4"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe4b8bbe8a681e382b5e38397e383a9e382a4e383a4e383bc"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe382afe383a9e382a6e38389e38395e382a1e383bce382b9e38388e688a6e795a5"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe5a4a7e8a68fe6a8a1e781bde5aeb3e799bae7949fe69982"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 12 results
# ✅ Result 1: id=..., distance=0.18196455162642533
# ✅ Result 2: id=..., distance=0.17617833134941607
# 🔎 Total records in LIGHTRAG_VDB_RELATION: 32
# 🔎 Raw metadata and distance values:
#    - ID: rel-9c77646c572e...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': 'body', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.18196455162642533
#    - ID: rel-c52286f7af4b...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'title', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.17617833134941607
#    - ID: rel-cd422c054355...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'summary', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.16627812634211925
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# 回答:
# {'answer': 'I’m sorry, but the information you’re looking for isn’t included '
#            'in the data that was provided. The mid‑term management plan '
#            'references procurement optimization, supplier resilience, and cost '
#            'structure reform in the APAC region, but it does not detail any '
#            'specific ESG or CO₂ emission requirements for suppliers. If you '
#            'have additional documents or sources that contain those details, '
#            'feel free to share them and I’ll be happy to help interpret them.',
#  'provenance': {'chunks': [{'chunk_id': 'chunk-summary-6e9e0387db74f4bdebe77292ebbcccea',
#                             'chunk_order_index': 0,
#                             'content': '2026年度から2028年度までの中期経営計画に基づき、APAC地域における調達オペレーションの最適化、サプライヤー・レジリエンスの強化、およびコスト構造の改革を定義する包括的文書。',
#                             'full_doc_id': 'proc-plan-fy2026-apac',
#                             'tokens': 69}],
#                 'entities': [{'description': '"The 2026‑2028 mid‑term '
#                                              'management plan outlines '
#                                              'optimization of procurement '
#                                              'operations, strengthening '
#                                              'supplier resilience, and '
#                                              'reforming cost structure within '
#                                              'the APAC region."<SEP>"The '
#                                              'mid‑term management plan '
#                                              'covering fiscal years 2026 to '
#                                              '2028 outlines procurement '
#                                              'operation optimization, supplier '
#                                              'resilience strengthening, and '
#                                              'cost structure reform in the '
#                                              'APAC region."',
#                               'entity_name': '"2026年度から2028年度までの中期経営計画"',
#                               'score': 0.4433894151186395}]}}
#
# 参照したチャンク:
# - 2026年度から2028年度までの中期経営計画に基づき、APAC地域における調達オペレーションの最適化、サプライヤー・レジリエンスの強化、およびコスト構造の改革を定義する包括的文書。

# %%
# 約12分かかった
import time
start_time = time.time()

# サンプルテキストデータ
sample_texts = [
    """
今日は素晴らしい一日でした。朝早く起きて、近所の公園を散歩しました。
桜の花が満開で、とても美しかったです。午後は友人と映画を見に行きました。
「君の名は。」という映画で、とても感動的でした。
夜は家族と一緒に夕食を取り、楽しい時間を過ごしました。
""",
    """
昨日は仕事で大きなプロジェクトが完了しました。
チーム全員で3ヶ月間取り組んできたAIシステムの開発が終わりました。
機械学習モデルの精度が95%を超え、クライアントからも高い評価をいただきました。
今夜はチームメンバーと祝賀会を開く予定です。
""",
    """
週末は料理に挑戦しました。初めてパスタを一から作ってみました。
小麦粉から麺を作るのは思っていたより難しかったですが、
最終的にはとても美味しいカルボナーラができました。
次回はリゾットに挑戦してみたいと思います。
""",
    """
読書が趣味で、最近は村上春樹の「ノルウェイの森」を読んでいます。
主人公の心情描写がとても繊細で、引き込まれます。
また、技術書も読んでおり、「深層学習」について学んでいます。
理論と実践のバランスが取れた良い本だと思います。
"""
]

# データの挿入
print("データを挿入中...")

async def insert_texts(rag_instance, texts):
    for i, text in enumerate(texts):
        print(f"テキスト {i+1}/{len(texts)} を挿入中...")
        await rag_instance.ainsert(text.strip())   # overwrite は デフォルトは False 

    print("\nすべてのデータが挿入されました！")


# イベントループが既に実行中の場合
try:
    await insert_texts(rag, sample_texts)
except RuntimeError:
    # 新しいループで実行
    asyncio.run(insert_texts(rag, sample_texts))

end_time = time.time()
elapsed_time = end_time - start_time
print(f"処理時間: {elapsed_time:.4f}秒")
# Out:
# データを挿入中...
# テキスト 1/4 を挿入中...
# 🚀 AINSERT called with overwrite=False
# 📥 Input: 1 documents
# 📥 IDs: None
# 📥 Metadatas: None
# 📝 Storing doc 'doc-6ecfce929dc1037e02183d8a074dd3d9' with metadata: {}
# ⚙️  Processing doc 'doc-6ecfce929dc1037e02183d8a074dd3d9', status_doc.metadata = {}
# 📦 Created 1 standard chunks for doc 'doc-6ecfce929dc1037e02183d8a074dd3d9'
#    └─ Chunk 'chunk-3c79463c8d...' text_field: _all, metadata: {'text_field': '_all'}
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 58.47batch/s]
# 💾 Upserting chunk 'chunk-3c79463c8d...' with metadata: {'text_field': '_all'}
# ⠙ Processed 1 chunks, 4 entities(duplicated), 4 relations(duplicated)
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 48.80batch/s]
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 64.50batch/s]
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 66.99batch/s]
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 49.98batch/s]
# KG successfully indexed.
# テキスト 2/4 を挿入中...
# 🚀 AINSERT called with overwrite=False
# 📥 Input: 1 documents
# 📥 IDs: None
# 📥 Metadatas: None
# 📝 Storing doc 'doc-6abf97cb07bd0b4f3449e46d819865dc' with metadata: {}
# ⚙️  Processing doc 'doc-6abf97cb07bd0b4f3449e46d819865dc', status_doc.metadata = {}
# 📦 Created 1 standard chunks for doc 'doc-6abf97cb07bd0b4f3449e46d819865dc'
#    └─ Chunk 'chunk-23680af8dd...' text_field: _all, metadata: {'text_field': '_all'}
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 75.00batch/s]
# 💾 Upserting chunk 'chunk-23680af8dd...' with metadata: {'text_field': '_all'}
# ⠙ Processed 1 chunks, 7 entities(duplicated), 7 relations(duplicated)
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 36.44batch/s]
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 37.60batch/s]
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 56.85batch/s]
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 39.87batch/s]
# KG successfully indexed.
# テキスト 3/4 を挿入中...
# 🚀 AINSERT called with overwrite=False
# 📥 Input: 1 documents
# 📥 IDs: None
# 📥 Metadatas: None
# 📝 Storing doc 'doc-5014bbd787359c7b7cbe71ab6e0bff62' with metadata: {}
# ⚙️  Processing doc 'doc-5014bbd787359c7b7cbe71ab6e0bff62', status_doc.metadata = {}
# 📦 Created 1 standard chunks for doc 'doc-5014bbd787359c7b7cbe71ab6e0bff62'
#    └─ Chunk 'chunk-cf733b0e4f...' text_field: _all, metadata: {'text_field': '_all'}
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 62.72batch/s]
# 💾 Upserting chunk 'chunk-cf733b0e4f...' with metadata: {'text_field': '_all'}
# ⠙ Processed 1 chunks, 6 entities(duplicated), 9 relations(duplicated)
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 34.07batch/s]
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 46.33batch/s]
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 56.72batch/s]
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 24.00batch/s]
# KG successfully indexed.
# テキスト 4/4 を挿入中...
# 🚀 AINSERT called with overwrite=False
# 📥 Input: 1 documents
# 📥 IDs: None
# 📥 Metadatas: None
# 📝 Storing doc 'doc-fa8a23778c759fee02925671c2270866' with metadata: {}
# ⚙️  Processing doc 'doc-fa8a23778c759fee02925671c2270866', status_doc.metadata = {}
# 📦 Created 1 standard chunks for doc 'doc-fa8a23778c759fee02925671c2270866'
#    └─ Chunk 'chunk-4091c9fc91...' text_field: _all, metadata: {'text_field': '_all'}
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 82.12batch/s]
# 💾 Upserting chunk 'chunk-4091c9fc91...' with metadata: {'text_field': '_all'}
# ⠙ Processed 1 chunks, 7 entities(duplicated), 10 relations(duplicated)
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 24.03batch/s]
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 28.46batch/s]
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 43.86batch/s]
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 26.97batch/s]
# KG successfully indexed.
#
# すべてのデータが挿入されました！
# 処理時間: 24.9748秒

# %%
# 約3分かかった

def print_test_case(name: str, answer: str, source: str, ):
    """テストケースの結果を分かりやすく表示するヘルパー関数"""
    print(f"\n--- {name} ---")
    print("Answer:", answer)
    print("Source:", source)
    print("-" * (len(name) + 8))


# # サンプルクエリ
# queries = [
#     "映画について教えて",
#     "仕事のプロジェクトはどうでしたか？",
#     "料理で何を作りましたか？",
#     "読んでいる本について教えて",
#     "散歩について詳しく教えて"
# ]

# # 各モードでクエリを実行。この3つがある
# modes = ["naive", "mini", "light"]

# for query in queries:
#     print(f"\n{'='*50}")
#     print(f"クエリ: {query}")
#     print(f"{'='*50}")

#     for mode in modes:
#         print(f"\n--- {mode.upper()}モード ---")
#         try:
#             answer = rag.query(query, param=QueryParam(mode=mode))     # .replace("\n", "").replace("\r", "")
#             print(f"回答: {answer}")
#         except Exception as e:
#             print(f"エラー: {e}")


async def run_queries(rag_instance, queries):
    # 各モードでクエリを実行。この3つがある
    modes = ["naive", "mini", "light"]

    for query in queries:
        print(f"\n{'='*50}")
        print(f"クエリ: {query}")
        print(f"{'='*50}")

        for mode in modes:
            print(f"\n--- {mode.upper()}モード ---")
            try:
                # 非同期でクエリを実行
                _answer, _source = await rag_instance.aquery(query, param=QueryParam(mode=mode))
                print_test_case(mode+"モード", _answer, _source)
            except Exception as e:
                print(f"エラー: {e}")


start_time = time.time()

sample_queries = [
    "映画について教えて",
    "仕事のプロジェクトはどうでしたか？",
    "料理で何を作りましたか？",
    "読んでいる本について教えて",
    "散歩について詳しく教えて"
]

# イベントループが既に実行中の場合
try:
    await run_queries(rag, sample_queries)
except RuntimeError:
    # 新しいループで実行
    asyncio.run(run_queries(rag, sample_queries))


end_time = time.time()
elapsed_time = end_time - start_time
print(f"処理時間: {elapsed_time:.4f}秒")
# Out:
# ==================================================
# クエリ: 映画について教えて
# ==================================================
#
# --- NAIVEモード ---
# 🎯 Using distance threshold: -1.0
# 🔍 No metadata filter applied
# 📊 Query returned 20 results
# ✅ Result 1: id=chunk-cf733b0e4f..., distance=0.4565610454279263
# ✅ Result 2: id=chunk-23680af8dd..., distance=0.45122152041276387
# 🔎 Total records in LIGHTRAG_DOC_CHUNKS: 20
# 🔎 Records with metadata: 20
# 🔎 Raw metadata and distance values:
#    - ID: chunk-cf733b0e4f...
#      Raw metadata: {'text_field': '_all'}
#      Extracted category: None
#      Distance: 0.4565610454279263
#    - ID: chunk-23680af8dd...
#      Raw metadata: {'text_field': '_all'}
#      Extracted category: None
#      Distance: 0.45122152041276387
#    - ID: chunk-4091c9fc91...
#      Raw metadata: {'text_field': '_all'}
#      Extracted category: None
#      Distance: 0.3793197605176075
#
# --- naiveモード ---
# Answer: 提供された文書情報によると、映画に関する具体的な記述は、個人の日常の出来事に関する箇所に限られています。文書には、ある方が「君の名は。」という映画を友人と一緒に観に行った際、その作品が非常に感動的であったと感想を述べている内容が含まれています。これは、個人的な娯楽活動や体験談の一部として記録されたものです。
#
# 一方、ビジネスや戦略に関する文書（「2026年度 APAC地域包括調達戦略・実施計画書」や「2026年度 次世代ITサービス調達・運用ガイドライン」など）には、映画の内容、業界動向、またはビジネスにおける映画の利用に関する具体的な情報は一切記載されていません。これらの文書は、主にサプライチェーンの最適化、デジタル変革、ITガバナンス、およびリスク管理に関する方針に焦点を当てています。
#
# したがって、提供されたデータに基づき得られる映画に関する情報は、上記の個人的な体験談のみとなります。映画のあらすじ、キャスト、制作背景、または一般的な映画業界の分析については、この文書からは情報を得ることができません。
# Source: ['昨日は仕事で大きなプロジェクトが完了しました。\nチーム全員で3ヶ月間取り組んできたAIシステムの開発が終わりました。\n機械学習モデルの精度が95%を超え、クライアントからも高い評価をいただきました。\n...', '今日は素晴らしい一日でした。朝早く起きて、近所の公園を散歩しました。\n桜の花が満開で、とても美しかったです。午後は友人と映画を見に行きました。\n「君の名は。」という映画で、とても感動的でした。\n夜は家...', '読書が趣味で、最近は村上春樹の「ノルウェイの森」を読んでいます。\n主人公の心情描写がとても繊細で、引き込まれます。\nまた、技術書も読んでおり、「深層学習」について学んでいます。\n理論と実践のバランスが...', '# 1. はじめに\n本計画書は、地政学的リスクの増大と原材料価格の変動に対応するため、2026年度におけるAPAC地域の調達方針を定めるものである。\n\n# 2. 戦略目標\n2026年度の最優先課題は「供給網の安定化」と「持続可能なコスト削減」の両立である。具体的には以下のKPIを設定する。\n- 重点カテゴリーにおける複数社購買（Multi-sourcing）率を現状の40%から65%へ引き上げる。\n- 地域内調達率（LCR: Local Content Ratio）を平均12%向上させ、物流コストと関税リスクを低減する。\n- AIによる需給予測モデルを本格稼働させ、過剰在庫による保管コストを年間で約1.2億円削減する。\n\n# 3. サプライヤーマネジメント\n## 3.1 新規サプライヤーの開拓\n東南アジア諸国（特にベトナム、タイ、インドネシア）における製造拠点の拡大に伴い、現地の有力サプライヤー50社との戦略的パートナーシップを締結する。\n特にインド市場においては、半導体関連部材の現地調達比率を25%まで高めることを目指す。\n\n## 3.2 ESG対応と監査\n2026年度より、全ての主要サプライヤー（年間取引額1億円以上）に対し、CO2排出量の四半期報告を義務付ける。\nまた、人権デューデリジェンスに関する第三者機関による監査を、対象企業の30%で実施する。\n\n# 4. デジタル変革（Procurement DX）\n調達プロセスの透明性を高めるため、次世代型E-Procurementシステムを全拠点に導入する。\nこれにより、発注から支払いまでのリードタイムを20%短縮し、サプライヤー支払いの100%電子化を実現する。\n\n# 5. リスク管理\n地政学的リスクに対応するため、特定の1カ国に生産が集中している重要部材（23品目）について、代替生産拠点の確保をQ2（7-9月）までに完了させる。\n大規模災害発生時の緊急調達フローを再構築し、初動対応時間を現状の24時間から6時間以内へ短縮する。\n2026年度 APAC地域包括調達戦略・実施計画書（第1版）\nAPAC\nin_progress\n2026年度から2028年度までの中期経営計画に基づき、APAC地域における調達オペレーションの最適化、サプライヤー・レジリエンスの強化、およびコスト構造の改革を定義する包括的文書。\nprocurement_docs\n2025-10-01T08:30:00+00:00', '# 1. 目的\n本ガイドラインは、グループ全体のITガバナンスを強化し、サイバーセキュリティリスクを低減しつつ、ITコストの最適化を図ることを目的とする。\n\n# 2. クラウドファースト戦略\n新規ITシステムの導入に際しては、クラウドネイティブな構成を原則とする。\n- 推奨プラットフォーム：AWS (Asia Pacific Regions), Microsoft Azure (Global)\n- 調達基準：可用性99.99%以上の保証、およびISO 27017認証の取得が必須。\n\n# 3. ソフトウェア・ライセンス管理\nSaaS利用の急増に伴い、シャドーITの撲滅とライセンス費用の重複を排除する。\n- 全拠点共通のSaaS管理ツールを導入し、利用率が30%以下のアプリケーションについては契約更新を行わない。\n- オープンソースソフトウェア（OSS）の利用に関しては、法務部およびセキュリティ部門の承認が必要。\n\n# 4. セキュリティ要件（サプライチェーンセキュリティ）\nITサービス提供ベンダーに対しては、以下のセキュリティ基準への準拠を求める。\n1. SOC2 Type2レポートの定期的な提出。\n2. ゼロトラストアーキテクチャに基づいたアクセス制御の実装。\n3. 脆弱性診断を年2回以上実施し、その結果を報告すること。\n\n# 5. ハードウェア調達と循環経済\nPC、サーバー、ネットワーク機器の調達において、環境負荷を最小限に抑える。\n- 廃棄されるハードウェアの80%以上をリサイクルまたはリユースする「IT資産循環プログラム」をQ3より開始する。\n- 消費電力効率が前世代比で15%以上向上しているモデルを優先的に選定する。\n2026年度 次世代ITサービス調達・運用ガイドライン\nNA\nfinalized\nグローバル全拠点におけるIT資産、ソフトウェア、クラウドサービスの調達基準とセキュリティ要件。\nprocurement_docs\n2025-10-02T09:15:00+00:00', '# 1. 目的\n本ガイドラインは、グループ全体のITガバナンスを強化し、サイバーセキュリティリスクを低減しつつ、ITコストの最適化を図ることを目的とする。\n\n# 2. クラウドファースト戦略\n新規ITシステムの導入に際しては、クラウドネイティブな構成を原則とする。\n- 推奨プラットフォーム：AWS (Asia Pacific Regions), Microsoft Azure (Global)\n- 調達基準：可用性99.99%以上の保証、およびISO 27017認証の取得が必須。\n\n# 3. ソフトウェア・ライセンス管理\nSaaS利用の急増に伴い、シャドーITの撲滅とライセンス費用の重複を排除する。\n- 全拠点共通のSaaS管理ツールを導入し、利用率が30%以下のアプリケーションについては契約更新を行わない。\n- オープンソースソフトウェア（OSS）の利用に関しては、法務部およびセキュリティ部門の承認が必要。\n\n# 4. セキュリティ要件（サプライチェーンセキュリティ）\nITサービス提供ベンダーに対しては、以下のセキュリティ基準への準拠を求める。\n1. SOC2 Type2レポートの定期的な提出。\n2. ゼロトラストアーキテクチャに基づいたアクセス制御の実装。\n3. 脆弱性診断を年2回以上実施し、その結果を報告すること。\n\n# 5. ハードウェア調達と循環経済\nPC、サーバー、ネットワーク機器の調達において、環境負荷を最小限に抑える。\n- 廃棄されるハードウェアの80%以上をリサイクルまたはリユースする「IT資産循環プログラム」をQ3より開始する。\n- 消費電力効率が前世代比で15%以上向上しているモデルを優先的に選定する。', '# 1. はじめに\n本計画書は、地政学的リスクの増大と原材料価格の変動に対応するため、2026年度におけるAPAC地域の調達方針を定めるものである。\n\n# 2. 戦略目標\n2026年度の最優先課題は「供給網の安定化」と「持続可能なコスト削減」の両立である。具体的には以下のKPIを設定する。\n- 重点カテゴリーにおける複数社購買（Multi-sourcing）率を現状の40%から65%へ引き上げる。\n- 地域内調達率（LCR: Local Content Ratio）を平均12%向上させ、物流コストと関税リスクを低減する。\n- AIによる需給予測モデルを本格稼働させ、過剰在庫による保管コストを年間で約1.2億円削減する。\n\n# 3. サプライヤーマネジメント\n## 3.1 新規サプライヤーの開拓\n東南アジア諸国（特にベトナム、タイ、インドネシア）における製造拠点の拡大に伴い、現地の有力サプライヤー50社との戦略的パートナーシップを締結する。\n特にインド市場においては、半導体関連部材の現地調達比率を25%まで高めることを目指す。\n\n## 3.2 ESG対応と監査\n2026年度より、全ての主要サプライヤー（年間取引額1億円以上）に対し、CO2排出量の四半期報告を義務付ける。\nまた、人権デューデリジェンスに関する第三者機関による監査を、対象企業の30%で実施する。\n\n# 4. デジタル変革（Procurement DX）\n調達プロセスの透明性を高めるため、次世代型E-Procurementシステムを全拠点に導入する。\nこれにより、発注から支払いまでのリードタイムを20%短縮し、サプライヤー支払いの100%電子化を実現する。\n\n# 5. リスク管理\n地政学的リスクに対応するため、特定の1カ国に生産が集中している重要部材（23品目）について、代替生産拠点の確保をQ2（7-9月）までに完了させる。\n大規模災害発生時の緊急調達フローを再構築し、初動対応時間を現状の24時間から6時間以内へ短縮する。', '週末は料理に挑戦しました。初めてパスタを一から作ってみました。\n小麦粉から麺を作るのは思っていたより難しかったですが、\n最終的には ...
# ----------------
#
# --- MINIモード ---
# ★デバッグ(minirag.py): mini mode
# ★デバッグ(postgres_impl.py): create_graph already exists
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 60 results
# ✅ Result 1: id=Ename-40ebe0b76a..., distance=0.4103584140432367
# ✅ Result 2: id=Ename-242746dddd..., distance=0.2998535312468895
# 🔎 Total records in LIGHTRAG_DOC_CHUNKS: 20
# 🔎 Raw metadata and distance values:
#    - ID: chunk-23680af8dd...
#      Raw metadata: {'text_field': '_all'}
#      Extracted category: None
#      Distance: 0.3848904487212099
#    - ID: chunk-cf733b0e4f...
#      Raw metadata: {'text_field': '_all'}
#      Extracted category: None
#      Distance: 0.3469636607494717
#    - ID: chunk-4091c9fc91...
#      Raw metadata: {'text_field': '_all'}
#      Extracted category: None
#      Distance: 0.23829931235275348
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 60 results
# ✅ Result 1: id=ent-c486cdd21a17..., distance=0.2884472257454773
# ✅ Result 2: id=Ename-71a243e81b..., distance=0.21294034912917437
# 🔎 Total records in LIGHTRAG_DOC_CHUNKS: 20
# 🔎 Raw metadata and distance values:
#    - ID: chunk-3c79463c8d...
#      Raw metadata: {'text_field': '_all'}
#      Extracted category: None
#      Distance: 0.06257639777843793
#    - ID: chunk-cf733b0e4f...
#      Raw metadata: {'text_field': '_all'}
#      Extracted category: None
#      Distance: 0.05771033523021507
#    - ID: chunk-title-e215...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': 'title', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.0564956585354488
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 60 results
# ✅ Result 1: id=ent-c486cdd21a17..., distance=0.34927577590733094
# ✅ Result 2: id=Ename-831acda0e8..., distance=0.21673845160920524
# 🔎 Total records in LIGHTRAG_DOC_CHUNKS: 20
# 🔎 Raw metadata and distance values:
#    - ID: chunk-cf733b0e4f...
#      Raw metadata: {'text_field': '_all'}
#      Extracted category: None
#      Distance: 0.12469604607690155
#    - ID: chunk-3c79463c8d...
#      Raw metadata: {'text_field': '_all'}
#      Extracted category: None
#      Distance: 0.07893844380389892
#    - ID: chunk-23680af8dd...
#      Raw metadata: {'text_field': '_all'}
#      Extracted category: None
#      Distance: 0.05137109745969104
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe980b1e69cab"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe6aca1e4b896e4bba34954e382b5e383bce38393e382b9e8aabfe98194e383bbe9818be794a8e382ace382a4e38389e383a9e382a4e383b3"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe7a781"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe383aae382bee38383e38388"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe5b08fe9baa6e7b289"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x434f32e68e92e587bae9878f"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe382b3e382b9e38388e6a78be980a0e381aee694b9e99da9"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x32303236e5b9b4e5baa62041504143e59cb0e59f9fe58c85e68bace8aabfe98194e688a6e795a5"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe58f8be4baba"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe6a19ce381aee88ab1"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe7acace4b889e88085e6a99fe996a2"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe382b3e382b9e38388e6a78be980a0"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe58d8ae5b08ee4bd93"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x4954e8b387e794a3e5beaae792b0e38397e383ade382b0e383a9e383a0"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x4d5552414b414d4920484152554b49"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe8aabfe98194"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe8bf91e68980e381aee585ace59c92"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe382abe383abe3839ce3838ae383bce383a9"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe382bce383ade38388e383a9e382b9e38388e382a2e383bce382ade38386e382afe38381e383a3"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe38391e382b9e382bf"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe8aabfe98194e382aae3839ae383ace383bce382b7e383a7e383b3"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x32303236e5b9b4e5baa62041504143e59cb0e59f9fe58c85e68bace8aabfe98194e688a6e795a5e383bbe5ae9fe696bde8a888e794bbe69bb8efbc88e7acac31e78988efbc89"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe38399e38388e3838ae383a0"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe382b5e382a4e38390e383bce382bbe382ade383a5e383aae38386e382a3e383aae382b9e382af"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x41504143e59cb0e59f9fe58c85e68bace8aabfe98194e688a6e795a5"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe382b5e38397e383a9e382a4e383a4e383bce383bbe383ace382b8e383aae382a8e383b3e382b9"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe58c85e68bace79a84e69687e69bb8"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe88486e5bcb1e680a7e8a8bae696ad"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe382a2e382b8e382a2e5a4aae5b9b3e6b48be59cb0e59f9f"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x32303238e5b9b4e5baa6"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x452d50524f435552454d454e54e382b7e382b9e38386e383a0"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe58c85e68bace8aabfe98194"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x32303236e5b9b4e5baa6"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe382a4e383b3e38389e3838de382b7e382a2"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe382b5e38397e383a9e382a4e383a4e383bc"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x4954e382b5e383bce38393e382b9"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x5133"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe382b0e383abe383bce38397"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe4b8ade69c9fe7b58ce596b6e8a888e794bb"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe382b7e383a3e38389e383bc4954"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x44454550204c4541524e494e47"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x544845205445414d"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x4d414348494e45204c4541524e494e47204d4f44454c"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x544543484e4943414c20424f4f4b53"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x41492053595354454d"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x5448524545204d4f4e544853"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x41492053595354454d5320444556454c4f504d454e54"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x54484520535045414b4552"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x5448454f5259"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe5aeb6"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x594553544552444159"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x53454d49434f4e445543544f52"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x434c49454e54"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x5132"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x513220284a554c592d53455054454d42455229"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x494e444941"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x434f3220454d495353494f4e205245504f5254"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x323032362046495343414c2059454152"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x323320435249544943414c20434f4d504f4e454e5453"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x3530204c4f43414c20535550504c49455253"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x564945544e414d"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x5052414354494345"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x323032352d31302d3032"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x50524f435552454d454e54204458"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x3230323620414e4e55414c2050524f435552454d454e54205354524154454759"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x4d414a4f5220535550504c49455253"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x32303236"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x4e4f5257454749414e20574f4f44"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x534f465457415245"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x544841494c414e44"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x4954e382ace38390e3838ae383b3e382b9"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x41504143e59cb0e59f9f"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "x4150414320524547494f4e"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None
# ★デバッグ(postgres_impl.py): create_graph already exists
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 132 results
# ✅ Result 1: id=..., distance=0.21628998857039483
# ✅ Result 2: id=..., distance=0.21607864829380152
# 🔎 Total records in LIGHTRAG_VDB_RELATION: 132
# 🔎 Raw metadata and distance values:
#    - ID: rel-7b59e1095d30...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': '_all', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.21628998857039483
#    - ID: rel-dc3fbb1272c2...
#      Raw metadata: {'text_field': '_all'}
#      Extracted category: None
#      Distance: 0.21607864829380152
#    - ID: rel-f6a6c6ed2766...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': '_all', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.21280161326147906
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
#
# --- miniモード ---
# Answer: 入力されたデータに基づくと、映画に関する具体的な情報は限定的ですが、以下の通り確認できます。
#
# 提供されたテキスト（ソースID 3）において、話者は週末の活動について触れており、午後に友人と映画館へ足を運んだことが記されています。そこで鑑賞したのは新海誠監督の作品である「君の名は。」です。話者はこの映画に対して「とても感動的でした」と強い感情的反応を示しており、映画鑑賞がその日の素晴らしい一日の一部を構成していたことがわかります。
#
# ただし、他のデータソース（調達戦略、ITガバナンス、読書日記など）やエンティティリストを確認した限り、「君の名は。」以外に特定の映画タイトルや映画業界の動向に関する詳細な情報は記載されていません。したがって、映画に関するより広範な解説や他の作品の紹介については、提供されたデータ内では裏付けが得られないため、これ以上の情報を追加することはできません。
# ...
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 60 results
# ✅ Result 1: id=..., distance=0.3713288992687407
# ✅ Result 2: id=..., distance=0.22653146094120902
# 🔎 Total records in LIGHTRAG_VDB_RELATION: 132
# 🔎 Raw metadata and distance values:
#    - ID: rel-4ead52d31f48...
#      Raw metadata: {'text_field': '_all'}
#      Extracted category: None
#      Distance: 0.3713288992687407
#    - ID: rel-06e970b46b42...
#      Raw metadata: {'text_field': '_all'}
#      Extracted category: None
#      Distance: 0.22653146094120902
#    - ID: rel-d8412ae29bbc...
#      Raw metadata: {'year': 2025, 'region': 'NA', 'category': 'contract', 'priority': 1, 'text_field': '_all', 'supplier_name': 'Quantum Systems Inc.', 'owner_department': 'Legal & Supply Chain Management', 'contract_value_usd': 12000000}
#      Extracted category: contract
#      Distance: 0.17599183651656258
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# エラー: Error code: 400 - {'error': {'code': 400, 'message': 'request (21009 tokens) exceeds the available context size (8192 tokens), try increasing it', 'type': 'exceed_context_size_error', 'n_prompt_tokens': 21009, 'n_ctx': 8192}}
# 処理時間: 30.8294秒

# %% [markdown]
# ## ここからは metadata_filter と time_filter を使ったテスト

# %% [markdown]
# ## 初回も2回目もうまくいった(2回目というのは以下のセルを2回実行するということ)
# - 精度にブレがあり、回答できる時とできない時があるが、今回は精度は求めていないのでこれで OK とする

# %%
from datetime import datetime, timedelta
from typing import Optional, Dict, List, Any

async def run_tests():
    """RAGシステムのフィルタリング機能をテストするメイン関数"""
    # 0. RAGシステムのセットアップ
    try:
        rag_with_filter = await setup_rag_system()
        print("------------------------- RAGシステムが初期化されました！ -------------------------")
    except Exception as e:
        print(f"RAGシステムのセットアップに失敗しました: {e}")
        return

    # 1. テストデータの準備と登録
    # タイムスタンプのテストのため、登録を複数回に分ける
    print("\n[ステップ1] データの登録を開始します...")

    # データセット1
    docs1 = [
        {"doc_id": "doc1", "content": "今日は東京でとても良い天気です。", "metadata": {"category": "weather", "city": "Tokyo", "year": 2024}},
        {"doc_id": "doc2", "content": "昨日の大阪は雨でした。", "metadata": {"category": "weather", "city": "Osaka", "year": 2024}},
    ]
    await rag_with_filter.ainsert(
        input=[d["content"] for d in docs1],
        ids=[d["doc_id"] for d in docs1],
        metadatas=[d["metadata"] for d in docs1],
        overwrite=True
    )
    print("データセット1 (doc1, doc2) を登録しました。")
    
    time_after_docs1 = datetime.utcnow()  # → Postgres は UTC で解釈するため、必ず UTC にすること
    await asyncio.sleep(10)  # タイムスタンプを明確に区別するため10秒待機
    
    # データセット2
    docs2 = [
        {"doc_id": "doc3", "content": "日本の首都は東京です。最近は兵庫も主要な都市に入るか議論されています。", "metadata": {"category": "geography", "country": "Japan", "year": 2023}},
        {"doc_id": "doc4", "content": "大阪は日本の主要な都市の一つです。最近は秋田も主要な都市に入るか議論されています。", "metadata": {"category": "geography", "country": "Japan", "year": 2023}},
        {"doc_id": "doc5", "content": "What is the capital of Japan? It's Tokyo.", "metadata": {}},  # メタデータなし
    ]
    await rag_with_filter.ainsert(
        input=[d["content"] for d in docs2],
        ids=[d["doc_id"] for d in docs2],
        metadatas=[d["metadata"] for d in docs2],
        overwrite=True
    )
    print("データセット2 (doc3, doc4, doc5) を登録しました。")
    time_after_docs2 = datetime.utcnow()  # → Postgres は UTC で解釈するため、必ず UTC にすること

    print("\n[ステップ2] 検索フィルタリングのテストを実行します...")

    # 思考プロセスと回答言語の指示
    instruction = "英語で思考して日本語で回答してください。回答は情報源に基づいて回答し、回答できない場合は`回答できない`と答えてください。"

    # --- メタデータフィルタリングのテスト ---
    param1 = QueryParam(mode="light",
                        metadata_filter={"category": "weather"})
    query1 = f"今日の天気について教えてください。{instruction}"
    answer1, source1 = await rag_with_filter.aquery(query1, param=param1)
    print_test_case("Test Case 1: 単一メタデータでフィルタ ('weather')", answer1, source1)

    param2 = QueryParam(mode="light",
                        metadata_filter={"category": "geography", "country": "Japan"})
    query2 = f"日本の地理に関する情報を情報源に基づいて回答してください。{instruction}"
    answer2, source2 = await rag_with_filter.aquery(query2, param=param2)
    print_test_case("Test Case 2: 複数メタデータでフィルタ (AND条件)。ちゃんと成功したのでフィルター機能は正常かも。ただ、ちょっと精度が低い", answer2, source2,)

    param3 = QueryParam(mode="light",
                        metadata_filter={"city": "北海道"})
    query3 = f"北海道の天気はどうですか？{instruction}"
    answer3, source3 = await rag_with_filter.aquery(query3, param=param3)
    print_test_case("Test Case 3: 存在しないメタデータ値でフィルタ（失敗例）", answer3, source3)

    query4 = f"東京について何か知っていますか？{instruction}"
    answer4, source4 = await rag_with_filter.aquery(query4) # フィルタなし
    print_test_case("Test Case 4: フィルタなしで検索", answer4, source4)

    param5 = QueryParam(mode="light",
                        metadata_filter={"category": "weather"})
    query5 = f"今日 の 東京 の 天気 について詳しく教えてください。{instruction}" # 'Tokyo'はdoc5にも含まれるが、こっちはフィルタで除外されるはず
    answer5, source5 = await rag_with_filter.aquery(query5, param=param5)
    print_test_case("Test Case 5: メタデータフィルタはメタデータなし文書を除外(正解: 天気について回答できる。これ精度が低い気がする)", answer5, source5)

    param6 = QueryParam(mode="light",
                        metadata_filter={"year": 2023})
    query6 = f"2023年の日本の出来事について何か知っていますか？{instruction}"
    answer6, source6 = await rag_with_filter.aquery(query6, param=param6)
    print_test_case("Test Case 6: 数値のメタデータでフィルタ", answer6, source6)

    # --- 時間フィルタリングのテスト ---
    param7 = QueryParam(mode="light",
                        start_time=time_after_docs1.isoformat())
    query7 = f"日本に関する最近登録された情報を教えてください。{instruction}"
    answer7, source7 = await rag_with_filter.aquery(query7, param=param7)
    print_test_case("Test Case 7: 'start_time'でフィルタ (後半の登録データのみ)。正解: 後半のデータのみで回答できること", answer7, source7)

    param8 = QueryParam(mode="light",
                        end_time=time_after_docs1.isoformat())
    query8 = f"大阪のことについて、なにか分かることを教えてください。{instruction}"
    answer8, source8 = await rag_with_filter.aquery(query8, param=param8)
    print_test_case("Test Case 8: 'end_time'でフィルタ (前半の登録データのみ)。正解: 大阪の天気について回答できること。これは精度が低いかも", answer8, source8)

    param9 = QueryParam(mode="light",
                        start_time=time_after_docs1.isoformat(), end_time=(time_after_docs1 - timedelta(seconds=10)).isoformat())
    query9 = f"東京について何か情報は登録されましたか？{instruction}"
    answer9, source9 = await rag_with_filter.aquery(query9, param=param9) # スタート時間よりも10秒前で指定している
    print_test_case("Test Case 9: 時間範囲指定 (結果なし)", answer9, source9)

    # --- 複合フィルタリングのテスト ---
    param10 = QueryParam(mode="light",
                         metadata_filter={"category": "geography"}, start_time=time_after_docs1.isoformat())
    query10 = f"日本の地理に関して、最近の話題を探しています。{instruction}"
    answer10, source10 = await rag_with_filter.aquery(query10, param=param10)
    print_test_case("Test Case 10: メタデータと時間の複合フィルタ (成功例。後半の情報を使う)", answer10, source10)


    param10 = QueryParam(mode="light",
                         metadata_filter={"category": "geography"}, end_time=time_after_docs1.isoformat())
    query10 = f"日本の地理に関して、最近の話題を探しています。{instruction}"
    answer10, source10 = await rag_with_filter.aquery(query10, param=param10)
    print_test_case("こっちはエンドタイムでやってみた。(失敗例。metadata_filter: geography とタイムフィルター)", answer10, source10)


    param10 = QueryParam(mode="light",
                                                                     end_time=time_after_docs1.isoformat())
    query10 = f"日本の地理に関して、最近の話題を探しています。{instruction}"
    answer10, source10 = await rag_with_filter.aquery(query10, param=param10)
    print_test_case("こっちはエンドタイムでやってみた。(失敗例。タイムフィルターのみ)", answer10, source10)


    
    param11 = QueryParam(mode="light",
                         metadata_filter={"category": "weather"}, start_time=time_after_docs1.isoformat())
    query11 = f"最近の天気予報について教えてください。{instruction}"
    answer11, source11 = await rag_with_filter.aquery(query11, param=param11)
    print_test_case("Test Case 11: メタデータと時間の複合フィルタ (失敗例)", answer11, source11)

    # --- その他のテスト ---
    query12 = f"フランスの首都について教えてください。{instruction}"
    answer12, source12 = await rag_with_filter.aquery(query12)
    print_test_case("Test Case 12: クエリがどの文書にもマッチしない", answer12, source12)



await run_tests()
# Out:
# ------------------------- ポスグレに接続しています -------------------------
# ------------------------- ポスグレに接続しました！ -------------------------
# ------------------------- テーブルの存在を確認・作成しています -------------------------
# ------------------------- テーブルの準備が完了しました！ -------------------------
# ------------------------- RAGシステムが初期化されました！ -------------------------
#
# [ステップ1] データの登録を開始します...
# 🚀 AINSERT called with overwrite=True
# 📥 Input: 2 documents
# 📥 IDs: ['doc1', 'doc2']
# 📥 Metadatas: [{'category': 'weather', 'city': 'Tokyo', 'year': 2024}, {'category': 'weather', 'city': 'Osaka', 'year': 2024}]
# 🔥 OVERWRITE MODE: Deleting existing chunks for 2 documents
# 📝 Storing doc 'doc1' with metadata: {'category': 'weather', 'city': 'Tokyo', 'year': 2024}
# 📝 Storing doc 'doc2' with metadata: {'category': 'weather', 'city': 'Osaka', 'year': 2024}
# ⚙️  Processing doc 'doc1', status_doc.metadata = {"city": "Tokyo", "year": 2024, "category": "weather"}
# 📦 Created 1 standard chunks for doc 'doc1'
#    └─ Chunk 'chunk-7da419c35b...' text_field: _all, metadata: {'city': 'Tokyo', 'year': 2024, 'category': 'weather', 'text_field': '_all'}
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 55.03batch/s]
# 💾 Upserting chunk 'chunk-7da419c35b...' with metadata: {'city': 'Tokyo', 'year': 2024, 'category': 'weather', 'text_field': '_all'}
# ⠙ Processed 1 chunks, 1 entities(duplicated), 0 relations(duplicated)
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ⚙️  Processing doc 'doc2', status_doc.metadata = {"city": "Osaka", "year": 2024, "category": "weather"}
# 📦 Created 1 standard chunks for doc 'doc2'
#    └─ Chunk 'chunk-4b17ba18b5...' text_field: _all, metadata: {'city': 'Osaka', 'year': 2024, 'category': 'weather', 'text_field': '_all'}
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 59.99batch/s]
# 💾 Upserting chunk 'chunk-4b17ba18b5...' with metadata: {'city': 'Osaka', 'year': 2024, 'category': 'weather', 'text_field': '_all'}
# ⠙ Processed 1 chunks, 2 entities(duplicated), 1 relations(duplicated)
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 67.04batch/s]
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 75.30batch/s]
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 124.99batch/s]
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 98.98batch/s]
# KG successfully indexed.
# データセット1 (doc1, doc2) を登録しました。
# 🚀 AINSERT called with overwrite=True
# 📥 Input: 3 documents
# 📥 IDs: ['doc3', 'doc4', 'doc5']
# 📥 Metadatas: [{'category': 'geography', 'country': 'Japan', 'year': 2023}, {'category': 'geography', 'country': 'Japan', 'year': 2023}, {}]
# 🔥 OVERWRITE MODE: Deleting existing chunks for 3 documents
# 📝 Storing doc 'doc5' with metadata: {}
# 📝 Storing doc 'doc4' with metadata: {'category': 'geography', 'country': 'Japan', 'year': 2023}
# 📝 Storing doc 'doc3' with metadata: {'category': 'geography', 'country': 'Japan', 'year': 2023}
# ⚙️  Processing doc 'doc3', status_doc.metadata = {"year": 2023, "country": "Japan", "category": "geography"}
# 📦 Created 1 standard chunks for doc 'doc3'
#    └─ Chunk 'chunk-da7de75046...' text_field: _all, metadata: {'year': 2023, 'country': 'Japan', 'category': 'geography', 'text_field': '_all'}
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 60.24batch/s]
# 💾 Upserting chunk 'chunk-da7de75046...' with metadata: {'year': 2023, 'country': 'Japan', 'category': 'geography', 'text_field': '_all'}
# ⠙ Processed 1 chunks, 3 entities(duplicated), 3 relations(duplicated)
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 47.70batch/s]
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 64.10batch/s]
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 77.91batch/s]
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 64.17batch/s]
# ⚙️  Processing doc 'doc4', status_doc.metadata = {"year": 2023, "country": "Japan", "category": "geography"}
# 📦 Created 1 standard chunks for doc 'doc4'
#    └─ Chunk 'chunk-1b272f6fd1...' text_field: _all, metadata: {'year': 2023, 'country': 'Japan', 'category': 'geography', 'text_field': '_all'}
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 68.58batch/s]
# 💾 Upserting chunk 'chunk-1b272f6fd1...' with metadata: {'year': 2023, 'country': 'Japan', 'category': 'geography', 'text_field': '_all'}
# ⠙ Processed 1 chunks, 3 entities(duplicated), 3 relations(duplicated)
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 51.50batch/s]
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 53.96batch/s]
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 91.70batch/s]
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 72.17batch/s]
# ⚙️  Processing doc 'doc5', status_doc.metadata = {}
# 📦 Created 1 standard chunks for doc 'doc5'
#    └─ Chunk 'chunk-94cf9b5fb2...' text_field: _all, metadata: {'text_field': '_all'}
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 179.81batch/s]
# 💾 Upserting chunk 'chunk-94cf9b5fb2...' with metadata: {'text_field': '_all'}
# ⠙ Processed 1 chunks, 2 entities(duplicated), 1 relations(duplicated)
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 60.31batch/s]
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 77.74batch/s]
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 138.28batch/s]
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00, 135.83batch/s]
# KG successfully indexed.
# データセット2 (doc3, doc4, doc5) を登録しました。
#
# [ステップ2] 検索フィルタリングのテストを実行します...
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 60 results
# ✅ Result 1: id=Ename-8ed3a92466..., distance=0.4758305801752106
# ✅ Result 2: id=ent-b6c85b592401..., distance=0.47106852425582246
# 🔎 Total records in LIGHTRAG_VDB_ENTITY: 218
# 🔎 Raw metadata and distance values:
#    - ID: Ename-8ed3a92466...
#      Raw metadata: {'text_field': '_all'}
#      Extracted category: None
#      Distance: 0.4758305801752106
#    - ID: ent-b6c85b592401...
#      Raw metadata: {'city': 'Osaka', 'year': 2024, 'category': 'weather', 'text_field': '_all'}
#      Extracted category: weather
#      Distance: 0.47106852425582246
#    - ID: ent-4f02f499ba62...
#      Raw metadata: {'text_field': '_all'}
#      Extracted category: None
#      Distance: 0.43871134559439495
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# [Local] Metadata filter: {'category': 'weather'}
# [Local] before: 16 candidates
# [Local] before samples:
#   - id=chunk-da7de75046..., category=geography, distance=0.23848341628060676
#   - id=chunk-94cf9b5fb2..., category=None, distance=0.3826965864159466
#   - id=chunk-4b17ba18b5..., category=weather, distance=0.23209457530012023
#   - id=chunk-7da419c35b..., category=weather, distance=0.35408943753265354
#   - id=chunk-1b272f6fd1..., category=geography, distance=0.15083606608754252
# [Local] filter reduced candidates: before=16 -> after=2
# [Local] Metadata filter: {'category': 'weather'}
# [Local] after: 2 candidates
# [Local] after samples:
#   - id=chunk-4b17ba18b5..., category=weather, distance=0.23209457530012023
#   - id=chunk-7da419c35b..., category=weather, distance=0.35408943753265354
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 60 results
# ✅ Result 1: id=..., distance=0.3682420965921248
# ✅ Result 2: id=..., distance=0.3508348197622597
# 🔎 Total records in LIGHTRAG_VDB_RELATION: 139
# 🔎 Raw metadata and distance values:
#    - ID: rel-5a7b3b5f4443...
#      Raw metadata: {'city': 'Osaka', 'year': 2024, 'category': 'weather', 'text_field': '_all'}
#      Extracted category: weather
#      Distance: 0.3682420965921248
#    - ID: rel-2f3f8335ab96...
#      Raw metadata: {'year': 2026, 'region': 'APAC', 'version': '2.1', 'approver': 'John Smith', 'category': 'planning_document', 'priority': 1, 'text_field': 'body', 'owner_department': 'IT Procurement Department'}
#      Extracted category: planning_document
#      Distance: 0.3508348197622597
#    - ID: rel-1ba5ec027be1...
#      Raw metadata: {'text_field': '_all'}
#      Extracted category: None
#      Distance: 0.33052833339043786
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# [Global] Metadata filter: {'category': 'weather'}
# [Global] before: 0 candidates
# [Global] filter reduced candidates: before=0 -> after=0
# [Global] Metadata filter: {'category': 'weather'}
# [Global] after: 0 candidates
#
# --- Test Case 1: 単一メタデータでフィルタ ('weather') ---
# Answer: 今日は東京で非常に良い天気です。この情報は、提供されたデータソースの1番目のエントリ「今日は東京でとても良い天気です。」に基づいています。東京は日本の首都であり、行政的および地理的な関係にある主要な都市として位置づけられています。
#
# 一方で、昨日の大阪の天気については、雨だったという情報があります。これは「昨日の大阪は雨でした。」というソースから得られた情報です。しかし、今日の日付における大阪の天気状況については、提供されたデータには記載されていないため、お答えすることはできません。
#
# まとめると、今日の東京の天気は非常に良好ですが、大阪の今日の天気については情報が不足しており、回答できません。
# Source: ['昨日の大阪は雨でした。', '今日は東京でとても良い天気です。']
# ---------------------------------------------
# 🎯 Using distance threshold: -1.0
# 📊 Query returned 60 results
# ✅ Result 1: id=Ename-8ed3a92466..., distance=0.6229396676612611
# ✅ Result 2: id=ent-af8dc1059b7c..., distance=0.5480357030498479
# 🔎 Total records in LIGHTRAG_VDB_ENTITY: 218
# 🔎 Raw metadata and distance values:
#    - ID: Ename-8ed3a92466...
#      Raw metadata: {'text_field': '_all'}
#      Extracted category: None
#      Distance: 0.6229396676612611
#    - ID: ent-af8dc1059b7c...
#      Raw metadata: {'year': 2023, 'country': 'Japan', 'category': 'geography', 'text_field': '_all'}
#      Extracted category: geography
#      Distance: 0.5480357030498479
#    - ID: ent-8ed3a92466b2...
#      Raw metadata: {'text_field': '_all'}
#      Extracted category: None
#      Distance: 0.5453992102772686
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# [Local] Metadata filter: {'category': 'geography', 'country': 'Japan'}
# [Local] before: 17 candidates
# [Local] before samples:
#   - id=chunk-da7de75046..., category=geography, distance=0.25888053870871475
#   - id=chunk-94cf9b5fb2..., category=None, distance=0.5522748273521867
#   - id=chunk-7da419c35b..., category=weather, distance=0.2582835368811196
#   - id=chunk-1b272f6fd1..., category=geography, distance=0.12928072517041878
# ...
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ★デバッグ(postgres_impl.py): create_graph already exists
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[34], line 144
#     139     answer12, source12 = await rag_with_filter.aquery(query12)
#     140     print_test_case("Test Case 12: クエリがどの文書にもマッチしない", answer12, source12)
# --> 144 await run_tests()
#
# Cell In[34], line 99, in run_tests()
#      96 param8 = QueryParam(mode="light",
#      97                     end_time=time_after_docs1.isoformat())
#      98 query8 = f"大阪のことについて、なにか分かることを教えてください。{instruction}"
# ---> 99 answer8, source8 = await rag_with_filter.aquery(query8, param=param8)
#     100 print_test_case("Test Case 8: 'end_time'でフィルタ (前半の登録データのみ)。正解: 大阪の天気について回答できること。これは精度が低いかも", answer8, source8)
#     102 param9 = QueryParam(mode="light",
#     103                     start_time=time_after_docs1.isoformat(), end_time=(time_after_docs1 - timedelta(seconds=10)).isoformat())
#
# File ~/.local/lib/python3.11/site-packages/minirag/minirag.py:1125, in MiniRAG.aquery(self, query, param)
#    1122     param = self._apply_target_fields_filter(param)
#    1124 if param.mode == "light":
# -> 1125     response, source = await hybrid_query(
#    1126         query,
#    1127         self.chunk_entity_relation_graph,
#    1128         self.entities_vdb,
#    1129         self.relationships_vdb,
#    1130         self.text_chunks,
#    1131         self.chunks_vdb,
#    1132         param,
#    1133         asdict(self),
#    1134     )
#    1135 elif param.mode == "mini":
#    1136     print("★デバッグ(minirag.py): mini mode")
#
# File ~/.local/lib/python3.11/site-packages/minirag/operate.py:1217, in hybrid_query(query, knowledge_graph_inst, entities_vdb, relationships_vdb, text_chunks_db, chunks_vdb, query_param, global_config)
#    1213 sys_prompt_temp = PROMPTS["rag_response"]
#    1214 sys_prompt = sys_prompt_temp.format(
#    1215     context_data=context, response_type=query_param.response_type
#    1216 )
# -> 1217 response = await use_model_func(
#    1218     query,
#    1219     system_prompt=sys_prompt,
#    1220 )
#    1221 if len(response) > len(sys_prompt):
#    1222     response = (
#    1223         response.replace(sys_prompt, "")
#    1224         .replace("user", "")
#    (...)   1229         .strip()
#    1230     )
#
# File ~/.local/lib/python3.11/site-packages/minirag/utils.py:110, in limit_async_func_call.<locals>.final_decro.<locals>.wait_func(*args, **kwargs)
#     108     await asyncio.sleep(waitting_time)
#     109 __current_size += 1
# --> 110 result = await func(*args, **kwargs)
#     111 __current_size -= 1
#     112 return result
#
# File ~/.local/lib/python3.11/site-packages/tenacity/asyncio/__init__.py:193, in AsyncRetrying.wraps.<locals>.async_wrapped(*args, **kwargs)
#     191 copy = self.copy()
#     192 async_wrapped.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 193 return await copy(fn, *args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/tenacity/asyncio/__init__.py:112, in AsyncRetrying.__call__(self, fn, *args, **kwargs)
#     110 is_async = _utils.is_coroutine_callable(fn)
#     111 while True:
# --> 112     do = await self.iter(retry_state=retry_state)
#     113     if isinstance(do, DoAttempt):
#     114         try:
#
# File ~/.local/lib/python3.11/site-packages/tenacity/asyncio/__init__.py:157, in AsyncRetrying.iter(self, retry_state)
#     155 result = None
#     156 for action in self.iter_state.actions:
# --> 157     result = await action(retry_state)
#     158 return result
#
# File ~/.local/lib/python3.11/site-packages/tenacity/_utils.py:111, in wrap_to_async_func.<locals>.inner(*args, **kwargs)
#     110 async def inner(*args: typing.Any, **kwargs: typing.Any) -> typing.Any:
# --> 111     return call(*args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/tenacity/__init__.py:393, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     391 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     392     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393         self._add_action_func(lambda rs: rs.outcome.result())
#     394         return
#     396     if self.after is not None:
#
# File /usr/local/lib/python3.11/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /usr/local/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/.local/lib/python3.11/site-packages/tenacity/asyncio/__init__.py:116, in AsyncRetrying.__call__(self, fn, *args, **kwargs)
#     114 try:
#     115     if is_async:
# --> 116         result = await fn(*args, **kwargs)
#     117     else:
#     118         result = fn(*args, **kwargs)
#
# Cell In[24], line 372, in openai_complete(prompt, system_prompt, history_messages, keyword_extraction, **kwargs)
#     369 if not model_name:
#     370     model_name = LLAMA_SERVER_MODEL_ALIAS_DEFAULT
# --> 372 return await openai_complete_if_cache(
#     373     model_name,
#     374     prompt,
#     375     system_prompt=system_prompt,
#     376     history_messages=history_messages,
#     377     **kwargs,
#     378 )
#
# Cell In[24], line 263, in openai_complete_if_cache(model, prompt, system_prompt, history_messages, base_url, api_key, **kwargs)
#     260         create_kwargs["extra_body"] = extra_body
#     262 try:
# --> 263     response = await openai_async_client.chat.completions.create(
#     264         model=model,
#     265         messages=messages,
#     266         **create_kwargs,
#     267     )
#     268 except APIConnectionError as e:
#     269     # ここに来るのは「到達不能」系がほとんどなので、情報を付ける
#     270     raise ConnectionError(
#     271         "OpenAI互換サーバへの接続に失敗しました。\n"
#     272         f"- base_url = {resolved_base_url}\n"
#     273         "確認: `curl http://172.17.0.1:1067/v1/health` が返るかを見てください。\n"
#     274         "注: llama-server の `--host 0.0.0.0` は待受用です。接続先は 172.17.0.1 か実IPにしてください。"
#     275     ) from e
#
# File ~/.local/lib/python3.11/site-packages/openai/resources/chat/completions/completions.py:2700, in AsyncCompletions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    2653 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    2654 async def create(
#    2655     self,
#    (...)   2697     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    2698 ) -> ChatCompletion | AsyncStream[ChatCompletionChunk]:
#    2699     validate_response_format(response_format)
# -> 2700     return await self._post(
#    2701         "/chat/completions",
#    2702         body=await async_maybe_transform(
#    2703             {
#    2704                 "messages": messages,
#    2705                 "model": model,
#    2706                 "audio": audio,
#    2707                 "frequency_penalty": frequency_penalty,
#    2708                 "function_call": function_call,
#    2709                 "functions": functions,
#    2710                 "logit_bias": logit_bias,
#    2711                 "logprobs": logprobs,
#    2712                 "max_completion_tokens": max_completion_tokens,
#    2713                 "max_tokens": max_tokens,
#    2714                 "metadata": metadata,
#    2715                 "modalities": modalities,
#    2716                 "n": n,
#    2717                 "parallel_tool_calls": parallel_tool_calls,
#    2718                 "prediction": prediction,
#    2719                 "presence_penalty": presence_penalty,
#    2720                 "prompt_cache_key": prompt_cache_key,
#    2721                 "prompt_cache_retention": prompt_cache_retention,
#    2722                 "reasoning_effort": reasoning_effort,
#    2723                 "response_format": response_format,
#    2724                 "safety_identifier": safety_identifier,
#    2725                 "seed": seed,
#    2726                 "service_tier": service_tier,
#    2727                 "stop": stop,
#    2728                 "store": store,
#    2729                 "stream": stream,
#    2730                 "stream_options": stream_options,
#    2731                 "temperature": temperature,
#    2732                 "tool_choice": tool_choice,
#    2733                 "tools": tools,
#    2734                 "top_logprobs": top_logprobs,
#    2735                 "top_p": top_p,
#    2736                 "user": user,
#    2737                 "verbosity": verbosity,
#    2738                 "web_search_options": web_search_options,
#    2739             },
#    2740             completion_create_params.CompletionCreateParamsStreaming
#    2741             if stream
#    2742             else completion_create_params.CompletionCreateParamsNonStreaming,
#    2743         ),
#    2744         options=make_request_options(
#    2745             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    2746         ),
#    2747         cast_to=ChatCompletion,
#    2748         stream=stream or False,
#    2749         stream_cls=AsyncStream[ChatCompletionChunk],
#    2750     )
#
# File ~/.local/lib/python3.11/site-packages/openai/_base_client.py:1884, in AsyncAPIClient.post(self, path, cast_to, body, content, files, options, stream, stream_cls)
#    1875     warnings.warn(
#    1876         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1877         "Please pass raw bytes via the `content` parameter instead.",
#    1878         DeprecationWarning,
#    1879         stacklevel=2,
#    1880     )
#    1881 opts = FinalRequestOptions.construct(
#    1882     method="post", url=path, json_data=body, content=content, files=await async_to_httpx_files(files), **options
#    1883 )
# -> 1884 return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File ~/.local/lib/python3.11/site-packages/openai/_base_client.py:1669, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1666             await err.response.aread()
#    1668         log.debug("Re-raising status error")
# -> 1669         raise self._make_status_error_from_response(err.response) from None
#    1671     break
#    1673 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'error': {'code': 400, 'message': 'request (18004 tokens) exceeds the available context size (8192 tokens), try increasing it', 'type': 'exceed_context_size_error', 'n_prompt_tokens': 18004, 'n_ctx': 8192}}

# %% [markdown]
# ### メモ
#
# - Mini モード／Light モードで使用している chunks_vdb.query() すべてに debug=False を明示したので、混乱を招くようなデバッグ表示は出ないようにした。ただし、Naive モードはデバッグ表示が ON になっているのでデバッグ表示の量がちょっと多い。また、Mini モードは一部 ベクトル検索を使っている関係で Naive モードと同じデバッグ表示が表示される。
# - デバッグ表示が ON になると以下が表示される。これらの表示が Mini モードや Naive モードで表示されるということ
#   - 「Total records in LIGHTRAG_DOC_CHUNKS: X」
#   - 「Raw metadata and distance values: ~~~」
#     - 「Raw metadata and distance values:」はトップ3が表示される仕様
# - ドキュメントIDが重複すると Deleted が出るのは仕様でOK。一回消して再インデックスを作成しているから。
# - 大量に出ている表示は正常
#   - 「★デバッグ(postgres_impl.py): create_graph already exists」がたくさん出るのは正常。ナレッジグラフがあるかどうか必ずチェックする仕様になっているため。
#   - Mini モードの「SELECT * FROM cypher('～～～」 や None も正常
# - 次元が混在するとエラーになるので、embedding model は基本的に統一した方が良い
# - doc_id はなくてもいいけど、管理しやすくなるのであった方が良さそう
# - 「🔎 Raw metadata and distance values:」というデバッグ出力はメタデータのフィルタリング「前」のVDBクエリ結果を表示しており、実際にLLMへ渡す直前のコンテキスト構築ではフィルタ済みのチャンクのみが使われているので、フィルターが適用されていないように見えるが問題なく動作している。
#   - メタデータフィルタはVDBクエリ段階では渡さず、チャンク取得後に適用する方針の実装になっています。
#   - ローカル文脈構築でのメタデータフィルタ適用。グローバル文脈構築でも同様にチャンク側でフィルタ
#   - 一方、デバッグ出力はVDBクエリ（pre-filter）内で行われています（件数・距離・生メタデータの表示）。

# %%
# 以下が色々出るのは仕様なので正常な動作。いっぱい出るのは並列処理しているらしい
# 正常に動いていることを確認したいので、あえて出したままにしている。
# ---------------------------------------------------------
# ★デバッグ(postgres_impl.py): create_graph already exists



# postgres16_age_pgvector_container  | 2025-07-22 04:43:01.467 UTC [1672] ERROR:  graph "my_minirag_graph" already exists
# postgres16_age_pgvector_container  | 2025-07-22 04:43:01.467 UTC [1672] STATEMENT:  select create_graph('my_minirag_graph')



# SELECT * FROM cypher('my_minirag_graph', $$
#                      MATCH path = (start:Entity {node_id: "xe980b1e69cab"})-[*1..2]-(neighbor:Entity)
#                      RETURN [n in nodes(path) | properties(n).node_id] AS path_nodes,
#                             [r in relationships(path) | r] AS path_edges
#                    $$) AS (path_nodes agtype, path_edges agtype)
# None

# 上記のクエリも合っているし Miniモード も正常に機能しているので問題ない。多分表示している箇所は PostgreSQLDB クラスの execute メソッドだと思う。




# INFO:minirag:Using the label default for PostgreSQL as identifier
# INFO:minirag:Connected to PostgreSQL database at postgres:5432/my_database
# ERROR:minirag:PostgreSQL database error: relation "lightrag_doc_full" does not exist
# ERROR:minirag:Failed to check table LIGHTRAG_DOC_FULL in PostgreSQL database
# ERROR:minirag:PostgreSQL database error: relation "lightrag_doc_full" does not exist
# INFO:minirag:Created table LIGHTRAG_DOC_FULL in PostgreSQL database
# ERROR:minirag:PostgreSQL database error: relation "lightrag_doc_chunks" does not exist
# ERROR:minirag:Failed to check table LIGHTRAG_DOC_CHUNKS in PostgreSQL database
# ERROR:minirag:PostgreSQL database error: relation "lightrag_doc_chunks" does not exist
# INFO:minirag:Created table LIGHTRAG_DOC_CHUNKS in PostgreSQL database
# ERROR:minirag:PostgreSQL database error: relation "lightrag_vdb_entity" does not exist
# ERROR:minirag:Failed to check table LIGHTRAG_VDB_ENTITY in PostgreSQL database
# ERROR:minirag:PostgreSQL database error: relation "lightrag_vdb_entity" does not exist
# INFO:minirag:Created table LIGHTRAG_VDB_ENTITY in PostgreSQL database
# ERROR:minirag:PostgreSQL database error: relation "lightrag_vdb_relation" does not exist
# ERROR:minirag:Failed to check table LIGHTRAG_VDB_RELATION in PostgreSQL database
# ERROR:minirag:PostgreSQL database error: relation "lightrag_vdb_relation" does not exist
# INFO:minirag:Created table LIGHTRAG_VDB_RELATION in PostgreSQL database
# ERROR:minirag:PostgreSQL database error: relation "lightrag_llm_cache" does not exist
# ERROR:minirag:Failed to check table LIGHTRAG_LLM_CACHE in PostgreSQL database
# ERROR:minirag:PostgreSQL database error: relation "lightrag_llm_cache" does not exist
# INFO:minirag:Created table LIGHTRAG_LLM_CACHE in PostgreSQL database
# ERROR:minirag:PostgreSQL database error: relation "lightrag_doc_status" does not exist
# ERROR:minirag:Failed to check table LIGHTRAG_DOC_STATUS in PostgreSQL database
# ERROR:minirag:PostgreSQL database error: relation "lightrag_doc_status" does not exist
# INFO:minirag:Created table LIGHTRAG_DOC_STATUS in PostgreSQL database
# INFO:minirag:Finished checking all tables in PostgreSQL database
# INFO:minirag:Logger initialized for working directory: /tmp/minirag_demo

# 上記の表示されている ERROR ログは、一見すると問題のように見えますが、実際には 「テーブルが存在しないことを検知した」 という正常な動作の一部です。check_tables メソッドは、このエラーを意図的に発生させて、テーブルが存在しない場合にのみ作成処理を行うように設計されています。
